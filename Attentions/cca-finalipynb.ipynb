# %% [markdown]
# # Mitotic Figure Binary Classification with Pre-Augmented Dataset - DenseNet GAP
#
# This notebook trains a PyTorch model for binary classification of mitotic figures using a pre-augmented Kaggle dataset with DenseNet architecture.
#
# ## Dataset Overview:
# - **Source**: Pre-augmented AMI-BR and MIDOG25 datasets from Kaggle
# - **Location**: `/kaggle/input/MitoticFigure_AugmentedDataSet/`
# - **Target**: Binary classification - Atypical vs Normal mitotic figures
# - **Data**: Includes original images + 4x augmented AMF images for better class balance
#
# ## Features:
# - Uses pre-processed and augmented dataset
# - Slide-based stratified splitting for proper validation
# - **DenseNet-121 architecture with Global Average Pooling (GAP)**
# - Full model training (entire DenseNet-121 + custom head trainable)
# - Comprehensive evaluation metrics

# %%
# Installation commands intentionally removed.
# Assumes required packages (torch, torchvision, timm, albumentations, ptflops, etc.)
# are already installed in the environment. If not, install them manually via pip or conda.

# %%
# Core libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Image processing
import cv2
from PIL import Image
import albumentations as A
from albumentations.pytorch import ToTensorV2

# Deep learning
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR
import torchvision.transforms as transforms
import torchvision.models as models

# Machine learning utilities
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Plotting style
plt.style.use('default')
sns.set_palette("husl")

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

print("All libraries imported successfully!")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# Out:
# All libraries imported successfully!
# PyTorch version: 2.6.0+cu124
# CUDA available: True
# CUDA device: Tesla P100-PCIE-16GB

# %%
# Set random seeds for reproducibility
import random

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# Define paths for your Kaggle dataset structure
BASE_DIR = Path('/kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset')
TRAINING_DIR = BASE_DIR / 'training'
VALIDATION_DIR = BASE_DIR / 'validation'
TESTING_DIR = BASE_DIR / 'testing'
DATASET_CSV = BASE_DIR / 'mitotic_figures_dataset.csv'

print(f"📁 Dataset paths for your pre-split Kaggle dataset:")
print(f"Base directory: {BASE_DIR}")
print(f"Training images: {TRAINING_DIR}")
print(f"Validation images: {VALIDATION_DIR}")
print(f"Testing images: {TESTING_DIR}")
print(f"Dataset CSV: {DATASET_CSV}")

# Check if directories exist
for dir_path, name in [(TRAINING_DIR, 'Training'), (VALIDATION_DIR, 'Validation'), (TESTING_DIR, 'Testing')]:
    if dir_path.exists():
        print(f"✅ {name} directory found")
    else:
        print(f"❌ {name} directory not found: {dir_path}")

# Training parameters (Optimized for DenseNet-121 with GAP)
IMG_SIZE = 224            # Standard input size for DenseNet
BATCH_SIZE = 32          # Good batch size for DenseNet-121
EPOCHS = 50              # Assignment requirement: minimum 50 epochs
LEARNING_RATE = 1e-3     # Learning rate for custom layers only
NUM_CLASSES = 2
PATIENCE = 10            # Assignment requirement: patience = 10 for early stopping

print(f"🎯 DENSENET-121 GAP PARAMETERS:")
print(f"Model: DenseNet-121 + Global Average Pooling")
print(f"Dataset directory: {BASE_DIR}")
print(f"Dataset CSV: {DATASET_CSV}")
print(f"Image size: {IMG_SIZE}x{IMG_SIZE} (standard for DenseNet)")
print(f"Batch size: {BATCH_SIZE}")
print(f"Epochs: {EPOCHS} (minimum as per assignment)")
print(f"Learning rate: {LEARNING_RATE} (custom layers only)")
print(f"Training approach: GAP + FULL MODEL training (entire network)")
print(f"Early stopping patience: {PATIENCE}")
print(f"Using GPU: {torch.cuda.is_available()}")
print(f"Automatic pretrained weights: ✅ (ImageNet DenseNet-121)")
# Out:
# 📁 Dataset paths for your pre-split Kaggle dataset:
# Base directory: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset
# Training images: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/training
# Validation images: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/validation
# Testing images: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/testing
# Dataset CSV: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/mitotic_figures_dataset.csv
# ✅ Training directory found
# ✅ Validation directory found
# ✅ Testing directory found
# 🎯 DENSENET-121 GAP PARAMETERS:
# Model: DenseNet-121 + Global Average Pooling
# Dataset directory: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset
# Dataset CSV: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/mitotic_figures_dataset.csv
# Image size: 224x224 (standard for DenseNet)
# Batch size: 32
# Epochs: 50 (minimum as per assignment)
# Learning rate: 0.001 (custom layers only)
# Training approach: GAP + FULL MODEL training (entire network)
# Early stopping patience: 10
# Using GPU: True
# Automatic pretrained weights: ✅ (ImageNet DenseNet-121)

# %% [markdown]
# ## Loading Pre-Augmented Dataset

# %%
# Load the organized dataset from your Kaggle upload
print("Loading pre-split dataset from Kaggle...")

# Load the CSV with all metadata
df = pd.read_csv(DATASET_CSV)
print(f"Dataset loaded: {df.shape}")
print(f"Columns: {df.columns.tolist()}")

# Display dataset information
print(f"\nDataset Statistics:")
print(f"Total samples: {len(df)}")

# Check split distribution
if 'split' in df.columns:
    split_counts = df['split'].value_counts()
    print(f"\nSplit distribution:")
    for split in ['training', 'validation', 'testing']:
        count = split_counts.get(split, 0)
        percentage = (count / len(df)) * 100 if len(df) > 0 else 0
        print(f"  {split.capitalize()}: {count} samples ({percentage:.1f}%)")
else:
    print("⚠️ No split column found - dataset might not be properly split")

# Check class distribution
class_counts = df['is_atypical'].value_counts()
print(f"\nClass distribution:")
print(f"Normal (False): {class_counts.get(False, 0)}")
print(f"Atypical (True): {class_counts.get(True, 0)}")

# Check augmentation status
if 'is_augmented' in df.columns:
    aug_counts = df['is_augmented'].value_counts()
    print(f"\nAugmentation breakdown:")
    print(f"Original: {aug_counts.get(False, 0)}")
    print(f"Augmented: {aug_counts.get(True, 0)}")

# Check augmentation types
if 'augmentation_type' in df.columns:
    aug_types = df['augmentation_type'].value_counts()
    print(f"\nAugmentation types:")
    for aug_type, count in aug_types.items():
        print(f"  {aug_type}: {count}")

# Check dataset sources
if 'dataset' in df.columns:
    dataset_counts = df['dataset'].value_counts()
    print(f"\nDataset sources:")
    for dataset, count in dataset_counts.items():
        print(f"  {dataset}: {count}")

# Show first few rows
print(f"\nFirst 5 rows:")
print(df[['filename', 'is_atypical', 'split', 'is_augmented']].head())

print(f"\n✅ Dataset loaded successfully!")
# Out:
# Loading pre-split dataset from Kaggle...
# Dataset loaded: (19162, 6)
# Columns: ['filename', 'is_atypical', 'dataset', 'split', 'is_augmented', 'augmentation_type']
#
# Dataset Statistics:
# Total samples: 19162
#
# Split distribution:
#   Training: 13586 samples (70.9%)
#   Validation: 2788 samples (14.5%)
#   Testing: 2788 samples (14.5%)
#
# Class distribution:
# Normal (False): 11762
# Atypical (True): 7400
#
# Augmentation breakdown:
# Original: 13938
# Augmented: 5224
#
# Augmentation types:
#   1.0: 1306
#   2.0: 1306
#   3.0: 1306
#   4.0: 1306
#
# Dataset sources:
#   MIDOG25: 16151
#   AMI-BR: 3011
#
# First 5 rows:
#            filename  is_atypical     split  is_augmented
# 0          1371.png        False  training         False
# 1  TUPAC16_2232.png        False  training         False
# 2          3733.png         True  training         False
# 3          9796.png        False  training         False
# 4          5477.png        False  training         False
#
# ✅ Dataset loaded successfully!

# %%
# Prepare the dataset for training using pre-split structure
print("Preparing pre-split dataset for training...")

# Create image paths based on the split information
def get_image_path(row):
    """Get the full image path based on split folder"""
    split_folder = row['split']
    filename = row['filename']
    
    if split_folder == 'training':
        return str(TRAINING_DIR / filename)
    elif split_folder == 'validation':
        return str(VALIDATION_DIR / filename)
    elif split_folder == 'testing':
        return str(TESTING_DIR / filename)
    else:
        # Fallback - try to find the file in any folder
        for folder in [TRAINING_DIR, VALIDATION_DIR, TESTING_DIR]:
            path = folder / filename
            if path.exists():
                return str(path)
        return str(TRAINING_DIR / filename)  # Default fallback

# Add image paths
df['image_path'] = df.apply(get_image_path, axis=1)

# Convert boolean to integer labels (0=Normal, 1=Atypical)
df['label'] = df['is_atypical'].astype(int)

# Verify file existence and filter out missing files
print("Verifying all image files exist...")
existing_files = []
missing_files = []

for idx, row in df.iterrows():
    if Path(row['image_path']).exists():
        existing_files.append(idx)
    else:
        missing_files.append(row['filename'])

if missing_files:
    print(f"⚠️ Warning: {len(missing_files)} files not found")
    if len(missing_files) <= 10:
        print(f"Missing files: {missing_files}")
    else:
        print(f"First 10 missing files: {missing_files[:10]}")

# Keep only existing files
df = df.loc[existing_files].reset_index(drop=True)

print(f"\nFinal dataset info:")
print(f"Total samples: {len(df)}")
print(f"Samples with existing files: {len(existing_files)}")
print(f"Missing files: {len(missing_files)}")

# Display augmentation breakdown if available
if 'is_augmented' in df.columns:
    aug_breakdown = df['is_augmented'].value_counts()
    print(f"\nAugmentation breakdown:")
    print(f"  Original images: {aug_breakdown.get(False, 0)}")
    print(f"  Augmented images: {aug_breakdown.get(True, 0)}")

# Display final class distribution
print(f"\nFinal class distribution:")
class_dist = df['label'].value_counts()
print(f"  Normal (0): {class_dist.get(0, 0)}")
print(f"  Atypical (1): {class_dist.get(1, 0)}")

# Display split distribution
print(f"\nSplit distribution:")
split_dist = df['split'].value_counts()
for split_name, count in split_dist.items():
    percentage = (count / len(df)) * 100
    print(f"  {split_name}: {count} samples ({percentage:.1f}%)")

print(f"\nSample data:")
print(df[['filename', 'label', 'is_atypical', 'split', 'is_augmented']].head())
# Out:
# Preparing pre-split dataset for training...
# Verifying all image files exist...
#
# Final dataset info:
# Total samples: 19162
# Samples with existing files: 19162
# Missing files: 0
#
# Augmentation breakdown:
#   Original images: 13938
#   Augmented images: 5224
#
# Final class distribution:
#   Normal (0): 11762
#   Atypical (1): 7400
#
# Split distribution:
#   training: 13586 samples (70.9%)
#   validation: 2788 samples (14.5%)
#   testing: 2788 samples (14.5%)
#
# Sample data:
#            filename  label  is_atypical     split  is_augmented
# 0          1371.png      0        False  training         False
# 1  TUPAC16_2232.png      0        False  training         False
# 2          3733.png      1         True  training         False
# 3          9796.png      0        False  training         False
# 4          5477.png      0        False  training         False

# %% [markdown]
# ## Data Visualization and Analysis

# %%
# Visualize class distribution of pre-augmented dataset
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Overall class distribution
df['label'].value_counts().plot(kind='bar', ax=axes[0,0], color=['skyblue', 'lightcoral'])
axes[0,0].set_title('Overall Class Distribution (After Augmentation)')
axes[0,0].set_xlabel('Class (0=Normal, 1=Atypical)')
axes[0,0].set_ylabel('Count')
axes[0,0].tick_params(axis='x', rotation=0)

# Original vs Augmented distribution (if available)
if 'is_augmented' in df.columns:
    df['is_augmented'].value_counts().plot(kind='bar', ax=axes[0,1], color=['lightgreen', 'orange'])
    axes[0,1].set_title('Original vs Augmented Images')
    axes[0,1].set_xlabel('Is Augmented')
    axes[0,1].set_ylabel('Count')
    axes[0,1].set_xticklabels(['Original', 'Augmented'], rotation=0)
else:
    axes[0,1].text(0.5, 0.5, 'Augmentation info\nnot available', ha='center', va='center', transform=axes[0,1].transAxes)
    axes[0,1].set_title('Original vs Augmented Images')

# Dataset source distribution (if available)
if 'dataset' in df.columns and len(df['dataset'].unique()) > 1:
    pd.crosstab(df['dataset'], df['label']).plot(kind='bar', ax=axes[1,0], 
                                                              color=['skyblue', 'lightcoral'])
    axes[1,0].set_title('Class Distribution by Dataset Source')
    axes[1,0].set_xlabel('Dataset')
    axes[1,0].set_ylabel('Count')
    axes[1,0].legend(['Normal', 'Atypical'])
    axes[1,0].tick_params(axis='x', rotation=45)
else:
    axes[1,0].text(0.5, 0.5, 'Dataset source info\nnot available', ha='center', va='center', transform=axes[1,0].transAxes)
    axes[1,0].set_title('Class Distribution by Dataset Source')

# Percentage distribution
class_pct = df['label'].value_counts(normalize=True) * 100
class_pct.plot(kind='pie', ax=axes[1,1], autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])
axes[1,1].set_title('Class Distribution (Percentage)')
axes[1,1].set_ylabel('')

plt.tight_layout()
plt.show()

# Print detailed statistics
print("Detailed Statistics:")
print(f"Total samples: {len(df)}")
print(f"Normal samples: {len(df[df['label'] == 0])} ({len(df[df['label'] == 0])/len(df)*100:.1f}%)")
print(f"Atypical samples: {len(df[df['label'] == 1])} ({len(df[df['label'] == 1])/len(df)*100:.1f}%)")

if 'is_augmented' in df.columns:
    print(f"\nAugmentation breakdown:")
    print(f"Original images: {len(df[df['is_augmented'] == False])}")
    print(f"Augmented images: {len(df[df['is_augmented'] == True])}")

if 'dataset' in df.columns:
    print(f"\nBy dataset source:")
    if len(df['dataset'].unique()) > 1:
        print(pd.crosstab(df['dataset'], df['label'], margins=True))
    else:
        print(f"Single dataset source: {df['dataset'].iloc[0]}")

# Show file naming patterns
print(f"\nSample filenames:")
print(df['filename'].head(10).tolist())
# Out:
# Detailed Statistics:
# Total samples: 19162
# Normal samples: 11762 (61.4%)
# Atypical samples: 7400 (38.6%)
#
# Augmentation breakdown:
# Original images: 13938
# Augmented images: 5224
#
# By dataset source:
# label        0     1    All
# dataset
# AMI-BR    1571  1440   3011
# MIDOG25  10191  5960  16151
# All      11762  7400  19162
#
# Sample filenames:
# ['1371.png', 'TUPAC16_2232.png', '3733.png', '9796.png', '5477.png', '11425.png', '1203.png', '7546.png', 'TUPAC16_2410.png', '7783.png']

# %%
# Sample image visualization
def visualize_samples(df, n_samples=8):
    fig, axes = plt.subplots(2, 4, figsize=(16, 8))
    axes = axes.ravel()
    
    # Get samples from each class
    samples = []
    
    # Get normal and atypical samples
    for label in [0, 1]:
        subset = df[df['label'] == label]
        if len(subset) > 0:
            # Try to get mix of original and augmented if available
            if 'is_augmented' in df.columns:
                original_subset = subset[subset['is_augmented'] == False]
                augmented_subset = subset[subset['is_augmented'] == True]
                
                # Get 2 original and 2 augmented if possible
                if len(original_subset) > 0:
                    samples.extend(original_subset.sample(min(2, len(original_subset))).to_dict('records'))
                if len(augmented_subset) > 0:
                    samples.extend(augmented_subset.sample(min(2, len(augmented_subset))).to_dict('records'))
            else:
                # Just get 4 samples of this class
                samples.extend(subset.sample(min(4, len(subset))).to_dict('records'))
    
    for i, sample in enumerate(samples[:8]):
        try:
            img = Image.open(sample['image_path'])
            axes[i].imshow(img)
            
            # Create title with available information
            label_text = 'Atypical' if sample['label'] == 1 else 'Normal'
            title_parts = [label_text]
            
            if 'is_augmented' in sample:
                aug_text = 'Augmented' if sample['is_augmented'] else 'Original'
                title_parts.append(aug_text)
            
            if 'dataset' in sample and sample['dataset'] != 'mixed':
                title_parts.append(sample['dataset'])
            
            title = '\n'.join(title_parts)
            axes[i].set_title(title, fontsize=10)
            axes[i].axis('off')
            
        except Exception as e:
            axes[i].text(0.5, 0.5, f"Error loading\n{sample['filename']}", 
                        ha='center', va='center', transform=axes[i].transAxes)
            axes[i].set_title(f"Error: {sample['filename'][:20]}...")
            axes[i].axis('off')
    
    # Hide unused subplots
    for i in range(len(samples), 8):
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.show()

visualize_samples(df)

# %% [markdown]
# ## Data Preparation for Training

# %%
# Use the pre-split data from your dataset
print("📊 Using pre-split dataset structure...")

# Extract splits based on the 'split' column
train_df = df[df['split'] == 'training'].reset_index(drop=True)
val_df = df[df['split'] == 'validation'].reset_index(drop=True)
test_df = df[df['split'] == 'testing'].reset_index(drop=True)

print(f"📈 Pre-split dataset distribution:")
print(f"Training set: {len(train_df)} samples")
print(f"Validation set: {len(val_df)} samples")
print(f"Test set: {len(test_df)} samples")
print(f"Total: {len(train_df) + len(val_df) + len(test_df)} samples")

# Calculate percentages
total_samples = len(df)
train_pct = len(train_df) / total_samples * 100
val_pct = len(val_df) / total_samples * 100
test_pct = len(test_df) / total_samples * 100

print(f"\n📊 Split percentages:")
print(f"Training: {train_pct:.1f}%")
print(f"Validation: {val_pct:.1f}%")
print(f"Test: {test_pct:.1f}%")

# Check detailed class distribution in each set
print("\n🎯 Class distribution verification:")
for split_name, split_df in [("Train", train_df), ("Val", val_df), ("Test", test_df)]:
    if len(split_df) > 0:
        class_dist = split_df['label'].value_counts()
        class_pct = split_df['label'].value_counts(normalize=True) * 100
        normal_count = class_dist.get(0, 0)
        atypical_count = class_dist.get(1, 0)
        normal_pct = class_pct.get(0, 0)
        atypical_pct = class_pct.get(1, 0)
        print(f"{split_name}: Normal={normal_count} ({normal_pct:.1f}%), "
              f"Atypical={atypical_count} ({atypical_pct:.1f}%)")

# Check augmentation distribution in each split
if 'is_augmented' in df.columns:
    print("\n🔄 Augmentation distribution by split:")
    for split_name, split_df in [("Train", train_df), ("Val", val_df), ("Test", test_df)]:
        if len(split_df) > 0:
            aug_dist = split_df['is_augmented'].value_counts()
            original = aug_dist.get(False, 0)
            augmented = aug_dist.get(True, 0)
            print(f"{split_name}: Original={original}, Augmented={augmented}")

# Verify that we have samples in all splits
if len(train_df) == 0:
    raise ValueError("❌ No training samples found! Check your dataset split column values.")
if len(val_df) == 0:
    raise ValueError("❌ No validation samples found! Check your dataset split column values.")
if len(test_df) == 0:
    raise ValueError("❌ No test samples found! Check your dataset split column values.")

print(f"\n✅ Successfully loaded pre-split dataset!")
print(f"Ready for training with {len(train_df)} training samples")
# Out:
# 📊 Using pre-split dataset structure...
# 📈 Pre-split dataset distribution:
# Training set: 13586 samples
# Validation set: 2788 samples
# Test set: 2788 samples
# Total: 19162 samples
#
# 📊 Split percentages:
# Training: 70.9%
# Validation: 14.5%
# Test: 14.5%
#
# 🎯 Class distribution verification:
# Train: Normal=7056 (51.9%), Atypical=6530 (48.1%)
# Val: Normal=2353 (84.4%), Atypical=435 (15.6%)
# Test: Normal=2353 (84.4%), Atypical=435 (15.6%)
#
# 🔄 Augmentation distribution by split:
# Train: Original=8362, Augmented=5224
# Val: Original=2788, Augmented=0
# Test: Original=2788, Augmented=0
#
# ✅ Successfully loaded pre-split dataset!
# Ready for training with 13586 training samples

# %%
# Define PyTorch Dataset class
class MitosisDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe.reset_index(drop=True)
        self.transform = transform
    
    def __len__(self):
        return len(self.dataframe)
    
    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        
        # Load image
        try:
            image = cv2.imread(row['image_path'])
            if image is None:
                raise ValueError(f"Could not load image: {row['image_path']}")
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        except Exception as e:
            print(f"Error loading {row['image_path']}: {e}")
            # Return a black image as fallback
            image = np.zeros((IMG_SIZE, IMG_SIZE, 3), dtype=np.uint8)
        
        # Apply transforms
        if self.transform:
            transformed = self.transform(image=image)
            image = transformed['image']
        
        label = torch.tensor(row['label'], dtype=torch.long)
        
        return image, label

# Define transforms (reduced augmentation since data is pre-augmented)
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.3),  # Reduced probability since data is pre-augmented
    A.Rotate(limit=15, p=0.3),  # Lighter augmentation
    A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.3),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

# Create datasets
train_dataset = MitosisDataset(train_df, transform=train_transform)
val_dataset = MitosisDataset(val_df, transform=val_transform)
test_dataset = MitosisDataset(test_df, transform=val_transform)

# Calculate class weights for WeightedRandomSampler
print("📊 Calculating sample weights for balanced training...")
class_counts = train_df['label'].value_counts().sort_index()
total_samples = len(train_df)

print(f"Training set class distribution:")
for i, count in enumerate(class_counts):
    class_name = "Normal" if i == 0 else "Atypical"
    percentage = (count / total_samples) * 100
    print(f"  Class {i} ({class_name}): {count} samples ({percentage:.1f}%)")

# Calculate weights for each class (inverse of frequency)
class_weights = []
for i in range(len(class_counts)):
    weight = total_samples / (len(class_counts) * class_counts[i])
    class_weights.append(weight)
    class_name = "Normal" if i == 0 else "Atypical"
    print(f"  Class {i} ({class_name}) weight: {weight:.4f}")

# Create sample weights for each training sample
sample_weights = []
for _, row in train_df.iterrows():
    label = row['label']
    sample_weights.append(class_weights[label])

sample_weights = torch.DoubleTensor(sample_weights)

# Create WeightedRandomSampler
sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True  # Allow replacement to balance classes
)

print(f"\n🎯 WeightedRandomSampler created:")
print(f"  Total samples: {len(sample_weights)}")
print(f"  Unique weights: {len(set(sample_weights.tolist()))}")
print(f"  Weight range: {sample_weights.min():.4f} - {sample_weights.max():.4f}")

# Create data loaders with WeightedRandomSampler for training
num_workers = 2 if torch.cuda.is_available() else 0

# Training loader with WeightedRandomSampler (no shuffle when using sampler)
train_loader = DataLoader(
    train_dataset, 
    batch_size=BATCH_SIZE, 
    sampler=sampler,  # Using WeightedRandomSampler instead of shuffle=True
    num_workers=num_workers, 
    pin_memory=torch.cuda.is_available()
)

# Validation and test loaders remain the same
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, 
                       num_workers=num_workers, pin_memory=torch.cuda.is_available())
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, 
                        num_workers=num_workers, pin_memory=torch.cuda.is_available())

print(f"\n📊 DataLoader Configuration:")
print(f"Training batches: {len(train_loader)} (with WeightedRandomSampler)")
print(f"Validation batches: {len(val_loader)}")
print(f"Test batches: {len(test_loader)}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Num workers: {num_workers}")
print(f"Pin memory: {torch.cuda.is_available()}")

# Verify sampler effectiveness by checking a few batches
print(f"\n🔍 Testing WeightedRandomSampler effectiveness...")
sample_batch_labels = []
for i, (_, labels) in enumerate(train_loader):
    sample_batch_labels.extend(labels.tolist())
    if i >= 4:  # Check first 5 batches
        break

sample_class_dist = pd.Series(sample_batch_labels).value_counts().sort_index()
print(f"Sample from first 5 batches:")
for i, count in enumerate(sample_class_dist):
    class_name = "Normal" if i == 0 else "Atypical"
    percentage = (count / len(sample_batch_labels)) * 100
    print(f"  Class {i} ({class_name}): {count} samples ({percentage:.1f}%)")

print(f"✅ WeightedRandomSampler should provide more balanced batches during training!")
# Out:
# 📊 Calculating sample weights for balanced training...
# Training set class distribution:
#   Class 0 (Normal): 7056 samples (51.9%)
#   Class 1 (Atypical): 6530 samples (48.1%)
#   Class 0 (Normal) weight: 0.9627
#   Class 1 (Atypical) weight: 1.0403
#
# 🎯 WeightedRandomSampler created:
#   Total samples: 13586
#   Unique weights: 2
#   Weight range: 0.9627 - 1.0403
#
# 📊 DataLoader Configuration:
# Training batches: 425 (with WeightedRandomSampler)
# Validation batches: 88
# Test batches: 88
# Batch size: 32
# Num workers: 2
# Pin memory: True
#
# 🔍 Testing WeightedRandomSampler effectiveness...
# Sample from first 5 batches:
#   Class 0 (Normal): 85 samples (53.1%)
#   Class 1 (Atypical): 75 samples (46.9%)
# ✅ WeightedRandomSampler should provide more balanced batches during training!

# %% [markdown]
# ## 🧠 Model Architecture: DenseNet-121 + CCA (Criss-Cross Attention)
#
# ### 🌟 New: CCA Mechanism
#
# **Architecture Overview:**
# - **DenseNet-121**: Pre-trained backbone for feature extraction
# - **CCA Block**: Criss-Cross Attention for long-range contextual modeling
# - **GAP Layer**: Global Average Pooling to reduce spatial dimensions
# - **Custom Classifier**: Dense layers for binary classification
#
# **CCA Benefits:**
# - ✅ **Long-Range Dependencies**: Captures relationships across entire feature map
# - ✅ **Row & Column Attention**: Independent attention along both spatial dimensions
# - ✅ **Efficient Implementation**: Reduced computational complexity compared to full attention
# - ✅ **Contextual Modeling**: Better understanding of spatial context
# - ✅ **Cross-Spatial Relations**: Captures dependencies between distant pixels
# - ✅ **Medical Imaging Optimized**: Ideal for detecting patterns across tissue regions
#
# **Training Strategy:**
# - Full model training (end-to-end)
# - All parameters trainable: backbone + CCA + classifier
# - Focal Loss for class imbalance
# - AdamW optimizer with ReduceLROnPlateau scheduler

# %%
# CCA (Criss-Cross Attention) Block Implementation
import torch
import torch.nn as nn
import torch.nn.functional as F

class CrissCrossAttention(nn.Module):
    """
    Criss-Cross Attention Module for capturing long-range contextual information.
    Applies attention along both row and column directions efficiently.
    """
    def __init__(self, in_channels):
        super(CrissCrossAttention, self).__init__()
        
        self.query_conv = nn.Conv2d(in_channels, in_channels // 8, kernel_size=1)
        self.key_conv   = nn.Conv2d(in_channels, in_channels // 8, kernel_size=1)
        self.value_conv = nn.Conv2d(in_channels, in_channels, kernel_size=1)
        
        self.softmax = nn.Softmax(dim=-1)
        
        print(f"  • CCA input channels: {in_channels}")
        print(f"  • CCA reduced channels: {in_channels // 8}")
        print(f"  • Row and column attention applied independently")

    def forward(self, x):
        B, C, H, W = x.size()

        # Generate Q, K, V maps
        proj_query = self.query_conv(x)       # B, C/8, H, W
        proj_key   = self.key_conv(x)         # B, C/8, H, W
        proj_value = self.value_conv(x)       # B, C,   H, W

        # Flatten along width (W) for row attention and along height (H) for column attention
        query_H = proj_query.permute(0, 3, 1, 2).contiguous().view(B*W, -1, H)
        key_H   = proj_key.permute(0, 3, 1, 2).contiguous().view(B*W, -1, H)
        value_H = proj_value.permute(0, 3, 1, 2).contiguous().view(B*W, -1, H)

        # Row attention
        energy_H = torch.bmm(query_H.transpose(1, 2), key_H)    # (B*W, H, H)
        attn_H = self.softmax(energy_H)
        out_H = torch.bmm(value_H, attn_H.transpose(1, 2))      # (B*W, C, H)
        out_H = out_H.view(B, W, C, H).permute(0, 2, 3, 1)      # B, C, H, W

        # Column attention
        query_W = proj_query.view(B*H, -1, W)
        key_W   = proj_key.view(B*H, -1, W)
        value_W = proj_value.view(B*H, -1, W)

        energy_W = torch.bmm(query_W.transpose(1, 2), key_W)    # (B*H, W, W)
        attn_W = self.softmax(energy_W)
        out_W = torch.bmm(value_W, attn_W.transpose(1, 2))      # (B*H, C, W)
        out_W = out_W.view(B, H, C, W).permute(0, 2, 1, 3)      # B, C, H, W

        # Combine row + column attention
        out = out_H + out_W

        return out

print("✅ CrissCrossAttention class defined")
print("  • Criss-cross attention for long-range contextual modeling")
print("  • Row and column attention applied independently")
print("  • Efficient implementation with reduced channel dimensions")
print("  • Captures spatial dependencies across entire feature maps")
# Out:
# ✅ CrissCrossAttention class defined
#   • Criss-cross attention for long-range contextual modeling
#   • Row and column attention applied independently
#   • Efficient implementation with reduced channel dimensions
#   • Captures spatial dependencies across entire feature maps

# %%
class MitosisClassifier(nn.Module):
    def __init__(self, model_name='densenet121', num_classes=2, pretrained=True):
        super(MitosisClassifier, self).__init__()
        
        print(f"🏗️ Creating {model_name} model with CCA + GAP + Full Model Training...")
        
        # Load DenseNet backbone with automatic pretrained weight download
        if pretrained:
            print(f"📥 Downloading ImageNet pretrained weights for {model_name}...")
            self.backbone = timm.create_model(model_name, pretrained=True)
            print(f"✅ Pretrained weights downloaded and loaded successfully!")
        else:
            print(f"⚠️ Creating model without pretrained weights (random initialization)")
            self.backbone = timm.create_model(model_name, pretrained=False)
        
        # Get the number of features from the backbone before removing classifier
        backbone_features = self.backbone.get_classifier().in_features
        print(f"📊 DenseNet backbone feature dimension: {backbone_features}")
        
        # Remove the original classifier from backbone
        self.backbone.reset_classifier(0)  # 0 means no classifier
        
        # ================================================================================================
        # CCA INTEGRATION: Add Criss-Cross Attention mechanism before classification
        # ================================================================================================
        print(f"\n🔍 Adding CCA (Criss-Cross Attention) block...")
        
        # CCA block (processes channel features with criss-cross attention before classification)
        self.cca = CrissCrossAttention(in_channels=backbone_features)
        
        print(f"✅ CCA block integrated!")
        print(f"   • Channel dimension: {backbone_features}")
        print(f"   • Row and column attention for contextual modeling")
        print(f"   • Long-range spatial dependency capture")
        print(f"   • Focus on cross-spatial relationships")
        
        # ================================================================================================
        # FULL MODEL TRAINING: Enable training for ALL parameters (backbone + CCA + custom layers)
        # ================================================================================================
        print("\n🔓 ENABLING FULL MODEL TRAINING - All parameters trainable!")
        for param in self.backbone.parameters():
            param.requires_grad = True  # Enable gradient computation for ALL backbone parameters
        print("✅ FULL MODEL TRAINING: Entire DenseNet-121 + CCA + Custom Head will be trained")
        
        # Create custom classification head with GAP and decreasing neurons
        # DenseNet-121 typically has 1024 features, so we can build a good head
        # Final layer: 2 neurons with Softmax activation
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),  # Global Average Pooling
            nn.Flatten(),  # Flatten after GAP
            nn.Dropout(0.3),
            nn.Linear(backbone_features, 1024),
            nn.ReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.3),
            
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.3),
            
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.3),
            
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            
            # Final layer: 2 neurons for binary classification
            nn.Linear(128, num_classes),
            nn.Softmax(dim=1)  # Softmax activation for probability output
        )
        
        print(f"\n🎯 Custom classifier head created (CCA + GAP approach):")
        print(f"  Architecture: DenseNet-121 -> CCA -> GAP -> Custom Head")
        print(f"  CCA: Criss-Cross Attention for long-range contextual modeling ⭐")
        print(f"  Global Average Pooling: ✅ (reduces overfitting)")
        print(f"  Final activation: Softmax (probability output)")
        print(f"  Output format: [p(class0), p(class1)] with sum = 1.0")
        print(f"  Training mode: FULL MODEL TRAINING (backbone + CCA + custom head)")
        print(f"  Attention mechanism: CCA for spatial context enhancement!")
        
    def forward(self, x):
        # Extract features using backbone
        features = self.backbone.forward_features(x)  # [B, C, H, W]
        
        # 🔥 Apply criss-cross attention here
        features = self.cca(features)  # [B, C, H, W] with criss-cross attention
        
        # GAP + fully connected classifier
        output = self.classifier(features)
        return output
    
    def predict_proba(self, x):
        """
        Returns the probability distribution (already Softmax activated)
        """
        with torch.no_grad():
            return self.forward(x)
    
    def predict(self, x):
        """
        Returns predicted class (argmax of probabilities)
        """
        with torch.no_grad():
            probs = self.forward(x)
            return torch.argmax(probs, dim=1)

# %%
import timm
import time

# Create DenseNet-121 model instance with CCA
print("🚀 Creating DenseNet-121 model with CCA + GAP + Full Training...")

# Instantiate model with DenseNet-121 and CCA
model = MitosisClassifier(
    model_name='densenet121', 
    num_classes=NUM_CLASSES, 
    pretrained=True  # Will automatically download ImageNet weights
)

# Move model to device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# Calculate parameters
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"\n📊 DENSENET-121 + CCA MODEL SUMMARY:")
print(f"  Total parameters: {total_params:,}")
print(f"  Trainable parameters: {trainable_params:,}")
print(f"  Non-trainable parameters: {total_params - trainable_params:,}")
print(f"  Training mode: FULL MODEL TRAINING (All parameters trainable)")
print(f"  Device: {device}")
print(f"  Model architecture: DenseNet-121 -> CCA -> GAP -> Custom Head")
print(f"  Attention mechanism: Criss-Cross Attention ⭐")

# Detailed architecture inspection
print(f"\n🔍 DETAILED ARCHITECTURE INSPECTION:")
print(f"  📦 Backbone: DenseNet-121 ({sum(p.numel() for p in model.backbone.parameters()):,} parameters)")
print(f"  🔍 CCA Block: {sum(p.numel() for p in model.cca.parameters()):,} parameters")
print(f"  🎯 Custom Head: {sum(p.numel() for p in model.classifier.parameters()):,} parameters")

print(f"\n✅ Model ready for training with CCA attention mechanism!")
print(f"   CCA provides efficient row and column attention with cross-spatial modeling")
# Out:
# 🚀 Creating DenseNet-121 model with CCA + GAP + Full Training...
# 🏗️ Creating densenet121 model with CCA + GAP + Full Model Training...
# 📥 Downloading ImageNet pretrained weights for densenet121...
# model.safetensors:   0%|          | 0.00/32.3M [00:00<?, ?B/s]
# ✅ Pretrained weights downloaded and loaded successfully!
# 📊 DenseNet backbone feature dimension: 1024
#
# 🔍 Adding CCA (Criss-Cross Attention) block...
#   • CCA input channels: 1024
#   • CCA reduced channels: 128
#   • Row and column attention applied independently
# ✅ CCA block integrated!
#    • Channel dimension: 1024
#    • Row and column attention for contextual modeling
#    • Long-range spatial dependency capture
#    • Focus on cross-spatial relationships
#
# 🔓 ENABLING FULL MODEL TRAINING - All parameters trainable!
# ✅ FULL MODEL TRAINING: Entire DenseNet-121 + CCA + Custom Head will be trained
#
# 🎯 Custom classifier head created (CCA + GAP approach):
#   Architecture: DenseNet-121 -> CCA -> GAP -> Custom Head
#   CCA: Criss-Cross Attention for long-range contextual modeling ⭐
#   Global Average Pooling: ✅ (reduces overfitting)
#   Final activation: Softmax (probability output)
#   Output format: [p(class0), p(class1)] with sum = 1.0
#   Training mode: FULL MODEL TRAINING (backbone + CCA + custom head)
#   Attention mechanism: CCA for spatial context enhancement!
#
# 📊 DENSENET-121 + CCA MODEL SUMMARY:
#   Total parameters: 10,008,578
#   Trainable parameters: 10,008,578
#   Non-trainable parameters: 0
#   Training mode: FULL MODEL TRAINING (All parameters trainable)
#   Device: cuda
#   Model architecture: DenseNet-121 -> CCA -> GAP -> Custom Head
#   Attention mechanism: Criss-Cross Attention ⭐
#
# 🔍 DETAILED ARCHITECTURE INSPECTION:
#   📦 Backbone: DenseNet-121 (6,953,856 parameters)
#   🔍 CCA Block: 1,312,000 parameters
#   🎯 Custom Head: 1,742,722 parameters
#
# ✅ Model ready for training with CCA attention mechanism!
#    CCA provides efficient row and column attention with cross-spatial modeling

# %% [markdown]
# ## Model Training

# %%
class FocalLoss(nn.Module):
    """
    Focal Loss implementation for handling class imbalance.
    
    Focal Loss = -alpha * (1-p_t)^gamma * log(p_t)
    
    Args:
        alpha (float): Weighting factor for rare class (default: 1.0)
        gamma (float): Focusing parameter (default: 2.0)
        reduction (str): Specifies reduction to apply to output ('mean', 'sum', 'none')
    """
    
    def __init__(self, alpha=1.0, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        
    def forward(self, inputs, targets):
        """
        Forward pass of Focal Loss
        
        Args:
            inputs: Predictions from model (before softmax) [batch_size, num_classes]
            targets: Ground truth labels [batch_size]
        
        Returns:
            Focal loss value
        """
        # Apply softmax to get probabilities
        ce_loss = nn.functional.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)  # pt = p_t (probability of true class)
        
        # Calculate focal loss: -alpha * (1-pt)^gamma * log(pt)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss
        
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# Calculate class frequencies for Focal Loss alpha parameter
print("📊 Calculating class distribution for Focal Loss configuration...")

class_counts = train_df['label'].value_counts().sort_index()
total_samples = len(train_df)

print(f"Class distribution analysis:")
for i, count in enumerate(class_counts):
    class_name = "Normal" if i == 0 else "Atypical"
    percentage = (count / total_samples) * 100
    print(f"  Class {i} ({class_name}): {count} samples ({percentage:.1f}%)")

# Calculate alpha for focal loss (inverse frequency ratio)
normal_count = class_counts[0]
atypical_count = class_counts[1]
alpha_focal = normal_count / atypical_count  # Higher weight for minority class

print(f"\n🎯 Focal Loss Configuration:")
print(f"  Alpha (class weighting): {alpha_focal:.3f}")
print(f"  Gamma (focusing parameter): 2.0 (standard)")
print(f"  Focus: Higher weight on hard-to-classify samples")
print(f"  Benefit: Addresses both class imbalance and hard examples")

print(f"\n✅ Focal Loss class implemented and configured!")
print(f"  • Handles class imbalance with alpha parameter")
print(f"  • Focuses on hard examples with gamma parameter")
print(f"  • Can work with or without WeightedRandomSampler")
print(f"  • Better than standard CrossEntropyLoss for imbalanced data")
# Out:
# 📊 Calculating class distribution for Focal Loss configuration...
# Class distribution analysis:
#   Class 0 (Normal): 7056 samples (51.9%)
#   Class 1 (Atypical): 6530 samples (48.1%)
#
# 🎯 Focal Loss Configuration:
#   Alpha (class weighting): 1.081
#   Gamma (focusing parameter): 2.0 (standard)
#   Focus: Higher weight on hard-to-classify samples
#   Benefit: Addresses both class imbalance and hard examples
#
# ✅ Focal Loss class implemented and configured!
#   • Handles class imbalance with alpha parameter
#   • Focuses on hard examples with gamma parameter
#   • Can work with or without WeightedRandomSampler
#   • Better than standard CrossEntropyLoss for imbalanced data

# %%
# Training function (optimized for CPU with immediate feedback)
def train_epoch(model, train_loader, criterion, optimizer, device, epoch_num=None):
    import time
    
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    epoch_start = time.time()
    
    print(f"  📊 Starting training with {len(train_loader)} batches...")
    
    for batch_idx, (data, target) in enumerate(train_loader):
        batch_start = time.time()
        
        data, target = data.to(device), target.to(device)
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += target.size(0)
        correct += (predicted == target).sum().item()
        
        current_acc = 100. * correct / total
        batch_time = time.time() - batch_start
        
        # Show progress more frequently for first few batches, then every 10 batches
        show_progress = (
            batch_idx < 5 or  # First 5 batches
            batch_idx % 10 == 0 or  # Every 10th batch
            batch_idx == len(train_loader) - 1  # Last batch
        )
        
        if show_progress:
            elapsed = time.time() - epoch_start
            progress_pct = (batch_idx + 1) / len(train_loader) * 100
            eta = elapsed / (batch_idx + 1) * len(train_loader) - elapsed
            
            print(f'  ⚡ Batch {batch_idx+1:3d}/{len(train_loader)} ({progress_pct:5.1f}%) | '
                  f'Loss: {loss.item():.4f} | Acc: {current_acc:5.2f}% | '
                  f'Time: {batch_time:.2f}s | ETA: {eta/60:.1f}min')
    
    epoch_loss = running_loss / len(train_loader)
    epoch_acc = 100. * correct / total
    total_time = time.time() - epoch_start
    
    print(f'  ✅ Training complete! Total time: {total_time/60:.1f}min, Avg batch: {total_time/len(train_loader):.2f}s')
    
    return epoch_loss, epoch_acc

# Validation function (optimized for CPU with immediate feedback)
def validate_epoch(model, val_loader, criterion, device, epoch_num=None):
    import time
    
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    all_preds = []
    all_targets = []
    epoch_start = time.time()
    
    print(f"  📊 Starting validation with {len(val_loader)} batches...")
    
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(val_loader):
            batch_start = time.time()
            
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            
            running_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            
            all_preds.extend(predicted.cpu().numpy())
            all_targets.extend(target.cpu().numpy())
            
            current_acc = 100. * correct / total
            batch_time = time.time() - batch_start
            
            # Show progress for first few batches and every 5th batch
            show_progress = (
                batch_idx < 3 or  # First 3 batches
                batch_idx % 5 == 0 or  # Every 5th batch
                batch_idx == len(val_loader) - 1  # Last batch
            )
            
            if show_progress:
                elapsed = time.time() - epoch_start
                progress_pct = (batch_idx + 1) / len(val_loader) * 100
                
                print(f'  🔍 Val Batch {batch_idx+1:2d}/{len(val_loader)} ({progress_pct:5.1f}%) | '
                      f'Loss: {loss.item():.4f} | Acc: {current_acc:5.2f}% | '
                      f'Time: {batch_time:.2f}s')
    
    epoch_loss = running_loss / len(val_loader)
    epoch_acc = 100. * correct / total
    total_time = time.time() - epoch_start
    
    print(f'  ✅ Validation complete! Total time: {total_time:.1f}s, Avg batch: {total_time/len(val_loader):.2f}s')
    
    return epoch_loss, epoch_acc, all_preds, all_targets

# %%
# Training loop - Full Model Training with DenseNet-121 + ECA + Focal Loss
print("Setting up Full Model Training with ECA...")
print("="*80)
print("🎯 FULL MODEL TRAINING APPROACH:")
print("  • DenseNet-121 Backbone: Fully trainable")
print("  • ECA: Efficient Channel Attention")
print("  • Custom Classifier: GAP + Dense layers")
print("  • All parameters will be trained end-to-end")
print("="*80)

# Define loss function - Using Focal Loss for better class imbalance handling
criterion = FocalLoss(alpha=alpha_focal, gamma=2.0, reduction='mean')
print(f"\nLoss function: Focal Loss (alpha={alpha_focal:.3f}, gamma=2.0)")
print(f"  • Focal Loss handles class imbalance AND hard examples")
print(f"  • Alpha={alpha_focal:.3f} gives higher weight to minority class")
print(f"  • Gamma=2.0 focuses on hard-to-classify samples")

# Training tracking
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
best_val_loss = float('inf')
best_val_acc = 0.0
patience_counter = 0
patience = 10

# Training parameters for full model training
TOTAL_EPOCHS = 50
LEARNING_RATE = 1e-4  # Lower LR for full model training with pretrained weights

start_time = time.time()
print(f"\n🎯 Starting Full Model Training:")
print(f"  • Model: {model.__class__.__name__} (DenseNet-121 + ECA)")
print(f"  • Total Epochs: {TOTAL_EPOCHS}")  
print(f"  • Learning Rate: {LEARNING_RATE}")
print(f"  • Early Stopping Patience: {patience}")
print(f"  • Architecture: DenseNet-121 -> ECA -> GAP -> Custom Head")
print(f"  • Attention: ECA (Efficient Channel Attention) ⭐")
print(f"  • Training approach: Full model (backbone + attention + classifier)")

# FULL MODEL TRAINING WITH ECA
print(f"\n  ATTENTION MECHANISM DETAILS:")
print(f"  • ECA: Efficient Channel Attention")
print(f"  • Minimal parameters compared to self-attention")
print(f"  • Adaptive kernel size based on channel count")
print(f"  • Focus on inter-channel relationships")
print(f"  • No spatial dimension reduction")

print(f"\n📊 Model Parameter Summary:")
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"  • Total parameters: {total_params:,}")
print(f"  • Trainable parameters: {trainable_params:,}")
print(f"  • Trainable percentage: {trainable_params/total_params*100:.1f}%")
print(f"  • Architecture: DenseNet-121 + ECA + Custom Head")

# Optimizer and Scheduler for full model training
optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)

print(f"\n✅ Training Setup Complete:")
print(f"  Optimizer: AdamW (LR={LEARNING_RATE}, weight_decay=1e-4)")
print(f"  Scheduler: ReduceLROnPlateau (factor=0.5, patience=5)")
print(f"  All model parameters will be trained")

for epoch in range(TOTAL_EPOCHS):
    epoch_start_time = time.time()
    print(f'\n📍 Epoch {epoch+1}/{TOTAL_EPOCHS}')
    print('-' * 50)
    
    # Training phase
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device, epoch+1)
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    
    # Validation phase
    val_loss, val_acc, val_preds, val_targets = validate_epoch(model, val_loader, criterion, device, epoch+1)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)
    
    # Step the scheduler
    scheduler.step(val_loss)
    current_lr = optimizer.param_groups[0]['lr']
    epoch_time = time.time() - epoch_start_time
    
    print(f'\n📊 Epoch {epoch+1} Summary:')
    print(f'  Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%')
    print(f'  Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')
    print(f'  Learning Rate: {current_lr:.6f}')
    print(f'  Epoch Time: {epoch_time:.1f}s')
    
    # Save best model based on validation loss
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_val_acc = val_acc
        patience_counter = 0
        
        # Save checkpoint
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
            'best_val_acc': best_val_acc,
            'train_losses': train_losses,
            'val_losses': val_losses,
            'train_accuracies': train_accuracies,
            'val_accuracies': val_accuracies
        }, 'best_model_densenet121_eca_gap.pth')
        
        print(f'  ✅ Best model saved! Val Loss: {best_val_loss:.4f}, Val Acc: {best_val_acc:.2f}%')
        print(f'  ⭐ ECA providing efficient channel attention!')
    else:
        patience_counter += 1
        print(f'  No improvement. Patience: {patience_counter}/{patience}')
        
        if patience_counter >= patience:
            print(f'\n⏹️  Early stopping triggered after {epoch + 1} epochs')
            print(f'  Best Val Loss: {best_val_loss:.4f}')
            print(f'  Best Val Acc: {best_val_acc:.2f}%')
            break

training_time = time.time() - start_time
print(f"\n{'='*80}")
print(f"✅ TRAINING COMPLETED!")
print(f"{'='*80}")
print(f"  Total training time: {training_time/60:.2f} minutes")
print(f"  Best validation loss: {best_val_loss:.4f}")
print(f"  Best validation accuracy: {best_val_acc:.2f}%")
print(f"  Architecture: DenseNet-121 + ECA + GAP")
print(f"  Attention: Efficient Channel Attention ⭐")
print(f"  Training mode: Full model (backbone + ECA + classifier)")

# Save final results
results_summary = {
    'model': 'DenseNet-121 + ECA',
    'total_epochs': len(train_losses),
    'best_val_loss': best_val_loss,
    'best_val_acc': best_val_acc,
    'train_losses': train_losses,
    'val_losses': val_losses,
    'train_accuracies': train_accuracies,
    'val_accuracies': val_accuracies,
    'training_time_minutes': training_time/60
}

# Load best model for evaluation
print(f"\n📂 Loading best trained model for evaluation...")
checkpoint = torch.load('best_model_densenet121_eca_gap.pth')
model.load_state_dict(checkpoint['model_state_dict'])
print(f"✅ Best model loaded! Val Loss: {checkpoint['best_val_loss']:.4f}, Val Acc: {checkpoint['best_val_acc']:.2f}%")
# Out:
# Setting up Full Model Training with ECA...
# ================================================================================
# 🎯 FULL MODEL TRAINING APPROACH:
#   • DenseNet-121 Backbone: Fully trainable
#   • ECA: Efficient Channel Attention
#   • Custom Classifier: GAP + Dense layers
#   • All parameters will be trained end-to-end
# ================================================================================
#
# Loss function: Focal Loss (alpha=1.081, gamma=2.0)
#   • Focal Loss handles class imbalance AND hard examples
#   • Alpha=1.081 gives higher weight to minority class
#   • Gamma=2.0 focuses on hard-to-classify samples
#
# 🎯 Starting Full Model Training:
#   • Model: MitosisClassifier (DenseNet-121 + ECA)
#   • Total Epochs: 50
#   • Learning Rate: 0.0001
#   • Early Stopping Patience: 10
#   • Architecture: DenseNet-121 -> ECA -> GAP -> Custom Head
#   • Attention: ECA (Efficient Channel Attention) ⭐
#   • Training approach: Full model (backbone + attention + classifier)
#
#   ATTENTION MECHANISM DETAILS:
#   • ECA: Efficient Channel Attention
#   • Minimal parameters compared to self-attention
#   • Adaptive kernel size based on channel count
#   • Focus on inter-channel relationships
#   • No spatial dimension reduction
#
# 📊 Model Parameter Summary:
#   • Total parameters: 10,008,578
#   • Trainable parameters: 10,008,578
#   • Trainable percentage: 100.0%
#   • Architecture: DenseNet-121 + ECA + Custom Head
#
# ✅ Training Setup Complete:
#   Optimizer: AdamW (LR=0.0001, weight_decay=1e-4)
#   Scheduler: ReduceLROnPlateau (factor=0.5, patience=5)
#   All model parameters will be trained
#
# 📍 Epoch 1/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.2257 | Acc: 56.25% | Time: 1.63s | ETA: 14.2min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.2630 | Acc: 45.31% | Time: 0.18s | ETA: 7.7min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.1783 | Acc: 52.08% | Time: 0.18s | ETA: 5.6min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.2048 | Acc: 53.91% | Time: 0.18s | ETA: 4.5min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.2189 | Acc: 53.75% | Time: 0.18s | ETA: 3.8min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.2160 | Acc: 50.57% | Time: 0.18s | ETA: 2.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.1822 | Acc: 53.57% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.1963 | Acc: 54.13% | Time: 0.18s | ETA: 1.6min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.1784 | Acc: 55.18% | Time: 0.18s | ETA: 1.5min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.1694 | Acc: 55.82% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.1801 | Acc: 56.71% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.1803 | Acc: 57.44% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.1783 | Acc: 58.37% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1464 | Acc: 59.31% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.1503 | Acc: 59.62% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.1673 | Acc: 59.97% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.1652 | Acc: 60.33% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.1874 | Acc: 60.33% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.1530 | Acc: 60.57% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.1558 | Acc: 61.01% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.1783 | Acc: 61.35% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.1725 | Acc: 61.49% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.2037 | Acc: 61.76% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.1353 | Acc: 61.89% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.1842 | Acc: 61.99% | Time: 0.19s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.1597 | Acc: 62.04% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.2004 | Acc: 62.05% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.1470 | Acc: 62.28% | Time: 0.19s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.1594 | Acc: 62.54% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.1565 | Acc: 62.72% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.1447 | Acc: 62.90% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.1513 | Acc: 63.07% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.1697 | Acc: 63.31% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.1585 | Acc: 63.50% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.1669 | Acc: 63.82% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.1189 | Acc: 64.08% | Time: 0.19s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.1503 | Acc: 64.33% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.1215 | Acc: 64.53% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.1164 | Acc: 64.70% | Time: 0.19s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.1580 | Acc: 64.87% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.1410 | Acc: 65.03% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.1498 | Acc: 65.25% | Time: 0.19s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.1562 | Acc: 65.50% | Time: 0.19s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.1716 | Acc: 65.69% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.1289 | Acc: 65.91% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.1117 | Acc: 66.05% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.1555 | Acc: 66.17% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1546 | Acc: 66.24% | Time: 0.21s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.1384 | Acc: 78.12% | Time: 0.07s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.1267 | Acc: 79.69% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1442 | Acc: 78.12% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1168 | Acc: 81.25% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.1413 | Acc: 78.98% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1475 | Acc: 77.93% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.1172 | Acc: 78.27% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.1392 | Acc: 78.12% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1310 | Acc: 78.43% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.1109 | Acc: 78.21% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1579 | Acc: 77.13% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1378 | Acc: 76.97% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1586 | Acc: 77.57% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1016 | Acc: 78.12% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1521 | Acc: 77.56% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1470 | Acc: 77.41% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1415 | Acc: 77.55% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1518 | Acc: 77.30% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.1444 | Acc: 77.43% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1291 | Acc: 77.58% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.1002 | Acc: 77.51% | Time: 0.09s
#   ✅ Validation complete! Total time: 12.7s, Avg batch: 0.14s
#
# 📊 Epoch 1 Summary:
#   Train Loss: 0.1677, Train Acc: 66.24%
#   Val Loss: 0.1372, Val Acc: 77.51%
#   Learning Rate: 0.000100
#   Epoch Time: 93.0s
#   ✅ Best model saved! Val Loss: 0.1372, Val Acc: 77.51%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 2/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.1327 | Acc: 84.38% | Time: 0.20s | ETA: 3.5min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.1452 | Acc: 81.25% | Time: 0.19s | ETA: 2.4min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.1486 | Acc: 76.04% | Time: 0.18s | ETA: 2.0min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.1897 | Acc: 72.66% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.1519 | Acc: 71.88% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.1420 | Acc: 73.01% | Time: 0.18s | ETA: 1.5min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.1122 | Acc: 73.21% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.1376 | Acc: 72.48% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.1560 | Acc: 72.18% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.1484 | Acc: 72.67% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.1398 | Acc: 72.54% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.1481 | Acc: 72.93% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0860 | Acc: 73.38% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1272 | Acc: 73.18% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.1130 | Acc: 73.42% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.1763 | Acc: 73.42% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.1394 | Acc: 73.63% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.1379 | Acc: 73.83% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.1341 | Acc: 73.98% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.1297 | Acc: 74.30% | Time: 0.19s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.1175 | Acc: 74.59% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.1365 | Acc: 74.43% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.1602 | Acc: 74.59% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.1405 | Acc: 74.57% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.1330 | Acc: 74.38% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.1093 | Acc: 74.66% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.1104 | Acc: 74.82% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0892 | Acc: 74.85% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.1198 | Acc: 74.88% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.1186 | Acc: 74.94% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.1375 | Acc: 74.83% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.1322 | Acc: 75.06% | Time: 0.19s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.1352 | Acc: 75.29% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.1590 | Acc: 75.29% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0821 | Acc: 75.40% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.1088 | Acc: 75.59% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0871 | Acc: 75.67% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.1505 | Acc: 75.73% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0984 | Acc: 75.91% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.1174 | Acc: 76.04% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0889 | Acc: 76.11% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.1655 | Acc: 76.24% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0741 | Acc: 76.35% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.1754 | Acc: 76.41% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.1271 | Acc: 76.50% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0873 | Acc: 76.60% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.1558 | Acc: 76.67% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1809 | Acc: 76.70% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.1237 | Acc: 78.12% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.1150 | Acc: 76.56% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1391 | Acc: 76.04% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1124 | Acc: 79.69% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.1020 | Acc: 82.39% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1245 | Acc: 82.62% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0980 | Acc: 81.55% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0922 | Acc: 81.25% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1113 | Acc: 81.65% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.1139 | Acc: 80.99% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1238 | Acc: 80.87% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1253 | Acc: 80.50% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1424 | Acc: 80.58% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1050 | Acc: 81.03% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1086 | Acc: 80.79% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1384 | Acc: 81.06% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1363 | Acc: 81.07% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1382 | Acc: 81.13% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.1117 | Acc: 81.10% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1198 | Acc: 81.18% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0658 | Acc: 81.17% | Time: 0.02s
#   ✅ Validation complete! Total time: 5.5s, Avg batch: 0.06s
#
# 📊 Epoch 2 Summary:
#   Train Loss: 0.1336, Train Acc: 76.70%
#   Val Loss: 0.1187, Val Acc: 81.17%
#   Learning Rate: 0.000100
#   Epoch Time: 84.2s
#   ✅ Best model saved! Val Loss: 0.1187, Val Acc: 81.17%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 3/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0974 | Acc: 81.25% | Time: 0.20s | ETA: 3.1min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.1534 | Acc: 79.69% | Time: 0.18s | ETA: 2.2min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.1086 | Acc: 82.29% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.1420 | Acc: 78.91% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.1388 | Acc: 77.50% | Time: 0.18s | ETA: 1.6min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.1308 | Acc: 75.85% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0956 | Acc: 77.53% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0953 | Acc: 79.03% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.1521 | Acc: 78.89% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.1045 | Acc: 78.80% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.1073 | Acc: 79.76% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0955 | Acc: 79.40% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.1610 | Acc: 79.48% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1395 | Acc: 79.05% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.1072 | Acc: 79.08% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0724 | Acc: 79.56% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0709 | Acc: 80.19% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0856 | Acc: 80.34% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.1097 | Acc: 80.43% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0947 | Acc: 80.57% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0973 | Acc: 80.75% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.1228 | Acc: 80.76% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.1071 | Acc: 80.87% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.1817 | Acc: 80.69% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.1208 | Acc: 80.74% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0737 | Acc: 80.64% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0873 | Acc: 80.71% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.1053 | Acc: 80.70% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.1063 | Acc: 80.86% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0944 | Acc: 80.75% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.1489 | Acc: 80.85% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.1129 | Acc: 80.96% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0812 | Acc: 81.02% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.1236 | Acc: 81.00% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0843 | Acc: 81.07% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.1514 | Acc: 81.13% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0734 | Acc: 81.22% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.1341 | Acc: 81.21% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0849 | Acc: 81.27% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0886 | Acc: 81.40% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0987 | Acc: 81.41% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.1571 | Acc: 81.54% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.1161 | Acc: 81.72% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0645 | Acc: 81.76% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0848 | Acc: 81.86% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0799 | Acc: 81.96% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0881 | Acc: 82.04% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1389 | Acc: 82.06% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.1241 | Acc: 84.38% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.1225 | Acc: 81.25% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1385 | Acc: 80.21% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1251 | Acc: 82.81% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0740 | Acc: 83.52% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1002 | Acc: 83.59% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0707 | Acc: 83.93% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.1063 | Acc: 82.81% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1010 | Acc: 83.87% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0877 | Acc: 83.77% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1254 | Acc: 83.69% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1007 | Acc: 83.42% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1203 | Acc: 83.58% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.0799 | Acc: 83.65% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.0928 | Acc: 83.71% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1425 | Acc: 84.00% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1414 | Acc: 83.76% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1038 | Acc: 83.72% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0902 | Acc: 83.87% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1283 | Acc: 83.90% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0717 | Acc: 83.93% | Time: 0.02s
#   ✅ Validation complete! Total time: 5.9s, Avg batch: 0.07s
#
# 📊 Epoch 3 Summary:
#   Train Loss: 0.1117, Train Acc: 82.06%
#   Val Loss: 0.1070, Val Acc: 83.93%
#   Learning Rate: 0.000100
#   Epoch Time: 84.9s
#   ✅ Best model saved! Val Loss: 0.1070, Val Acc: 83.93%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 4/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0901 | Acc: 87.50% | Time: 0.20s | ETA: 3.1min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0966 | Acc: 89.06% | Time: 0.18s | ETA: 2.2min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.1049 | Acc: 89.58% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0948 | Acc: 88.28% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.1025 | Acc: 88.75% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0908 | Acc: 86.08% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0833 | Acc: 86.16% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0663 | Acc: 85.79% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0900 | Acc: 84.53% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0895 | Acc: 84.56% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0654 | Acc: 84.73% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0817 | Acc: 85.04% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0901 | Acc: 84.99% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1150 | Acc: 85.03% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.1129 | Acc: 84.87% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0856 | Acc: 84.99% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0963 | Acc: 85.36% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0995 | Acc: 85.21% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0894 | Acc: 85.42% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.1149 | Acc: 85.43% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0961 | Acc: 85.54% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.1152 | Acc: 85.25% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0862 | Acc: 85.22% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0681 | Acc: 85.27% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0862 | Acc: 85.32% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.1373 | Acc: 85.44% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0826 | Acc: 85.58% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.1385 | Acc: 85.55% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0542 | Acc: 85.72% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.1199 | Acc: 85.84% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0842 | Acc: 85.88% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0546 | Acc: 85.98% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.1113 | Acc: 86.01% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0893 | Acc: 86.10% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0641 | Acc: 86.10% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0836 | Acc: 86.17% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0728 | Acc: 86.27% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.1140 | Acc: 86.31% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.1054 | Acc: 86.47% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0808 | Acc: 86.49% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0704 | Acc: 86.52% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0544 | Acc: 86.49% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0900 | Acc: 86.47% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0525 | Acc: 86.60% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0841 | Acc: 86.60% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0890 | Acc: 86.60% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0548 | Acc: 86.65% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1089 | Acc: 86.60% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.1242 | Acc: 84.38% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0988 | Acc: 84.38% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1073 | Acc: 84.38% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1227 | Acc: 83.85% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0923 | Acc: 85.23% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.0884 | Acc: 83.20% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0574 | Acc: 83.48% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0904 | Acc: 82.69% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1056 | Acc: 83.77% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.1012 | Acc: 83.25% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1549 | Acc: 83.23% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.0837 | Acc: 83.29% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.0949 | Acc: 83.52% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1165 | Acc: 83.48% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1172 | Acc: 83.35% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1113 | Acc: 83.57% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1281 | Acc: 83.32% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1159 | Acc: 83.47% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0865 | Acc: 83.72% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0996 | Acc: 83.58% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0631 | Acc: 83.61% | Time: 0.02s
#   ✅ Validation complete! Total time: 6.1s, Avg batch: 0.07s
#
# 📊 Epoch 4 Summary:
#   Train Loss: 0.0935, Train Acc: 86.60%
#   Val Loss: 0.1058, Val Acc: 83.61%
#   Learning Rate: 0.000100
#   Epoch Time: 84.8s
#   ✅ Best model saved! Val Loss: 0.1058, Val Acc: 83.61%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 5/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.1209 | Acc: 84.38% | Time: 0.22s | ETA: 3.3min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0533 | Acc: 89.06% | Time: 0.18s | ETA: 2.3min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0897 | Acc: 88.54% | Time: 0.18s | ETA: 2.0min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0913 | Acc: 88.28% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.1007 | Acc: 87.50% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0888 | Acc: 88.64% | Time: 0.18s | ETA: 1.5min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0803 | Acc: 87.95% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0582 | Acc: 88.91% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0968 | Acc: 88.95% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0900 | Acc: 88.66% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0628 | Acc: 88.63% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0666 | Acc: 88.69% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0633 | Acc: 88.97% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1139 | Acc: 89.01% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0581 | Acc: 89.33% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0692 | Acc: 89.16% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0836 | Acc: 89.28% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0542 | Acc: 89.50% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0417 | Acc: 89.27% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.1028 | Acc: 89.36% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.1124 | Acc: 89.17% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0595 | Acc: 89.18% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.1020 | Acc: 88.95% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0852 | Acc: 88.87% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0657 | Acc: 88.98% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0621 | Acc: 88.91% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0502 | Acc: 89.06% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0609 | Acc: 89.19% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0955 | Acc: 89.08% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0443 | Acc: 89.06% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0975 | Acc: 89.09% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0627 | Acc: 89.02% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0629 | Acc: 89.06% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0984 | Acc: 89.04% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0855 | Acc: 89.09% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0811 | Acc: 89.19% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.1018 | Acc: 89.16% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0868 | Acc: 89.19% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0941 | Acc: 89.25% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0476 | Acc: 89.31% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0858 | Acc: 89.27% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0316 | Acc: 89.36% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.1160 | Acc: 89.35% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.1015 | Acc: 89.35% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0915 | Acc: 89.44% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0632 | Acc: 89.40% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.1157 | Acc: 89.31% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1228 | Acc: 89.35% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.1152 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0929 | Acc: 89.06% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1145 | Acc: 88.54% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1170 | Acc: 88.02% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0773 | Acc: 87.78% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.0818 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0596 | Acc: 87.05% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0837 | Acc: 86.30% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1325 | Acc: 87.10% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0742 | Acc: 86.46% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1446 | Acc: 86.36% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.0737 | Acc: 86.28% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1035 | Acc: 86.46% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1082 | Acc: 86.61% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.0980 | Acc: 86.48% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1245 | Acc: 86.70% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1275 | Acc: 86.53% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.0891 | Acc: 86.47% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0974 | Acc: 86.65% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1107 | Acc: 86.59% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0613 | Acc: 86.59% | Time: 0.02s
#   ✅ Validation complete! Total time: 5.8s, Avg batch: 0.07s
#
# 📊 Epoch 5 Summary:
#   Train Loss: 0.0811, Train Acc: 89.35%
#   Val Loss: 0.0971, Val Acc: 86.59%
#   Learning Rate: 0.000100
#   Epoch Time: 84.5s
#   ✅ Best model saved! Val Loss: 0.0971, Val Acc: 86.59%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 6/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0952 | Acc: 87.50% | Time: 0.21s | ETA: 3.2min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0818 | Acc: 87.50% | Time: 0.18s | ETA: 2.2min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0622 | Acc: 90.62% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0412 | Acc: 92.97% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.1125 | Acc: 90.00% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0622 | Acc: 91.48% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0421 | Acc: 91.67% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0708 | Acc: 90.42% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0529 | Acc: 90.85% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0865 | Acc: 91.12% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0639 | Acc: 91.19% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0938 | Acc: 90.62% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0353 | Acc: 90.78% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1195 | Acc: 90.66% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0741 | Acc: 90.69% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0634 | Acc: 90.93% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0979 | Acc: 90.91% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0403 | Acc: 90.72% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0604 | Acc: 90.85% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.1042 | Acc: 90.56% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0454 | Acc: 90.57% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0855 | Acc: 90.53% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0485 | Acc: 90.62% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0563 | Acc: 90.64% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0652 | Acc: 90.62% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0393 | Acc: 90.68% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0550 | Acc: 90.68% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0362 | Acc: 90.53% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0813 | Acc: 90.65% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0656 | Acc: 90.64% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0646 | Acc: 90.68% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0905 | Acc: 90.74% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0658 | Acc: 90.80% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0896 | Acc: 90.88% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0369 | Acc: 90.91% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0479 | Acc: 90.90% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0537 | Acc: 90.87% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0349 | Acc: 90.94% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0516 | Acc: 91.02% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.1016 | Acc: 90.91% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0416 | Acc: 90.98% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0385 | Acc: 91.00% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0412 | Acc: 91.00% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0410 | Acc: 91.06% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0712 | Acc: 91.09% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0517 | Acc: 91.13% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0836 | Acc: 91.11% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1772 | Acc: 91.09% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.1322 | Acc: 81.25% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0660 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1153 | Acc: 86.46% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1090 | Acc: 88.02% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0700 | Acc: 90.06% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1023 | Acc: 88.67% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0453 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0944 | Acc: 87.26% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1117 | Acc: 87.70% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0707 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1709 | Acc: 86.66% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.0766 | Acc: 86.82% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1122 | Acc: 86.58% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.0933 | Acc: 86.66% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1178 | Acc: 86.53% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1258 | Acc: 86.55% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1241 | Acc: 86.40% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1105 | Acc: 86.31% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0987 | Acc: 86.42% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0835 | Acc: 86.56% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0757 | Acc: 86.55% | Time: 0.02s
#   ✅ Validation complete! Total time: 5.7s, Avg batch: 0.06s
#
# 📊 Epoch 6 Summary:
#   Train Loss: 0.0733, Train Acc: 91.09%
#   Val Loss: 0.0985, Val Acc: 86.55%
#   Learning Rate: 0.000100
#   Epoch Time: 84.4s
#   No improvement. Patience: 1/10
#
# 📍 Epoch 7/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0477 | Acc: 96.88% | Time: 0.21s | ETA: 3.0min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.1083 | Acc: 89.06% | Time: 0.18s | ETA: 2.1min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0325 | Acc: 92.71% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0687 | Acc: 91.41% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.0745 | Acc: 91.25% | Time: 0.18s | ETA: 1.6min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0667 | Acc: 92.61% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.1257 | Acc: 93.01% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0552 | Acc: 92.64% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0450 | Acc: 92.84% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0944 | Acc: 92.89% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0500 | Acc: 92.88% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0564 | Acc: 92.56% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0731 | Acc: 92.63% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1109 | Acc: 92.38% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0443 | Acc: 92.39% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0522 | Acc: 92.43% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0332 | Acc: 92.54% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0874 | Acc: 92.51% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0585 | Acc: 92.40% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0864 | Acc: 92.49% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0881 | Acc: 92.41% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0696 | Acc: 92.47% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0700 | Acc: 92.63% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0423 | Acc: 92.64% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0967 | Acc: 92.57% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0826 | Acc: 92.45% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0521 | Acc: 92.51% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0523 | Acc: 92.34% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0534 | Acc: 92.40% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0376 | Acc: 92.32% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0557 | Acc: 92.39% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0754 | Acc: 92.37% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0538 | Acc: 92.44% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0658 | Acc: 92.39% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0490 | Acc: 92.44% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0453 | Acc: 92.48% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0584 | Acc: 92.45% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.1075 | Acc: 92.47% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0528 | Acc: 92.49% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0594 | Acc: 92.40% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0714 | Acc: 92.43% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0677 | Acc: 92.43% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0413 | Acc: 92.41% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0474 | Acc: 92.41% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0465 | Acc: 92.49% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0435 | Acc: 92.56% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0534 | Acc: 92.59% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1477 | Acc: 92.52% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0722 | Acc: 93.75% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0771 | Acc: 92.19% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1298 | Acc: 88.54% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1115 | Acc: 89.58% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.1006 | Acc: 90.06% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1025 | Acc: 88.48% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0563 | Acc: 87.20% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0967 | Acc: 86.42% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.0927 | Acc: 87.00% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0915 | Acc: 87.07% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1457 | Acc: 86.59% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.0716 | Acc: 87.09% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.0862 | Acc: 87.13% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.0930 | Acc: 87.17% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1186 | Acc: 87.14% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1050 | Acc: 87.31% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1438 | Acc: 86.93% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1065 | Acc: 86.92% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0821 | Acc: 87.11% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0908 | Acc: 87.28% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0877 | Acc: 87.27% | Time: 0.02s
#   ✅ Validation complete! Total time: 6.3s, Avg batch: 0.07s
#
# 📊 Epoch 7 Summary:
#   Train Loss: 0.0661, Train Acc: 92.52%
#   Val Loss: 0.0949, Val Acc: 87.27%
#   Learning Rate: 0.000100
#   Epoch Time: 85.0s
#   ✅ Best model saved! Val Loss: 0.0949, Val Acc: 87.27%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 8/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0461 | Acc: 93.75% | Time: 0.20s | ETA: 3.1min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0733 | Acc: 90.62% | Time: 0.18s | ETA: 2.2min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0844 | Acc: 90.62% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0553 | Acc: 89.84% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.1332 | Acc: 86.25% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0722 | Acc: 90.62% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0763 | Acc: 92.86% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0569 | Acc: 92.94% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0364 | Acc: 93.14% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0352 | Acc: 92.89% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.1007 | Acc: 92.98% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0357 | Acc: 92.91% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0827 | Acc: 92.71% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.0836 | Acc: 92.93% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0688 | Acc: 92.98% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0623 | Acc: 92.82% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0666 | Acc: 92.90% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0791 | Acc: 92.96% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0520 | Acc: 92.84% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0402 | Acc: 93.13% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0362 | Acc: 93.19% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0541 | Acc: 93.26% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0466 | Acc: 93.32% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0336 | Acc: 93.37% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0314 | Acc: 93.38% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0735 | Acc: 93.44% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0632 | Acc: 93.58% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0343 | Acc: 93.64% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0327 | Acc: 93.56% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0674 | Acc: 93.63% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0789 | Acc: 93.67% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0469 | Acc: 93.67% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0577 | Acc: 93.67% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0894 | Acc: 93.63% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0322 | Acc: 93.55% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0341 | Acc: 93.55% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0275 | Acc: 93.58% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0783 | Acc: 93.58% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0869 | Acc: 93.61% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0928 | Acc: 93.53% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0533 | Acc: 93.59% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0322 | Acc: 93.58% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0738 | Acc: 93.59% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0544 | Acc: 93.59% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0690 | Acc: 93.58% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0554 | Acc: 93.64% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0376 | Acc: 93.71% | Time: 0.18s | ETA: 0.0min
# ...
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0571 | Acc: 99.03% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0264 | Acc: 99.04% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0347 | Acc: 99.02% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0372 | Acc: 98.99% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0475 | Acc: 98.98% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0250 | Acc: 99.02% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0253 | Acc: 99.04% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0246 | Acc: 99.06% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0246 | Acc: 99.04% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0246 | Acc: 99.06% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0424 | Acc: 99.07% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0246 | Acc: 99.07% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0250 | Acc: 99.06% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0247 | Acc: 99.07% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0299 | Acc: 99.06% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0248 | Acc: 99.06% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0302 | Acc: 99.08% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0246 | Acc: 99.08% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0945 | Acc: 84.38% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0710 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1219 | Acc: 86.46% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1166 | Acc: 88.02% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0703 | Acc: 89.20% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1039 | Acc: 87.30% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0929 | Acc: 86.90% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.1156 | Acc: 86.78% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.0746 | Acc: 87.70% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0566 | Acc: 87.41% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1146 | Acc: 87.35% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.0504 | Acc: 88.04% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1039 | Acc: 88.05% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1077 | Acc: 88.23% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1339 | Acc: 88.06% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1189 | Acc: 88.30% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1804 | Acc: 87.90% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.0905 | Acc: 87.75% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.1219 | Acc: 87.92% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1220 | Acc: 87.94% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0250 | Acc: 87.98% | Time: 0.02s
#   ✅ Validation complete! Total time: 5.5s, Avg batch: 0.06s
#
# 📊 Epoch 26 Summary:
#   Train Loss: 0.0301, Train Acc: 99.08%
#   Val Loss: 0.0969, Val Acc: 87.98%
#   Learning Rate: 0.000050
#   Epoch Time: 84.2s
#   No improvement. Patience: 8/10
#
# 📍 Epoch 27/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0257 | Acc: 100.00% | Time: 0.20s | ETA: 2.9min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0326 | Acc: 100.00% | Time: 0.18s | ETA: 2.1min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0280 | Acc: 100.00% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0248 | Acc: 100.00% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.0257 | Acc: 100.00% | Time: 0.18s | ETA: 1.6min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0246 | Acc: 99.15% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0247 | Acc: 99.40% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0248 | Acc: 99.29% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0328 | Acc: 98.93% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0335 | Acc: 99.08% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0246 | Acc: 99.03% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0255 | Acc: 98.99% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0436 | Acc: 99.07% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.0324 | Acc: 99.07% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0477 | Acc: 99.04% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0253 | Acc: 99.10% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0252 | Acc: 99.17% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0247 | Acc: 99.19% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0251 | Acc: 99.16% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0248 | Acc: 99.19% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0246 | Acc: 99.18% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0249 | Acc: 99.20% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0246 | Acc: 99.17% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0246 | Acc: 99.17% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0246 | Acc: 99.19% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0268 | Acc: 99.17% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0247 | Acc: 99.19% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0255 | Acc: 99.22% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0249 | Acc: 99.25% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0248 | Acc: 99.22% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0246 | Acc: 99.22% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0256 | Acc: 99.25% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0253 | Acc: 99.27% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0400 | Acc: 99.28% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0286 | Acc: 99.27% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0252 | Acc: 99.28% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0252 | Acc: 99.27% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0527 | Acc: 99.25% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0247 | Acc: 99.28% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0255 | Acc: 99.29% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0475 | Acc: 99.30% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0258 | Acc: 99.28% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0246 | Acc: 99.29% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0270 | Acc: 99.28% | Time: 0.19s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0247 | Acc: 99.30% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0255 | Acc: 99.31% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0247 | Acc: 99.30% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0246 | Acc: 99.30% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0926 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0682 | Acc: 89.06% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1187 | Acc: 88.54% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.0982 | Acc: 89.06% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0685 | Acc: 89.49% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.0947 | Acc: 88.28% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0965 | Acc: 88.24% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.1390 | Acc: 88.22% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.0892 | Acc: 88.51% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0670 | Acc: 88.19% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1080 | Acc: 88.26% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.0546 | Acc: 88.86% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1370 | Acc: 88.91% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.0903 | Acc: 89.06% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1279 | Acc: 89.04% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1139 | Acc: 89.16% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1539 | Acc: 88.95% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1049 | Acc: 88.69% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.1040 | Acc: 88.81% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1346 | Acc: 88.70% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0246 | Acc: 88.74% | Time: 0.02s
#   ✅ Validation complete! Total time: 5.5s, Avg batch: 0.06s
#
# 📊 Epoch 27 Summary:
#   Train Loss: 0.0291, Train Acc: 99.30%
#   Val Loss: 0.0941, Val Acc: 88.74%
#   Learning Rate: 0.000050
#   Epoch Time: 84.1s
#   No improvement. Patience: 9/10
#
# 📍 Epoch 28/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0255 | Acc: 100.00% | Time: 0.21s | ETA: 3.0min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0247 | Acc: 100.00% | Time: 0.18s | ETA: 2.1min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0246 | Acc: 100.00% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0247 | Acc: 100.00% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.0247 | Acc: 100.00% | Time: 0.18s | ETA: 1.6min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0251 | Acc: 99.72% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0260 | Acc: 99.26% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0246 | Acc: 98.69% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0512 | Acc: 98.78% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0323 | Acc: 98.84% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0247 | Acc: 98.87% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0373 | Acc: 98.77% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0257 | Acc: 98.92% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.0247 | Acc: 98.97% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0452 | Acc: 99.04% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0270 | Acc: 99.10% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0246 | Acc: 99.17% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0247 | Acc: 99.24% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0300 | Acc: 99.25% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0246 | Acc: 99.28% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0486 | Acc: 99.26% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0247 | Acc: 99.31% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0247 | Acc: 99.29% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0246 | Acc: 99.31% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0248 | Acc: 99.33% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0246 | Acc: 99.35% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0319 | Acc: 99.35% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0251 | Acc: 99.36% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0248 | Acc: 99.35% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0245 | Acc: 99.32% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0276 | Acc: 99.28% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0246 | Acc: 99.30% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0246 | Acc: 99.32% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0248 | Acc: 99.32% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0246 | Acc: 99.29% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0247 | Acc: 99.28% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0287 | Acc: 99.27% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0261 | Acc: 99.27% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0245 | Acc: 99.28% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0248 | Acc: 99.28% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0467 | Acc: 99.27% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0304 | Acc: 99.26% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0247 | Acc: 99.27% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0332 | Acc: 99.26% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0246 | Acc: 99.24% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0247 | Acc: 99.25% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0248 | Acc: 99.24% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1054 | Acc: 99.23% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0600 | Acc: 96.88% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0661 | Acc: 93.75% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1243 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1167 | Acc: 90.10% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0667 | Acc: 90.34% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.0949 | Acc: 89.26% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0793 | Acc: 89.14% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0949 | Acc: 89.30% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.0854 | Acc: 89.62% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0798 | Acc: 89.06% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.0930 | Acc: 88.80% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.0653 | Acc: 89.13% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1319 | Acc: 89.22% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1369 | Acc: 89.29% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1505 | Acc: 89.14% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1242 | Acc: 89.25% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1413 | Acc: 89.08% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1216 | Acc: 88.65% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.1270 | Acc: 88.70% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1203 | Acc: 88.63% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0344 | Acc: 88.70% | Time: 0.02s
#   ✅ Validation complete! Total time: 5.5s, Avg batch: 0.06s
#
# 📊 Epoch 28 Summary:
#   Train Loss: 0.0293, Train Acc: 99.23%
#   Val Loss: 0.0937, Val Acc: 88.70%
#   Learning Rate: 0.000050
#   Epoch Time: 84.2s
#   No improvement. Patience: 10/10
#
# ⏹️  Early stopping triggered after 28 epochs
#   Best Val Loss: 0.0889
#   Best Val Acc: 88.95%
#
# ================================================================================
# ✅ TRAINING COMPLETED!
# ================================================================================
#   Total training time: 39.58 minutes
#   Best validation loss: 0.0889
#   Best validation accuracy: 88.95%
#   Architecture: DenseNet-121 + ECA + GAP
#   Attention: Efficient Channel Attention ⭐
#   Training mode: Full model (backbone + ECA + classifier)
#
# 📂 Loading best trained model for evaluation...
# ✅ Best model loaded! Val Loss: 0.0889, Val Acc: 88.95%

# %% [markdown]
# ## Training Visualization

# %%
# Plot training history
def plot_training_history(train_losses, val_losses, train_accuracies, val_accuracies):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    epochs = range(1, len(train_losses) + 1)
    
    # Plot loss
    ax1.plot(epochs, train_losses, 'b-', label='Training Loss')
    ax1.plot(epochs, val_losses, 'r-', label='Validation Loss')
    ax1.set_title('Model Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Plot accuracy
    ax2.plot(epochs, train_accuracies, 'b-', label='Training Accuracy')
    ax2.plot(epochs, val_accuracies, 'r-', label='Validation Accuracy')
    ax2.set_title('Model Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy (%)')
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# Plot the training history
plot_training_history(train_losses, val_losses, train_accuracies, val_accuracies)

# %% [markdown]
# ## Model Evaluation

# %%
# Load best model
model.load_state_dict(torch.load('best_model_densenet121_eca_gap.pth')['model_state_dict'])
model.eval()

# Evaluate on test set
print("Evaluating DenseNet-121 model on test set...")
print("📊 Model specifications:")
print("  • Model: MitosisClassifier")
print("  • Backbone: DenseNet-121")
print("  • Output: 2 neurons with SoftMax activation")
print("  • Loss function: FocalLoss()")
print("  • Device: cuda")
print("  • Classification head: 1024 -> 1024 -> 512 -> 256 -> 128 -> 2")
print("  • Output layer: 2 neurons with Softmax activation")
print("  • Output format: Two probabilities [p(class0), p(class1)], use argmax for prediction")

test_running_loss = 0.0
test_correct = 0
test_total = 0
all_test_preds = []
all_test_targets = []
all_test_probs = []

with torch.no_grad():
    for batch_idx, (data, target) in enumerate(test_loader):
        data, target = data.to(device), target.to(device)
        output = model(data)  # Softmax probabilities
        loss = criterion(output, target)  # FocalLoss
        
        test_running_loss += loss.item()
        _, predicted = torch.max(output.data, 1)  # argmax for prediction
        test_total += target.size(0)
        test_correct += (predicted == target).sum().item()
        
        all_test_preds.extend(predicted.cpu().numpy())
        all_test_targets.extend(target.cpu().numpy())
        all_test_probs.extend(output.cpu().numpy())
        
        if batch_idx % 10 == 0:
            current_acc = 100. * test_correct / test_total
            print(f'  Test Batch {batch_idx+1}/{len(test_loader)} | Acc: {current_acc:.2f}%')

test_loss = test_running_loss / len(test_loader)
test_acc = 100. * test_correct / test_total

print(f"\n📈 Test Results (DenseNet-121 Full Model Training):")
print(f"  Test Loss: {test_loss:.4f}")
print(f"  Test Accuracy: {test_acc:.2f}%")
print(f"  Total test samples: {test_total}")
print(f"  Correct predictions: {test_correct}")

# Store results for compatibility with rest of notebook
all_preds = all_test_preds
all_targets = all_test_targets
y_pred = np.array(all_test_preds)
y_true = np.array(all_test_targets)
y_probs = np.array(all_test_probs)
print(f"  Total test samples: {test_total}")
print(f"  Correct predictions: {test_correct}")

# Store results for compatibility with rest of notebook
all_preds = all_test_preds
all_targets = all_test_targets
# Out:
# Evaluating DenseNet-121 model on test set...
# 📊 Model specifications:
#   • Model: MitosisClassifier
#   • Backbone: DenseNet-121
#   • Output: 2 neurons with SoftMax activation
#   • Loss function: FocalLoss()
#   • Device: cuda
#   • Classification head: 1024 -> 1024 -> 512 -> 256 -> 128 -> 2
#   • Output layer: 2 neurons with Softmax activation
#   • Output format: Two probabilities [p(class0), p(class1)], use argmax for prediction
#   Test Batch 1/88 | Acc: 93.75%
#   Test Batch 11/88 | Acc: 86.08%
#   Test Batch 21/88 | Acc: 86.76%
#   Test Batch 31/88 | Acc: 87.70%
#   Test Batch 41/88 | Acc: 87.96%
#   Test Batch 51/88 | Acc: 88.11%
#   Test Batch 61/88 | Acc: 88.37%
#   Test Batch 71/88 | Acc: 88.69%
#   Test Batch 81/88 | Acc: 88.58%
#
# 📈 Test Results (DenseNet-121 Full Model Training):
#   Test Loss: 0.0881
#   Test Accuracy: 88.88%
#   Total test samples: 2788
#   Correct predictions: 2478
#   Total test samples: 2788
#   Correct predictions: 2478

# %%
# Analyze performance by different factors
test_df_with_predictions = test_df.copy().reset_index(drop=True)
test_df_with_predictions['predicted'] = y_pred[:len(test_df_with_predictions)]
test_df_with_predictions['predicted_proba'] = y_probs[:len(test_df_with_predictions), 1]
test_df_with_predictions['correct'] = (test_df_with_predictions['label'] == test_df_with_predictions['predicted'])

print("Performance Analysis:")

# Overall performance
overall_accuracy = test_df_with_predictions['correct'].mean()
print(f"Overall Test Accuracy: {overall_accuracy:.4f} ({len(test_df_with_predictions)} samples)")

# Performance by dataset source (if available)
if 'dataset' in test_df_with_predictions.columns and len(test_df_with_predictions['dataset'].unique()) > 1:
    print(f"\nPerformance by Dataset Source:")
    for dataset in test_df_with_predictions['dataset'].unique():
        if pd.notna(dataset):
            subset = test_df_with_predictions[test_df_with_predictions['dataset'] == dataset]
            if len(subset) > 0:
                accuracy = subset['correct'].mean()
                print(f"  {dataset}: {accuracy:.4f} accuracy ({len(subset)} samples)")

# Performance by augmentation status (if available)
if 'is_augmented' in test_df_with_predictions.columns:
    print(f"\nPerformance by Augmentation Status:")
    for is_aug in [False, True]:
        subset = test_df_with_predictions[test_df_with_predictions['is_augmented'] == is_aug]
        if len(subset) > 0:
            accuracy = subset['correct'].mean()
            status = "Augmented" if is_aug else "Original"
            print(f"  {status}: {accuracy:.4f} accuracy ({len(subset)} samples)")

# Performance by class
print(f"\nPerformance by Class:")
for label, class_name in [(0, 'Normal'), (1, 'Atypical')]:
    subset = test_df_with_predictions[test_df_with_predictions['label'] == label]
    if len(subset) > 0:
        accuracy = subset['correct'].mean()
        print(f"  {class_name}: {accuracy:.4f} accuracy ({len(subset)} samples)")

# Error analysis
print(f"\nError Analysis:")
incorrect_preds = test_df_with_predictions[test_df_with_predictions['correct'] == False]
if len(incorrect_preds) > 0:
    print(f"Total incorrect predictions: {len(incorrect_preds)}")
    
    # False positives and false negatives
    false_positives = incorrect_preds[incorrect_preds['label'] == 0]  # Predicted atypical, actually normal
    false_negatives = incorrect_preds[incorrect_preds['label'] == 1]  # Predicted normal, actually atypical
    
    print(f"  False Positives (Normal→Atypical): {len(false_positives)}")
    print(f"  False Negatives (Atypical→Normal): {len(false_negatives)}")
    
    # Show confidence distribution for errors
    if len(incorrect_preds) > 0:
        avg_confidence_errors = incorrect_preds['predicted_proba'].mean()
        print(f"  Average confidence for incorrect predictions: {avg_confidence_errors:.3f}")
else:
    print("No incorrect predictions!")

# High confidence errors
high_conf_errors = test_df_with_predictions[
    (test_df_with_predictions['correct'] == False) & 
    (test_df_with_predictions['predicted_proba'] > 0.8)
]
if len(high_conf_errors) > 0:
    print(f"\nHigh-confidence errors (>0.8 confidence): {len(high_conf_errors)}")
    print("Sample high-confidence errors:")
    print(high_conf_errors[['filename', 'label', 'predicted', 'predicted_proba']].head())
# Out:
# Performance Analysis:
# Overall Test Accuracy: 0.8888 (2788 samples)
#
# Performance by Dataset Source:
#   MIDOG25: 0.8955 accuracy (2402 samples)
#   AMI-BR: 0.8472 accuracy (386 samples)
#
# Performance by Augmentation Status:
#   Original: 0.8888 accuracy (2788 samples)
#
# Performance by Class:
#   Normal: 0.9469 accuracy (2353 samples)
#   Atypical: 0.5747 accuracy (435 samples)
#
# Error Analysis:
# Total incorrect predictions: 310
#   False Positives (Normal→Atypical): 125
#   False Negatives (Atypical→Normal): 185
#   Average confidence for incorrect predictions: 0.440
#
# High-confidence errors (>0.8 confidence): 74
# Sample high-confidence errors:
#               filename  label  predicted  predicted_proba
# 153          11400.png      0          1         0.999254
# 157           9542.png      0          1         0.924235
# 185  TUPAC16_10594.png      0          1         0.975667
# 202           3717.png      0          1         0.993312
# 213   TUPAC16_2357.png      0          1         0.881504

# %%
# Visualize some predictions
def visualize_predictions(df_with_pred, n_samples=12):
    fig, axes = plt.subplots(3, 4, figsize=(16, 12))
    axes = axes.ravel()
    
    # Get some correct and incorrect predictions
    correct_pred = df_with_pred[df_with_pred['correct'] == True]
    incorrect_pred = df_with_pred[df_with_pred['correct'] == False]
    
    if len(correct_pred) > 0:
        correct_sample = correct_pred.sample(min(6, len(correct_pred)))
    else:
        correct_sample = pd.DataFrame()
    
    if len(incorrect_pred) > 0:
        incorrect_sample = incorrect_pred.sample(min(6, len(incorrect_pred)))
    else:
        incorrect_sample = pd.DataFrame()
    
    samples = pd.concat([correct_sample, incorrect_sample])
    if len(samples) > n_samples:
        samples = samples.sample(n_samples)
    
    for i, (_, row) in enumerate(samples.iterrows()):
        if i >= n_samples:
            break
            
        try:
            img = Image.open(row['image_path'])
            axes[i].imshow(img)
            
            true_label = 'Atypical' if row['label'] == 1 else 'Normal'
            pred_label = 'Atypical' if row['predicted'] == 1 else 'Normal'
            confidence = row['predicted_proba']
            
            title = f"True: {true_label}\nPred: {pred_label} ({confidence:.3f})\n{row['dataset']}"
            color = 'green' if row['correct'] else 'red'
            axes[i].set_title(title, color=color, fontsize=10)
            axes[i].axis('off')
        except Exception as e:
            axes[i].text(0.5, 0.5, f"Error loading\n{row['filename']}", 
                        ha='center', va='center', transform=axes[i].transAxes)
            axes[i].axis('off')
    
    # Hide unused subplots
    for i in range(len(samples), n_samples):
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.show()

visualize_predictions(test_df_with_predictions)

# %% [markdown]
# ## Model Saving and Summary

# %%
# Save model as the best model for future use
torch.save({
    'model_state_dict': model.state_dict(),
    'best_val_loss': best_val_loss,
    'best_val_acc': best_val_acc,
    'epoch': len(train_losses),
    'class_names': ['Normal', 'Atypical']
}, 'mitotic_figure_densenet121_cca_gap_classifier.pth')

print("Model saved as 'mitotic_figure_densenet121_cca_gap_classifier.pth'")

# Calculate metrics
from sklearn.metrics import precision_score, recall_score, f1_score

test_precision = precision_score(y_true, y_pred, average='weighted')
test_recall = recall_score(y_true, y_pred, average='weighted')
test_f1 = f1_score(y_true, y_pred, average='weighted')

# Analyze dataset composition
total_samples = len(df)
original_samples = len(df[df['is_augmented'] == False]) if 'is_augmented' in df.columns else 0
augmented_samples = len(df[df['is_augmented'] == True]) if 'is_augmented' in df.columns else 0

# Save model summary and results
results_summary = {
    'model_architecture': 'DenseNet-121 + CCA + GAP + Custom Head (PyTorch)',
    'framework': 'PyTorch',
    'backbone_model': 'DenseNet-121',
    'attention_mechanism': 'CCA (Criss-Cross Attention)',
    'pretrained_weights': 'ImageNet (automatically downloaded)',
    'training_approach': 'Full model training with CCA + Global Average Pooling + Focal Loss',
    'class_balancing': 'Focal Loss + WeightedRandomSampler (advanced strategy)',
    'learning_rate': float(LEARNING_RATE),
    'output_format': '2 neurons with Softmax activation',
    'loss_function': 'Focal Loss',
    'focal_alpha': float(alpha_focal),
    'focal_gamma': 2.0,
    'prediction_method': 'argmax of [p(class0), p(class1)]',
    'dataset_source': 'Pre-augmented Kaggle dataset',
    'total_samples': int(total_samples),
    'original_samples': int(original_samples),
    'augmented_samples': int(augmented_samples),
    'train_samples': len(train_df),
    'val_samples': len(val_df),
    'test_samples': len(test_df),
    'test_accuracy': float(test_acc / 100),  # Convert from percentage
    'test_precision': float(test_precision),
    'test_recall': float(test_recall),
    'test_f1': float(test_f1),
    # 'auc_score': float(auc_score),
    'best_val_accuracy': float(best_val_acc / 100),  # Convert from percentage
    'best_val_loss': float(best_val_loss),
    'early_stopping_metric': 'validation_loss',
    'early_stopping_patience': 10,
    'class_distribution': df['label'].value_counts().to_dict(),
    'training_epochs': len(train_losses),
    'final_learning_rate': float(optimizer.param_groups[0]['lr']),
    'used_augmented_data': augmented_samples > 0,
    'trainable_parameters': int(trainable_params),
    'total_parameters': int(total_params),
    'trainable_percentage': float(trainable_params/total_params*100),
    'gap_layer': True,
    'frozen_backbone': False,  # Full model training
    'cca_attention': True,
    'dense_connectivity': True,
    'advanced_loss': True
}

print("\n" + "="*90)
print("FINAL RESULTS SUMMARY - MITOTIC FIGURE CLASSIFICATION (DENSENET-121 + CCA)")
print("="*90)
print(f"Model Architecture: {results_summary['model_architecture']}")
print(f"Backbone Model: {results_summary['backbone_model']}")
print(f"Framework: {results_summary['framework']}")
print(f"Attention Mechanism: {results_summary['attention_mechanism']}")
print(f"Pretrained Weights: {results_summary['pretrained_weights']}")
print(f"Training Approach: {results_summary['training_approach']}")
print(f"Class Balancing: {results_summary['class_balancing']}")
print(f"Output Format: {results_summary['output_format']}")
print(f"Loss Function: {results_summary['loss_function']} (alpha={results_summary['focal_alpha']:.3f}, gamma={results_summary['focal_gamma']})")
print(f"Prediction Method: {results_summary['prediction_method']}")
print(f"Dataset Source: {results_summary['dataset_source']}")

print(f"\nArchitecture Details:")
print(f"  Backbone: DenseNet-121 (fully trainable 🔓)")
print(f"  Attention: ECA (Efficient Channel Attention) ⭐")
print(f"  Dense Connectivity: ✅ (feature reuse & gradient flow)")
print(f"  GAP Layer: Global Average Pooling")
print(f"  Custom Head: 1024 -> 512 -> 256 -> 128 -> 2")
print(f"  Learning Rate: {results_summary['learning_rate']}")
print(f"  Final Learning Rate: {results_summary['final_learning_rate']:.2e}")
print(f"  Pretrained: ImageNet weights (automatic download)")

print(f"\nDataset Composition:")
print(f"  Total Samples: {results_summary['total_samples']:,}")
print(f"  Training Samples: {results_summary['train_samples']:,}")
print(f"  Validation Samples: {results_summary['val_samples']:,}")
print(f"  Test Samples: {results_summary['test_samples']:,}")
if results_summary['used_augmented_data']:
    print(f"  Original Samples: {results_summary['original_samples']:,}")
    print(f"  Augmented Samples: {results_summary['augmented_samples']:,}")
    augmentation_ratio = results_summary['augmented_samples'] / results_summary['original_samples']
    print(f"  Augmentation Ratio: {augmentation_ratio:.1f}x")

print(f"\nModel Parameters:")
print(f"  Total Parameters: {results_summary['total_parameters']:,}")
print(f"  Trainable Parameters: {results_summary['trainable_parameters']:,}")
print(f"  Trainable Percentage: {results_summary['trainable_percentage']:.1f}%")

print(f"\nTraining Performance:")
print(f"  Training Epochs: {results_summary['training_epochs']}")
print(f"  Best Validation Loss: {results_summary['best_val_loss']:.4f}")
print(f"  Best Validation Accuracy: {results_summary['best_val_accuracy']:.4f}")

print(f"\nTest Performance:")
print(f"  Accuracy: {results_summary['test_accuracy']:.4f}")
print(f"  Precision: {results_summary['test_precision']:.4f}")
print(f"  Recall: {results_summary['test_recall']:.4f}")
print(f"  F1-Score: {results_summary['test_f1']:.4f}")
# print(f"  AUC Score: {results_summary['auc_score']:.4f}")

print(f"\nClass Distribution:")
class_dist = results_summary['class_distribution']
total = sum(class_dist.values())
for label, count in class_dist.items():
    class_name = "Atypical" if label == 1 else "Normal"
    percentage = (count / total) * 100
    print(f"  {class_name}: {count} samples ({percentage:.1f}%)")

print(f"\n🎯 DENSENET-121 + ECA TRAINING HIGHLIGHTS:")
print(f"  • Training Mode: Full model training ({results_summary['trainable_percentage']:.1f}% parameters)")
print(f"  • Backbone: DenseNet-121 (fully trainable) - Dense feature connections")
print(f"  • Attention: ECA (Efficient Channel Attention) ⭐")
print(f"  • Global Average Pooling: ✅ (reduces overfitting)")
print(f"  • Advanced Loss: Focal Loss (α={results_summary['focal_alpha']:.3f}, γ={results_summary['focal_gamma']})")
print(f"  • Dense Connectivity: Feature reuse & improved gradient flow")
print(f"  • Class Balancing: Focal Loss + WeightedRandomSampler (double protection)")
print(f"  • Hard Example Focus: Focal Loss emphasizes difficult samples")
print(f"  • Early Stopping: Based on validation loss (patience=10)")
print(f"  • Best Val Loss: {results_summary['best_val_loss']:.4f}")
print(f"  • Final Layer: {NUM_CLASSES} neurons with Softmax")
print(f"  • Output: [p(class0), p(class1)] with argmax prediction")
print(f"  • Automatic Downloads: ImageNet pretrained weights")

print("="*90)

# Save results to JSON
with open('densenet121_eca_gap_training_results.json', 'w') as f:
    json.dump(results_summary, f, indent=2)

print("\nResults saved to 'densenet121_eca_gap_training_results.json'")
print("DenseNet-121 + ECA + GAP model training completed successfully!")

# Final model performance summary
print(f"\n🎯 KEY PERFORMANCE METRICS (DENSENET-121 + ECA):")
print(f"  • Test Accuracy: {results_summary['test_accuracy']:.1%}")
# print(f"  • AUC Score: {results_summary['auc_score']:.3f}")
print(f"  • F1 Score: {results_summary['test_f1']:.3f}")
print(f"  • Architecture: DenseNet-121 + ECA + GAP + Custom Head")
print(f"  • Attention: ECA (Efficient Channel Attention)")
print(f"  • Loss Function: Focal Loss (advanced class imbalance handling)")
print(f"  • Training: Full model training (end-to-end)")
print(f"  • Dense Connectivity: Enhanced feature reuse")
print(f"  • Advanced Strategy: Focal Loss + WeightedRandomSampler + CCA")
if results_summary['used_augmented_data']:
    print(f"  • Benefited from {augmentation_ratio:.1f}x data augmentation")
print(f"  • DenseNet-121 + CCA model ready for deployment! 🚀")
# Out:
# Model saved as 'mitotic_figure_densenet121_cca_gap_classifier.pth'
#
# ==========================================================================================
# FINAL RESULTS SUMMARY - MITOTIC FIGURE CLASSIFICATION (DENSENET-121 + CCA)
# ==========================================================================================
# Model Architecture: DenseNet-121 + CCA + GAP + Custom Head (PyTorch)
# Backbone Model: DenseNet-121
# Framework: PyTorch
# Attention Mechanism: CCA (Criss-Cross Attention)
# Pretrained Weights: ImageNet (automatically downloaded)
# Training Approach: Full model training with CCA + Global Average Pooling + Focal Loss
# Class Balancing: Focal Loss + WeightedRandomSampler (advanced strategy)
# Output Format: 2 neurons with Softmax activation
# Loss Function: Focal Loss (alpha=1.081, gamma=2.0)
# Prediction Method: argmax of [p(class0), p(class1)]
# Dataset Source: Pre-augmented Kaggle dataset
#
# Architecture Details:
#   Backbone: DenseNet-121 (fully trainable 🔓)
#   Attention: ECA (Efficient Channel Attention) ⭐
#   Dense Connectivity: ✅ (feature reuse & gradient flow)
#   GAP Layer: Global Average Pooling
#   Custom Head: 1024 -> 512 -> 256 -> 128 -> 2
#   Learning Rate: 0.0001
#   Final Learning Rate: 5.00e-05
#   Pretrained: ImageNet weights (automatic download)
#
# Dataset Composition:
#   Total Samples: 19,162
#   Training Samples: 13,586
#   Validation Samples: 2,788
#   Test Samples: 2,788
#   Original Samples: 13,938
#   Augmented Samples: 5,224
#   Augmentation Ratio: 0.4x
#
# Model Parameters:
#   Total Parameters: 10,008,578
#   Trainable Parameters: 10,008,578
#   Trainable Percentage: 100.0%
#
# Training Performance:
#   Training Epochs: 28
#   Best Validation Loss: 0.0889
#   Best Validation Accuracy: 0.8895
#
# Test Performance:
#   Accuracy: 0.8888
#   Precision: 0.8833
#   Recall: 0.8888
#   F1-Score: 0.8854
#
# Class Distribution:
#   Normal: 11762 samples (61.4%)
#   Atypical: 7400 samples (38.6%)
#
# 🎯 DENSENET-121 + ECA TRAINING HIGHLIGHTS:
#   • Training Mode: Full model training (100.0% parameters)
#   • Backbone: DenseNet-121 (fully trainable) - Dense feature connections
#   • Attention: ECA (Efficient Channel Attention) ⭐
#   • Global Average Pooling: ✅ (reduces overfitting)
#   • Advanced Loss: Focal Loss (α=1.081, γ=2.0)
#   • Dense Connectivity: Feature reuse & improved gradient flow
#   • Class Balancing: Focal Loss + WeightedRandomSampler (double protection)
#   • Hard Example Focus: Focal Loss emphasizes difficult samples
#   • Early Stopping: Based on validation loss (patience=10)
#   • Best Val Loss: 0.0889
#   • Final Layer: 2 neurons with Softmax
#   • Output: [p(class0), p(class1)] with argmax prediction
#   • Automatic Downloads: ImageNet pretrained weights
# ==========================================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_39/2011547948.py in <cell line: 0>()
#     147 # Save results to JSON
#     148 with open('densenet121_eca_gap_training_results.json', 'w') as f:
# --> 149     json.dump(results_summary, f, indent=2)
#     150
#     151 print("\nResults saved to 'densenet121_eca_gap_training_results.json'")
#
# NameError: name 'json' is not defined

# %% [markdown]
# ## 📊 Detailed Model Evaluation - Confusion Matrix & ROC Curve
#
# Now let's generate comprehensive evaluation metrics including:
# - **Confusion Matrix**: Shows the breakdown of correct and incorrect predictions
# - **ROC Curve & AUC**: Shows the model's ability to distinguish between classes
# - **Precision-Recall Curve**: Shows precision vs recall trade-off
# - **Sample Predictions**: Visual validation with confidence scores

# %%
import numpy as np
import torch
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns

# Load the best DenseNet-121 + CCA model
print("📂 Loading best trained DenseNet-121 + CCA model...")
try:
    checkpoint = torch.load('best_model_densenet121_cca_gap.pth')
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"✅ Best CCA model loaded! Best Val Loss: {checkpoint.get('best_val_loss', 'N/A'):.4f}")
    print(f"✅ Best CCA model loaded! Best Val Acc: {checkpoint.get('best_val_acc', 'N/A'):.2f}%")
except FileNotFoundError:
    print("⚠️ Best model file not found, using current model state")

model.eval()

# Generate predictions
all_predictions = []
all_probabilities = []
all_targets = []
all_predicted_probs = []

with torch.no_grad():
    for data, target in val_loader:
        data, target = data.to(device), target.to(device)
        outputs = model(data)
        probabilities = torch.softmax(outputs, dim=1)
        predictions = torch.argmax(probabilities, dim=1)

        all_predictions.extend(predictions.cpu().numpy())
        all_targets.extend(target.cpu().numpy())
        all_probabilities.extend(probabilities.cpu().numpy())
        all_predicted_probs.extend(probabilities[:, 1].cpu().numpy())

# Convert to numpy
y_true = np.array(all_targets)
y_pred = np.array(all_predictions)
y_prob = np.array(all_predicted_probs)

# Class names
class_names = ['Normal', 'Atypical']

print(f"\n📊 EVALUATION RESULTS (DENSENET-121 + ECA):")
print(f"  • Total test samples: {len(y_true)}")
print(f"  • Predictions generated with ECA attention mechanism")

# Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)
print(f"\n🎯 Confusion Matrix:")
print(f"  True Negatives (Normal → Normal): {cm[0,0]}")
print(f"  False Positives (Normal → Atypical): {cm[0,1]}")
print(f"  False Negatives (Atypical → Normal): {cm[1,0]}")
print(f"  True Positives (Atypical → Atypical): {cm[1,1]}")

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names,
            cbar_kws={'label': 'Count'})
plt.title('📊 Confusion Matrix - DenseNet-121 + ECA', fontsize=14, fontweight='bold')
plt.xlabel('Predicted Label', fontweight='bold')
plt.ylabel('True Label', fontweight='bold')

# Add percentages to cells
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
for i in range(len(class_names)):
    for j in range(len(class_names)):
        plt.text(j + 0.5, i + 0.7, f'({cm_percent[i, j]:.1%})',
                 ha='center', va='center', fontsize=10, color='darkred', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# 📂 Loading best trained DenseNet-121 + CCA model...
# ⚠️ Best model file not found, using current model state
#
# 📊 EVALUATION RESULTS (DENSENET-121 + ECA):
#   • Total test samples: 2788
#   • Predictions generated with ECA attention mechanism
#
# 🎯 Confusion Matrix:
#   True Negatives (Normal → Normal): 2226
#   False Positives (Normal → Atypical): 127
#   False Negatives (Atypical → Normal): 181
#   True Positives (Atypical → Atypical): 254

# %%
# 🖼️ DENSENET-121 SAMPLE PREDICTIONS VISUALIZATION
print("🔍 Showing sample predictions with confidence scores...")
print("="*80)

# Get a batch of validation images for visualization
model.eval()
with torch.no_grad():
    # Get one batch from validation loader
    data_iter = iter(val_loader)
    images, labels = next(data_iter)
    images, labels = images.to(device), labels.to(device)
    
    # Get predictions
    outputs = model(images)
    probabilities = torch.softmax(outputs, dim=1)
    predictions = torch.argmax(probabilities, dim=1)
    
    # Move to CPU for visualization
    images = images.cpu()
    labels = labels.cpu()
    predictions = predictions.cpu()
    probabilities = probabilities.cpu()

# Create visualization
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
fig.suptitle('🖼️ DenseNet-121 Sample Predictions from Validation Set', fontsize=16, fontweight='bold')

class_names = ['Non-Mitotic', 'Mitotic']
colors = ['#4caf50', '#f44336']  # Green for correct, Red for incorrect

for i in range(8):
    row = i // 4
    col = i % 4
    
    # Get image, true label, prediction, and confidence
    img = images[i]
    true_label = labels[i].item()
    pred_label = predictions[i].item()
    confidence = probabilities[i][pred_label].item()
    
    # Denormalize image for display (assuming ImageNet normalization)
    mean = torch.tensor([0.485, 0.456, 0.406])
    std = torch.tensor([0.229, 0.224, 0.225])
    img = img * std.view(3, 1, 1) + mean.view(3, 1, 1)
    img = torch.clamp(img, 0, 1)
    
    # Display image
    axes[row, col].imshow(img.permute(1, 2, 0))
    axes[row, col].axis('off')
    
    # Determine if prediction is correct
    is_correct = true_label == pred_label
    border_color = colors[0] if is_correct else colors[1]
    status_icon = "✅" if is_correct else "❌"
    
    # Create title with prediction info
    title = f"{status_icon} True: {class_names[true_label]}\n"
    title += f"Pred: {class_names[pred_label]} ({confidence:.1%})"
    
    axes[row, col].set_title(title, fontsize=10, fontweight='bold', 
                           color=border_color, pad=10)
    
    # Add colored border
    for spine in axes[row, col].spines.values():
        spine.set_edgecolor(border_color)
        spine.set_linewidth(3)

plt.tight_layout()
plt.show()

# Show statistics for this batch
batch_accuracy = (predictions == labels).float().mean().item()
correct_predictions = (predictions == labels).sum().item()
total_predictions = len(labels)

print(f"\n📊 DENSENET-121 BATCH STATISTICS:")
print(f"🎯 Batch Accuracy: {batch_accuracy:.1%} ({correct_predictions}/{total_predictions})")
print(f"🔹 Non-Mitotic samples: {(labels == 0).sum().item()}")
print(f"🔸 Mitotic samples: {(labels == 1).sum().item()}")

# Show confidence distribution
high_conf_correct = ((probabilities.max(dim=1)[0] > 0.9) & (predictions == labels)).sum().item()
low_conf_incorrect = ((probabilities.max(dim=1)[0] < 0.6) & (predictions != labels)).sum().item()

print(f"\n🔍 CONFIDENCE ANALYSIS:")
print(f"✅ High confidence (>90%) correct predictions: {high_conf_correct}")
print(f"⚠️ Low confidence (<60%) incorrect predictions: {low_conf_incorrect}")

print("\n" + "="*80)
# Out:
# 🔍 Showing sample predictions with confidence scores...
# ================================================================================
# 📊 DENSENET-121 BATCH STATISTICS:
# 🎯 Batch Accuracy: 90.6% (29/32)
# 🔹 Non-Mitotic samples: 29
# 🔸 Mitotic samples: 3
#
# 🔍 CONFIDENCE ANALYSIS:
# ✅ High confidence (>90%) correct predictions: 0
# ⚠️ Low confidence (<60%) incorrect predictions: 1
#
# ================================================================================

# %%
# 🎯 DENSENET-121 FINAL EVALUATION SUMMARY & CLINICAL RECOMMENDATIONS
print("📋 COMPREHENSIVE DENSENET-121 MODEL EVALUATION SUMMARY")
print("=" * 80)

# Calculate key metrics for summary
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn)  # Recall for mitotic class
specificity = tn / (tn + fp)  # Recall for non-mitotic class
precision_mitotic = tp / (tp + fp)  # Precision for mitotic class
precision_non_mitotic = tn / (tn + fn)  # Precision for non-mitotic class

print(f"🏆 DENSENET-121 MODEL PERFORMANCE OVERVIEW:")
print(f"   • Overall Accuracy: {accuracy:.1%}")
print(f"   • AUC-ROC Score: {auc_score:.4f}")
print(f"   • Sensitivity (Mitotic Detection): {sensitivity:.1%}")
print(f"   • Specificity (Non-Mitotic Detection): {specificity:.1%}")

print(f"\n🏥 CLINICAL RELEVANCE FOR MITOTIC FIGURE DETECTION:")
print(f"   • True Positive Rate (Sensitivity): {sensitivity:.1%}")
print(f"     → Out of all actual mitotic figures, {sensitivity:.1%} were correctly identified")
print(f"   • False Negative Rate: {fn/(tp+fn):.1%}")
print(f"     → {fn} mitotic figures were missed (could impact cancer grading)")
print(f"   • False Positive Rate: {fp/(fp+tn):.1%}")
print(f"     → {fp} non-mitotic figures were incorrectly flagged as mitotic")
print(f"   • Positive Predictive Value: {precision_mitotic:.1%}")
print(f"     → When model predicts mitotic, it's correct {precision_mitotic:.1%} of the time")

print(f"\n🔍 CONFUSION MATRIX CLINICAL INTERPRETATION:")
print(f"   ✅ True Negatives (TN): {tn} - Correctly identified non-mitotic figures")
print(f"   ❌ False Positives (FP): {fp} - Non-mitotic figures misclassified as mitotic")
print(f"   ❌ False Negatives (FN): {fn} - Mitotic figures missed by the model")
print(f"   ✅ True Positives (TP): {tp} - Correctly identified mitotic figures")

print(f"\n📊 DENSENET-121 AUC-ROC CLINICAL INTERPRETATION:")
if auc_score >= 0.9:
    auc_interpretation = "EXCELLENT - Outstanding ability to distinguish mitotic from non-mitotic figures"
    clinical_readiness = "Ready for clinical validation studies"
elif auc_score >= 0.8:
    auc_interpretation = "VERY GOOD - Good discrimination ability for mitotic figure detection"
    clinical_readiness = "Consider additional validation on diverse pathology datasets"
elif auc_score >= 0.7:
    auc_interpretation = "GOOD - Acceptable discrimination ability"
    clinical_readiness = "Requires improvement before clinical consideration"
else:
    auc_interpretation = "NEEDS IMPROVEMENT - Limited discrimination ability"
    clinical_readiness = "Significant improvements needed for clinical use"

print(f"   🎯 Score: {auc_score:.4f} - {auc_interpretation}")
print(f"   🏥 Clinical Readiness: {clinical_readiness}")

print(f"\n🔬 DENSENET-121 VS. OTHER ARCHITECTURES:")
print(f"   • DenseNet-121 leverages dense connectivity for feature reuse")
print(f"   • Fewer parameters than ResNet but deeper feature propagation")
print(f"   • GAP layer reduces overfitting and improves generalization")
print(f"   • Focal Loss addresses class imbalance in mitotic figure detection")

print(f"\n💡 CLINICAL DEPLOYMENT RECOMMENDATIONS:")

# Risk assessment based on metrics
if sensitivity >= 0.9 and specificity >= 0.8:
    risk_level = "🟢 LOW RISK"
    deployment_advice = "Suitable for clinical assistance with pathologist oversight"
elif sensitivity >= 0.8 and specificity >= 0.7:
    risk_level = "🟡 MODERATE RISK"  
    deployment_advice = "Requires careful clinical validation and expert review"
else:
    risk_level = "🔴 HIGH RISK"
    deployment_advice = "Not recommended for clinical use without major improvements"

print(f"   • Risk Level: {risk_level}")
print(f"   • Deployment Advice: {deployment_advice}")

print(f"\n🎯 STRENGTHS OF DENSENET-121 MODEL:")
strengths = []
if accuracy >= 0.85:
    strengths.append(f"High overall accuracy ({accuracy:.1%})")
if auc_score >= 0.85:
    strengths.append(f"Excellent discrimination (AUC: {auc_score:.4f})")
if sensitivity >= 0.8:
    strengths.append(f"Good sensitivity for mitotic detection ({sensitivity:.1%})")
if specificity >= 0.8:
    strengths.append(f"Good specificity for non-mitotic identification ({specificity:.1%})")
if precision_mitotic >= 0.8:
    strengths.append(f"High precision for mitotic predictions ({precision_mitotic:.1%})")

for strength in strengths:
    print(f"   ✅ {strength}")

print(f"\n⚠️  AREAS FOR IMPROVEMENT:")
improvements = []
if accuracy < 0.85:
    improvements.append(f"Overall accuracy needs improvement (current: {accuracy:.1%})")
if auc_score < 0.85:
    improvements.append(f"Discrimination ability needs enhancement (AUC: {auc_score:.4f})")
if sensitivity < 0.8:
    improvements.append(f"Sensitivity for mitotic detection needs improvement ({sensitivity:.1%})")
if specificity < 0.8:
    improvements.append(f"Specificity needs improvement to reduce false alarms ({specificity:.1%})")
if fn > tp * 0.2:  # If false negatives > 20% of true positives
    improvements.append(f"Too many missed mitotic figures ({fn} false negatives)")
if fp > tp:  # If false positives > true positives
    improvements.append(f"Too many false alarms ({fp} false positives)")

for improvement in improvements:
    print(f"   🔧 {improvement}")

if not improvements:
    print(f"   🎉 DenseNet-121 model meets clinical standards across all key metrics!")

print(f"\n🏥 CLINICAL IMPACT ASSESSMENT:")
if sensitivity >= 0.9:
    print(f"   ✅ EXCELLENT sensitivity: Very few mitotic figures will be missed")
else:
    print(f"   ⚠️ Sensitivity {sensitivity:.1%}: Risk of missing {100-sensitivity*100:.1f}% of mitotic figures")

if fp <= tp:
    print(f"   ✅ GOOD precision: Low false alarm rate")
else:
    print(f"   ⚠️ High false positive rate: May burden pathologists with unnecessary reviews")

# Model comparison context
print(f"\n📊 DENSENET-121 ARCHITECTURE ADVANTAGES:")
print(f"   • Dense connectivity: Efficient feature reuse and gradient flow")
print(f"   • Parameter efficiency: {sum(p.numel() for p in model.parameters())/1e6:.1f}M parameters")
print(f"   • GAP integration: Reduces overfitting, improves localization")
print(f"   • Focal Loss compatibility: Effectively handles class imbalance")
print(f"   • Clinical relevance: Suitable for pathology image analysis")

print(f"\n" + "=" * 80)
print(f"🏁 DENSENET-121 EVALUATION COMPLETED")
print(f"📊 Final Performance: {accuracy:.1%} Accuracy | {auc_score:.4f} AUC | {sensitivity:.1%} Sensitivity | {specificity:.1%} Specificity")
print(f"🏥 Clinical Status: {clinical_readiness}")
print(f"=" * 80)
# Out:
# 📋 COMPREHENSIVE DENSENET-121 MODEL EVALUATION SUMMARY
# ================================================================================
# 🏆 DENSENET-121 MODEL PERFORMANCE OVERVIEW:
#    • Overall Accuracy: 57.5%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_39/2780034883.py in <cell line: 0>()
#      12 print(f"🏆 DENSENET-121 MODEL PERFORMANCE OVERVIEW:")
#      13 print(f"   • Overall Accuracy: {accuracy:.1%}")
# ---> 14 print(f"   • AUC-ROC Score: {auc_score:.4f}")
#      15 print(f"   • Sensitivity (Mitotic Detection): {sensitivity:.1%}")
#      16 print(f"   • Specificity (Non-Mitotic Detection): {specificity:.1%}")
#
# NameError: name 'auc_score' is not defined
