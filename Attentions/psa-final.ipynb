# %% [markdown]
# # Mitotic Figure Binary Classification with Pre-Augmented Dataset - DenseNet GAP
#
# This notebook trains a PyTorch model for binary classification of mitotic figures using a pre-augmented Kaggle dataset with DenseNet architecture.
#
# ## Dataset Overview:
# - **Source**: Pre-augmented AMI-BR and MIDOG25 datasets from Kaggle
# - **Location**: `/kaggle/input/MitoticFigure_AugmentedDataSet/`
# - **Target**: Binary classification - Atypical vs Normal mitotic figures
# - **Data**: Includes original images + 4x augmented AMF images for better class balance
#
# ## Features:
# - Uses pre-processed and augmented dataset
# - Slide-based stratified splitting for proper validation
# - **DenseNet-121 architecture with Global Average Pooling (GAP)**
# - Full model training (entire DenseNet-121 + custom head trainable)
# - Comprehensive evaluation metrics

# %%
# Installation commands intentionally removed.
# Assumes required packages (torch, torchvision, timm, albumentations, ptflops, etc.)
# are already installed in the environment. If not, install them manually via pip or conda.

# %%
# Core libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Image processing
import cv2
from PIL import Image
import albumentations as A
from albumentations.pytorch import ToTensorV2

# Deep learning
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR
import torchvision.transforms as transforms
import torchvision.models as models

# Machine learning utilities
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Plotting style
plt.style.use('default')
sns.set_palette("husl")

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

print("All libraries imported successfully!")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# Out:
# All libraries imported successfully!
# PyTorch version: 2.6.0+cu124
# CUDA available: True
# CUDA device: Tesla P100-PCIE-16GB

# %%
# Set random seeds for reproducibility
import random

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# Define paths for your Kaggle dataset structure
BASE_DIR = Path('/kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset')
TRAINING_DIR = BASE_DIR / 'training'
VALIDATION_DIR = BASE_DIR / 'validation'
TESTING_DIR = BASE_DIR / 'testing'
DATASET_CSV = BASE_DIR / 'mitotic_figures_dataset.csv'

print(f"📁 Dataset paths for your pre-split Kaggle dataset:")
print(f"Base directory: {BASE_DIR}")
print(f"Training images: {TRAINING_DIR}")
print(f"Validation images: {VALIDATION_DIR}")
print(f"Testing images: {TESTING_DIR}")
print(f"Dataset CSV: {DATASET_CSV}")

# Check if directories exist
for dir_path, name in [(TRAINING_DIR, 'Training'), (VALIDATION_DIR, 'Validation'), (TESTING_DIR, 'Testing')]:
    if dir_path.exists():
        print(f"✅ {name} directory found")
    else:
        print(f"❌ {name} directory not found: {dir_path}")

# Training parameters (Optimized for DenseNet-121 with GAP)
IMG_SIZE = 224            # Standard input size for DenseNet
BATCH_SIZE = 32          # Good batch size for DenseNet-121
EPOCHS = 50              # Assignment requirement: minimum 50 epochs
LEARNING_RATE = 1e-3     # Learning rate for custom layers only
NUM_CLASSES = 2
PATIENCE = 10            # Assignment requirement: patience = 10 for early stopping

print(f"🎯 DENSENET-121 GAP PARAMETERS:")
print(f"Model: DenseNet-121 + Global Average Pooling")
print(f"Dataset directory: {BASE_DIR}")
print(f"Dataset CSV: {DATASET_CSV}")
print(f"Image size: {IMG_SIZE}x{IMG_SIZE} (standard for DenseNet)")
print(f"Batch size: {BATCH_SIZE}")
print(f"Epochs: {EPOCHS} (minimum as per assignment)")
print(f"Learning rate: {LEARNING_RATE} (custom layers only)")
print(f"Training approach: GAP + FULL MODEL training (entire network)")
print(f"Early stopping patience: {PATIENCE}")
print(f"Using GPU: {torch.cuda.is_available()}")
print(f"Automatic pretrained weights: ✅ (ImageNet DenseNet-121)")
# Out:
# 📁 Dataset paths for your pre-split Kaggle dataset:
# Base directory: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset
# Training images: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/training
# Validation images: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/validation
# Testing images: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/testing
# Dataset CSV: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/mitotic_figures_dataset.csv
# ✅ Training directory found
# ✅ Validation directory found
# ✅ Testing directory found
# 🎯 DENSENET-121 GAP PARAMETERS:
# Model: DenseNet-121 + Global Average Pooling
# Dataset directory: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset
# Dataset CSV: /kaggle/input/mitoticfigure-spiltandaugmenteddataset/MitoticFigure_AugmentedDataset/mitotic_figures_dataset.csv
# Image size: 224x224 (standard for DenseNet)
# Batch size: 32
# Epochs: 50 (minimum as per assignment)
# Learning rate: 0.001 (custom layers only)
# Training approach: GAP + FULL MODEL training (entire network)
# Early stopping patience: 10
# Using GPU: True
# Automatic pretrained weights: ✅ (ImageNet DenseNet-121)

# %% [markdown]
# ## Loading Pre-Augmented Dataset

# %%
# Load the organized dataset from your Kaggle upload
print("Loading pre-split dataset from Kaggle...")

# Load the CSV with all metadata
df = pd.read_csv(DATASET_CSV)
print(f"Dataset loaded: {df.shape}")
print(f"Columns: {df.columns.tolist()}")

# Display dataset information
print(f"\nDataset Statistics:")
print(f"Total samples: {len(df)}")

# Check split distribution
if 'split' in df.columns:
    split_counts = df['split'].value_counts()
    print(f"\nSplit distribution:")
    for split in ['training', 'validation', 'testing']:
        count = split_counts.get(split, 0)
        percentage = (count / len(df)) * 100 if len(df) > 0 else 0
        print(f"  {split.capitalize()}: {count} samples ({percentage:.1f}%)")
else:
    print("⚠️ No split column found - dataset might not be properly split")

# Check class distribution
class_counts = df['is_atypical'].value_counts()
print(f"\nClass distribution:")
print(f"Normal (False): {class_counts.get(False, 0)}")
print(f"Atypical (True): {class_counts.get(True, 0)}")

# Check augmentation status
if 'is_augmented' in df.columns:
    aug_counts = df['is_augmented'].value_counts()
    print(f"\nAugmentation breakdown:")
    print(f"Original: {aug_counts.get(False, 0)}")
    print(f"Augmented: {aug_counts.get(True, 0)}")

# Check augmentation types
if 'augmentation_type' in df.columns:
    aug_types = df['augmentation_type'].value_counts()
    print(f"\nAugmentation types:")
    for aug_type, count in aug_types.items():
        print(f"  {aug_type}: {count}")

# Check dataset sources
if 'dataset' in df.columns:
    dataset_counts = df['dataset'].value_counts()
    print(f"\nDataset sources:")
    for dataset, count in dataset_counts.items():
        print(f"  {dataset}: {count}")

# Show first few rows
print(f"\nFirst 5 rows:")
print(df[['filename', 'is_atypical', 'split', 'is_augmented']].head())

print(f"\n✅ Dataset loaded successfully!")
# Out:
# Loading pre-split dataset from Kaggle...
# Dataset loaded: (19162, 6)
# Columns: ['filename', 'is_atypical', 'dataset', 'split', 'is_augmented', 'augmentation_type']
#
# Dataset Statistics:
# Total samples: 19162
#
# Split distribution:
#   Training: 13586 samples (70.9%)
#   Validation: 2788 samples (14.5%)
#   Testing: 2788 samples (14.5%)
#
# Class distribution:
# Normal (False): 11762
# Atypical (True): 7400
#
# Augmentation breakdown:
# Original: 13938
# Augmented: 5224
#
# Augmentation types:
#   1.0: 1306
#   2.0: 1306
#   3.0: 1306
#   4.0: 1306
#
# Dataset sources:
#   MIDOG25: 16151
#   AMI-BR: 3011
#
# First 5 rows:
#            filename  is_atypical     split  is_augmented
# 0          1371.png        False  training         False
# 1  TUPAC16_2232.png        False  training         False
# 2          3733.png         True  training         False
# 3          9796.png        False  training         False
# 4          5477.png        False  training         False
#
# ✅ Dataset loaded successfully!

# %%
# Prepare the dataset for training using pre-split structure
print("Preparing pre-split dataset for training...")

# Create image paths based on the split information
def get_image_path(row):
    """Get the full image path based on split folder"""
    split_folder = row['split']
    filename = row['filename']
    
    if split_folder == 'training':
        return str(TRAINING_DIR / filename)
    elif split_folder == 'validation':
        return str(VALIDATION_DIR / filename)
    elif split_folder == 'testing':
        return str(TESTING_DIR / filename)
    else:
        # Fallback - try to find the file in any folder
        for folder in [TRAINING_DIR, VALIDATION_DIR, TESTING_DIR]:
            path = folder / filename
            if path.exists():
                return str(path)
        return str(TRAINING_DIR / filename)  # Default fallback

# Add image paths
df['image_path'] = df.apply(get_image_path, axis=1)

# Convert boolean to integer labels (0=Normal, 1=Atypical)
df['label'] = df['is_atypical'].astype(int)

# Verify file existence and filter out missing files
print("Verifying all image files exist...")
existing_files = []
missing_files = []

for idx, row in df.iterrows():
    if Path(row['image_path']).exists():
        existing_files.append(idx)
    else:
        missing_files.append(row['filename'])

if missing_files:
    print(f"⚠️ Warning: {len(missing_files)} files not found")
    if len(missing_files) <= 10:
        print(f"Missing files: {missing_files}")
    else:
        print(f"First 10 missing files: {missing_files[:10]}")

# Keep only existing files
df = df.loc[existing_files].reset_index(drop=True)

print(f"\nFinal dataset info:")
print(f"Total samples: {len(df)}")
print(f"Samples with existing files: {len(existing_files)}")
print(f"Missing files: {len(missing_files)}")

# Display augmentation breakdown if available
if 'is_augmented' in df.columns:
    aug_breakdown = df['is_augmented'].value_counts()
    print(f"\nAugmentation breakdown:")
    print(f"  Original images: {aug_breakdown.get(False, 0)}")
    print(f"  Augmented images: {aug_breakdown.get(True, 0)}")

# Display final class distribution
print(f"\nFinal class distribution:")
class_dist = df['label'].value_counts()
print(f"  Normal (0): {class_dist.get(0, 0)}")
print(f"  Atypical (1): {class_dist.get(1, 0)}")

# Display split distribution
print(f"\nSplit distribution:")
split_dist = df['split'].value_counts()
for split_name, count in split_dist.items():
    percentage = (count / len(df)) * 100
    print(f"  {split_name}: {count} samples ({percentage:.1f}%)")

print(f"\nSample data:")
print(df[['filename', 'label', 'is_atypical', 'split', 'is_augmented']].head())
# Out:
# Preparing pre-split dataset for training...
# Verifying all image files exist...
#
# Final dataset info:
# Total samples: 19162
# Samples with existing files: 19162
# Missing files: 0
#
# Augmentation breakdown:
#   Original images: 13938
#   Augmented images: 5224
#
# Final class distribution:
#   Normal (0): 11762
#   Atypical (1): 7400
#
# Split distribution:
#   training: 13586 samples (70.9%)
#   validation: 2788 samples (14.5%)
#   testing: 2788 samples (14.5%)
#
# Sample data:
#            filename  label  is_atypical     split  is_augmented
# 0          1371.png      0        False  training         False
# 1  TUPAC16_2232.png      0        False  training         False
# 2          3733.png      1         True  training         False
# 3          9796.png      0        False  training         False
# 4          5477.png      0        False  training         False

# %% [markdown]
# ## Data Visualization and Analysis

# %%
# Visualize class distribution of pre-augmented dataset
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Overall class distribution
df['label'].value_counts().plot(kind='bar', ax=axes[0,0], color=['skyblue', 'lightcoral'])
axes[0,0].set_title('Overall Class Distribution (After Augmentation)')
axes[0,0].set_xlabel('Class (0=Normal, 1=Atypical)')
axes[0,0].set_ylabel('Count')
axes[0,0].tick_params(axis='x', rotation=0)

# Original vs Augmented distribution (if available)
if 'is_augmented' in df.columns:
    df['is_augmented'].value_counts().plot(kind='bar', ax=axes[0,1], color=['lightgreen', 'orange'])
    axes[0,1].set_title('Original vs Augmented Images')
    axes[0,1].set_xlabel('Is Augmented')
    axes[0,1].set_ylabel('Count')
    axes[0,1].set_xticklabels(['Original', 'Augmented'], rotation=0)
else:
    axes[0,1].text(0.5, 0.5, 'Augmentation info\nnot available', ha='center', va='center', transform=axes[0,1].transAxes)
    axes[0,1].set_title('Original vs Augmented Images')

# Dataset source distribution (if available)
if 'dataset' in df.columns and len(df['dataset'].unique()) > 1:
    pd.crosstab(df['dataset'], df['label']).plot(kind='bar', ax=axes[1,0], 
                                                              color=['skyblue', 'lightcoral'])
    axes[1,0].set_title('Class Distribution by Dataset Source')
    axes[1,0].set_xlabel('Dataset')
    axes[1,0].set_ylabel('Count')
    axes[1,0].legend(['Normal', 'Atypical'])
    axes[1,0].tick_params(axis='x', rotation=45)
else:
    axes[1,0].text(0.5, 0.5, 'Dataset source info\nnot available', ha='center', va='center', transform=axes[1,0].transAxes)
    axes[1,0].set_title('Class Distribution by Dataset Source')

# Percentage distribution
class_pct = df['label'].value_counts(normalize=True) * 100
class_pct.plot(kind='pie', ax=axes[1,1], autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])
axes[1,1].set_title('Class Distribution (Percentage)')
axes[1,1].set_ylabel('')

plt.tight_layout()
plt.show()

# Print detailed statistics
print("Detailed Statistics:")
print(f"Total samples: {len(df)}")
print(f"Normal samples: {len(df[df['label'] == 0])} ({len(df[df['label'] == 0])/len(df)*100:.1f}%)")
print(f"Atypical samples: {len(df[df['label'] == 1])} ({len(df[df['label'] == 1])/len(df)*100:.1f}%)")

if 'is_augmented' in df.columns:
    print(f"\nAugmentation breakdown:")
    print(f"Original images: {len(df[df['is_augmented'] == False])}")
    print(f"Augmented images: {len(df[df['is_augmented'] == True])}")

if 'dataset' in df.columns:
    print(f"\nBy dataset source:")
    if len(df['dataset'].unique()) > 1:
        print(pd.crosstab(df['dataset'], df['label'], margins=True))
    else:
        print(f"Single dataset source: {df['dataset'].iloc[0]}")

# Show file naming patterns
print(f"\nSample filenames:")
print(df['filename'].head(10).tolist())
# Out:
# Detailed Statistics:
# Total samples: 19162
# Normal samples: 11762 (61.4%)
# Atypical samples: 7400 (38.6%)
#
# Augmentation breakdown:
# Original images: 13938
# Augmented images: 5224
#
# By dataset source:
# label        0     1    All
# dataset
# AMI-BR    1571  1440   3011
# MIDOG25  10191  5960  16151
# All      11762  7400  19162
#
# Sample filenames:
# ['1371.png', 'TUPAC16_2232.png', '3733.png', '9796.png', '5477.png', '11425.png', '1203.png', '7546.png', 'TUPAC16_2410.png', '7783.png']

# %%
# Sample image visualization
def visualize_samples(df, n_samples=8):
    fig, axes = plt.subplots(2, 4, figsize=(16, 8))
    axes = axes.ravel()
    
    # Get samples from each class
    samples = []
    
    # Get normal and atypical samples
    for label in [0, 1]:
        subset = df[df['label'] == label]
        if len(subset) > 0:
            # Try to get mix of original and augmented if available
            if 'is_augmented' in df.columns:
                original_subset = subset[subset['is_augmented'] == False]
                augmented_subset = subset[subset['is_augmented'] == True]
                
                # Get 2 original and 2 augmented if possible
                if len(original_subset) > 0:
                    samples.extend(original_subset.sample(min(2, len(original_subset))).to_dict('records'))
                if len(augmented_subset) > 0:
                    samples.extend(augmented_subset.sample(min(2, len(augmented_subset))).to_dict('records'))
            else:
                # Just get 4 samples of this class
                samples.extend(subset.sample(min(4, len(subset))).to_dict('records'))
    
    for i, sample in enumerate(samples[:8]):
        try:
            img = Image.open(sample['image_path'])
            axes[i].imshow(img)
            
            # Create title with available information
            label_text = 'Atypical' if sample['label'] == 1 else 'Normal'
            title_parts = [label_text]
            
            if 'is_augmented' in sample:
                aug_text = 'Augmented' if sample['is_augmented'] else 'Original'
                title_parts.append(aug_text)
            
            if 'dataset' in sample and sample['dataset'] != 'mixed':
                title_parts.append(sample['dataset'])
            
            title = '\n'.join(title_parts)
            axes[i].set_title(title, fontsize=10)
            axes[i].axis('off')
            
        except Exception as e:
            axes[i].text(0.5, 0.5, f"Error loading\n{sample['filename']}", 
                        ha='center', va='center', transform=axes[i].transAxes)
            axes[i].set_title(f"Error: {sample['filename'][:20]}...")
            axes[i].axis('off')
    
    # Hide unused subplots
    for i in range(len(samples), 8):
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.show()

visualize_samples(df)

# %% [markdown]
# ## Data Preparation for Training

# %%
# Use the pre-split data from your dataset
print("📊 Using pre-split dataset structure...")

# Extract splits based on the 'split' column
train_df = df[df['split'] == 'training'].reset_index(drop=True)
val_df = df[df['split'] == 'validation'].reset_index(drop=True)
test_df = df[df['split'] == 'testing'].reset_index(drop=True)

print(f"📈 Pre-split dataset distribution:")
print(f"Training set: {len(train_df)} samples")
print(f"Validation set: {len(val_df)} samples")
print(f"Test set: {len(test_df)} samples")
print(f"Total: {len(train_df) + len(val_df) + len(test_df)} samples")

# Calculate percentages
total_samples = len(df)
train_pct = len(train_df) / total_samples * 100
val_pct = len(val_df) / total_samples * 100
test_pct = len(test_df) / total_samples * 100

print(f"\n📊 Split percentages:")
print(f"Training: {train_pct:.1f}%")
print(f"Validation: {val_pct:.1f}%")
print(f"Test: {test_pct:.1f}%")

# Check detailed class distribution in each set
print("\n🎯 Class distribution verification:")
for split_name, split_df in [("Train", train_df), ("Val", val_df), ("Test", test_df)]:
    if len(split_df) > 0:
        class_dist = split_df['label'].value_counts()
        class_pct = split_df['label'].value_counts(normalize=True) * 100
        normal_count = class_dist.get(0, 0)
        atypical_count = class_dist.get(1, 0)
        normal_pct = class_pct.get(0, 0)
        atypical_pct = class_pct.get(1, 0)
        print(f"{split_name}: Normal={normal_count} ({normal_pct:.1f}%), "
              f"Atypical={atypical_count} ({atypical_pct:.1f}%)")

# Check augmentation distribution in each split
if 'is_augmented' in df.columns:
    print("\n🔄 Augmentation distribution by split:")
    for split_name, split_df in [("Train", train_df), ("Val", val_df), ("Test", test_df)]:
        if len(split_df) > 0:
            aug_dist = split_df['is_augmented'].value_counts()
            original = aug_dist.get(False, 0)
            augmented = aug_dist.get(True, 0)
            print(f"{split_name}: Original={original}, Augmented={augmented}")

# Verify that we have samples in all splits
if len(train_df) == 0:
    raise ValueError("❌ No training samples found! Check your dataset split column values.")
if len(val_df) == 0:
    raise ValueError("❌ No validation samples found! Check your dataset split column values.")
if len(test_df) == 0:
    raise ValueError("❌ No test samples found! Check your dataset split column values.")

print(f"\n✅ Successfully loaded pre-split dataset!")
print(f"Ready for training with {len(train_df)} training samples")
# Out:
# 📊 Using pre-split dataset structure...
# 📈 Pre-split dataset distribution:
# Training set: 13586 samples
# Validation set: 2788 samples
# Test set: 2788 samples
# Total: 19162 samples
#
# 📊 Split percentages:
# Training: 70.9%
# Validation: 14.5%
# Test: 14.5%
#
# 🎯 Class distribution verification:
# Train: Normal=7056 (51.9%), Atypical=6530 (48.1%)
# Val: Normal=2353 (84.4%), Atypical=435 (15.6%)
# Test: Normal=2353 (84.4%), Atypical=435 (15.6%)
#
# 🔄 Augmentation distribution by split:
# Train: Original=8362, Augmented=5224
# Val: Original=2788, Augmented=0
# Test: Original=2788, Augmented=0
#
# ✅ Successfully loaded pre-split dataset!
# Ready for training with 13586 training samples

# %%
# Define PyTorch Dataset class
class MitosisDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe.reset_index(drop=True)
        self.transform = transform
    
    def __len__(self):
        return len(self.dataframe)
    
    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        
        # Load image
        try:
            image = cv2.imread(row['image_path'])
            if image is None:
                raise ValueError(f"Could not load image: {row['image_path']}")
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        except Exception as e:
            print(f"Error loading {row['image_path']}: {e}")
            # Return a black image as fallback
            image = np.zeros((IMG_SIZE, IMG_SIZE, 3), dtype=np.uint8)
        
        # Apply transforms
        if self.transform:
            transformed = self.transform(image=image)
            image = transformed['image']
        
        label = torch.tensor(row['label'], dtype=torch.long)
        
        return image, label

# Define transforms (reduced augmentation since data is pre-augmented)
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.3),  # Reduced probability since data is pre-augmented
    A.Rotate(limit=15, p=0.3),  # Lighter augmentation
    A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.3),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

# Create datasets
train_dataset = MitosisDataset(train_df, transform=train_transform)
val_dataset = MitosisDataset(val_df, transform=val_transform)
test_dataset = MitosisDataset(test_df, transform=val_transform)

# Calculate class weights for WeightedRandomSampler
print("📊 Calculating sample weights for balanced training...")
class_counts = train_df['label'].value_counts().sort_index()
total_samples = len(train_df)

print(f"Training set class distribution:")
for i, count in enumerate(class_counts):
    class_name = "Normal" if i == 0 else "Atypical"
    percentage = (count / total_samples) * 100
    print(f"  Class {i} ({class_name}): {count} samples ({percentage:.1f}%)")

# Calculate weights for each class (inverse of frequency)
class_weights = []
for i in range(len(class_counts)):
    weight = total_samples / (len(class_counts) * class_counts[i])
    class_weights.append(weight)
    class_name = "Normal" if i == 0 else "Atypical"
    print(f"  Class {i} ({class_name}) weight: {weight:.4f}")

# Create sample weights for each training sample
sample_weights = []
for _, row in train_df.iterrows():
    label = row['label']
    sample_weights.append(class_weights[label])

sample_weights = torch.DoubleTensor(sample_weights)

# Create WeightedRandomSampler
sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True  # Allow replacement to balance classes
)

print(f"\n🎯 WeightedRandomSampler created:")
print(f"  Total samples: {len(sample_weights)}")
print(f"  Unique weights: {len(set(sample_weights.tolist()))}")
print(f"  Weight range: {sample_weights.min():.4f} - {sample_weights.max():.4f}")

# Create data loaders with WeightedRandomSampler for training
num_workers = 2 if torch.cuda.is_available() else 0

# Training loader with WeightedRandomSampler (no shuffle when using sampler)
train_loader = DataLoader(
    train_dataset, 
    batch_size=BATCH_SIZE, 
    sampler=sampler,  # Using WeightedRandomSampler instead of shuffle=True
    num_workers=num_workers, 
    pin_memory=torch.cuda.is_available()
)

# Validation and test loaders remain the same
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, 
                       num_workers=num_workers, pin_memory=torch.cuda.is_available())
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, 
                        num_workers=num_workers, pin_memory=torch.cuda.is_available())

print(f"\n📊 DataLoader Configuration:")
print(f"Training batches: {len(train_loader)} (with WeightedRandomSampler)")
print(f"Validation batches: {len(val_loader)}")
print(f"Test batches: {len(test_loader)}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Num workers: {num_workers}")
print(f"Pin memory: {torch.cuda.is_available()}")

# Verify sampler effectiveness by checking a few batches
print(f"\n🔍 Testing WeightedRandomSampler effectiveness...")
sample_batch_labels = []
for i, (_, labels) in enumerate(train_loader):
    sample_batch_labels.extend(labels.tolist())
    if i >= 4:  # Check first 5 batches
        break

sample_class_dist = pd.Series(sample_batch_labels).value_counts().sort_index()
print(f"Sample from first 5 batches:")
for i, count in enumerate(sample_class_dist):
    class_name = "Normal" if i == 0 else "Atypical"
    percentage = (count / len(sample_batch_labels)) * 100
    print(f"  Class {i} ({class_name}): {count} samples ({percentage:.1f}%)")

print(f"✅ WeightedRandomSampler should provide more balanced batches during training!")
# Out:
# 📊 Calculating sample weights for balanced training...
# Training set class distribution:
#   Class 0 (Normal): 7056 samples (51.9%)
#   Class 1 (Atypical): 6530 samples (48.1%)
#   Class 0 (Normal) weight: 0.9627
#   Class 1 (Atypical) weight: 1.0403
#
# 🎯 WeightedRandomSampler created:
#   Total samples: 13586
#   Unique weights: 2
#   Weight range: 0.9627 - 1.0403
#
# 📊 DataLoader Configuration:
# Training batches: 425 (with WeightedRandomSampler)
# Validation batches: 88
# Test batches: 88
# Batch size: 32
# Num workers: 2
# Pin memory: True
#
# 🔍 Testing WeightedRandomSampler effectiveness...
# Sample from first 5 batches:
#   Class 0 (Normal): 85 samples (53.1%)
#   Class 1 (Atypical): 75 samples (46.9%)
# ✅ WeightedRandomSampler should provide more balanced batches during training!

# %% [markdown]
# ## 🧠 Model Architecture: DenseNet-121 + PSA (Pyramid Split Attention)
#
# ### 🌟 New: PSA Mechanism
#
# **Architecture Overview:**
# - **DenseNet-121**: Pre-trained backbone for feature extraction
# - **PSA Block**: Pyramid Split Attention with multi-scale group convolutions
# - **GAP Layer**: Global Average Pooling to reduce spatial dimensions
# - **Custom Classifier**: Dense layers for binary classification
#
# **PSA Benefits:**
# - ✅ **Multi-Scale Processing**: Uses pyramid of different kernel sizes (3x3, 5x5, 7x7, 9x9)
# - ✅ **Group-Based Splitting**: Efficient channel splitting for parallel processing
# - ✅ **Soft Attention Fusion**: Learnable attention weights across different scales
# - ✅ **Depthwise Convolutions**: Efficient computation with reduced parameters
# - ✅ **Feature Enhancement**: Combines features from multiple receptive field sizes
# - ✅ **Scale-Aware**: Adaptive to features at different scales
#
# **Training Strategy:**
# - Full model training (end-to-end)
# - All parameters trainable: backbone + PSA + classifier
# - Focal Loss for class imbalance
# - AdamW optimizer with ReduceLROnPlateau scheduler

# %%
# PSA (Pyramid Split Attention) Block Implementation - FIXED
import torch
import torch.nn as nn
import torch.nn.functional as F

class PSABlock(nn.Module):
    """
    Pyramid Split Attention block (ResNeSt)
    Multi-scale group convolution + soft attention fusion
    FIXED: Maintains original channel dimensions
    """
    def __init__(self, in_channels, groups=4, reduction=4):
        super(PSABlock, self).__init__()

        # Ensure in_channels is divisible by groups
        if in_channels % groups != 0:
            # Adjust groups to be a divisor of in_channels
            for g in [8, 4, 2, 1]:
                if in_channels % g == 0:
                    groups = g
                    break
        
        self.groups = groups
        self.group_channels = in_channels // groups
        self.in_channels = in_channels

        # Split into multiple depthwise convs with different kernel sizes
        kernel_sizes = [3, 5, 7, 9][:groups]   # Use only as many kernels as groups
        padding_sizes = [1, 2, 3, 4][:groups]

        self.convs = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(
                    self.group_channels, self.group_channels,
                    kernel_size=kernel_sizes[i],
                    padding=padding_sizes[i],
                    groups=self.group_channels,  # depthwise
                    bias=False
                ),
                nn.BatchNorm2d(self.group_channels),
                nn.ReLU(inplace=True)
            )
            for i in range(groups)
        ])

        # Attention vector (softmax over groups)
        self.attention_fc = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(in_channels, max(in_channels // reduction, 1), kernel_size=1, bias=False),
            nn.ReLU(inplace=True),
            nn.Conv2d(max(in_channels // reduction, 1), groups, kernel_size=1, bias=False)
        )

        self.softmax = nn.Softmax(dim=1)
        
        print(f"  • PSA groups: {groups}, group_channels: {self.group_channels}")
        print(f"  • Multi-scale kernels: {kernel_sizes}")
        print(f"  • Reduction ratio: {reduction}")
        print(f"  • Input/Output channels: {in_channels}")

    def forward(self, x):
        B, C, H, W = x.shape
        
        # Split channels into groups
        splits = torch.split(x, self.group_channels, dim=1)

        # Apply multi-scale convs on each split
        conv_outs = [self.convs[i](splits[i]) for i in range(self.groups)]

        # Stack → shape [B, groups, C//groups, H, W] 
        conv_stack = torch.stack(conv_outs, dim=1)

        # Compute attention weights
        attn = self.attention_fc(x)   # [B, groups, 1, 1]
        attn = self.softmax(attn).view(B, self.groups, 1, 1, 1)

        # Apply attention to each group
        attended_groups = conv_stack * attn  # [B, groups, C//groups, H, W]
        
        # Sum across groups but maintain channel dimension
        # Reshape to combine groups back into channel dimension
        out = attended_groups.view(B, -1, H, W)  # [B, C, H, W]
        
        # Ensure output has same dimensions as input
        assert out.shape == x.shape, f"Output shape {out.shape} doesn't match input shape {x.shape}"
        
        return out

print("✅ PSABlock class defined (FIXED)")
print("  • Pyramid Split Attention with multi-scale convolutions")
print("  • Group-based channel splitting for efficient processing") 
print("  • Soft attention fusion across pyramid scales")
print("  • Multi-scale feature extraction with depthwise convolutions")
print("  • ✅ FIXED: Maintains original channel dimensions")
# Out:
# ✅ PSABlock class defined (FIXED)
#   • Pyramid Split Attention with multi-scale convolutions
#   • Group-based channel splitting for efficient processing
#   • Soft attention fusion across pyramid scales
#   • Multi-scale feature extraction with depthwise convolutions
#   • ✅ FIXED: Maintains original channel dimensions

# %%
class MitosisClassifier(nn.Module):
    def __init__(self, model_name='densenet121', num_classes=2, pretrained=True):
        super(MitosisClassifier, self).__init__()
        
        print(f"🏗️ Creating {model_name} model with PSA + GAP + Full Model Training...")
        
        # Load DenseNet backbone with automatic pretrained weight download
        if pretrained:
            print(f"📥 Downloading ImageNet pretrained weights for {model_name}...")
            self.backbone = timm.create_model(model_name, pretrained=True)
            print(f"✅ Pretrained weights downloaded and loaded successfully!")
        else:
            print(f"⚠️ Creating model without pretrained weights (random initialization)")
            self.backbone = timm.create_model(model_name, pretrained=False)
        
        # Get the number of features from the backbone before removing classifier
        backbone_features = self.backbone.get_classifier().in_features
        print(f"📊 DenseNet backbone feature dimension: {backbone_features}")
        
        # Remove the original classifier from backbone
        self.backbone.reset_classifier(0)  # 0 means no classifier
        
        # ================================================================================================
        # PSA INTEGRATION: Add Pyramid Split Attention mechanism before classification
        # ================================================================================================
        print(f"\n🔍 Adding PSA (Pyramid Split Attention) block...")
        
        # PSA block (processes channel features with multi-scale attention before classification)
        self.psa = PSABlock(in_channels=backbone_features)
        
        print(f"✅ PSA block integrated!")
        print(f"   • Channel dimension: {backbone_features}")
        print(f"   • Multi-scale pyramid processing with groups")
        print(f"   • Soft attention fusion across scales")
        print(f"   • Focus on multi-scale feature relationships")
        
        # ================================================================================================
        # FULL MODEL TRAINING: Enable training for ALL parameters (backbone + PSA + custom layers)
        # ================================================================================================
        print("\n🔓 ENABLING FULL MODEL TRAINING - All parameters trainable!")
        for param in self.backbone.parameters():
            param.requires_grad = True  # Enable gradient computation for ALL backbone parameters
        print("✅ FULL MODEL TRAINING: Entire DenseNet-121 + PSA + Custom Head will be trained")
        
        # Create custom classification head with GAP and decreasing neurons
        # DenseNet-121 typically has 1024 features, so we can build a good head
        # Final layer: 2 neurons with Softmax activation
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),  # Global Average Pooling
            nn.Flatten(),  # Flatten after GAP
            nn.Dropout(0.3),
            nn.Linear(backbone_features, 1024),
            nn.ReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.3),
            
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.3),
            
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.3),
            
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            
            # Final layer: 2 neurons for binary classification
            nn.Linear(128, num_classes),
            nn.Softmax(dim=1)  # Softmax activation for probability output
        )
        
        print(f"\n🎯 Custom classifier head created (PSA + GAP approach):")
        print(f"  Architecture: DenseNet-121 -> PSA -> GAP -> Custom Head")
        print(f"  PSA: Pyramid Split Attention with multi-scale processing ⭐")
        print(f"  Global Average Pooling: ✅ (reduces overfitting)")
        print(f"  Final activation: Softmax (probability output)")
        print(f"  Output format: [p(class0), p(class1)] with sum = 1.0")
        print(f"  Training mode: FULL MODEL TRAINING (backbone + PSA + custom head)")
        print(f"  Attention mechanism: PSA for multi-scale feature enhancement!")
        
    def forward(self, x):
        # Extract features using backbone
        features = self.backbone.forward_features(x)  # [B, C, H, W]
        
        # Apply PSA before classification
        features = self.psa(features)  # [B, C, H, W] with pyramid split attention
        
        # Apply GAP + Classification
        output = self.classifier(features)
        return output
    
    def predict_proba(self, x):
        """
        Returns the probability distribution (already Softmax activated)
        """
        with torch.no_grad():
            return self.forward(x)
    
    def predict(self, x):
        """
        Returns predicted class (argmax of probabilities)
        """
        with torch.no_grad():
            probs = self.forward(x)
            return torch.argmax(probs, dim=1)

# %%
import timm
import time

# Create DenseNet-121 model instance with PSA
print("🚀 Creating DenseNet-121 model with PSA + GAP + Full Training...")

# Instantiate model with DenseNet-121 and PSA
model = MitosisClassifier(
    model_name='densenet121', 
    num_classes=NUM_CLASSES, 
    pretrained=True  # Will automatically download ImageNet weights
)

# Move model to device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# Calculate parameters
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"\n📊 DENSENET-121 + PSA MODEL SUMMARY:")
print(f"  Total parameters: {total_params:,}")
print(f"  Trainable parameters: {trainable_params:,}")
print(f"  Non-trainable parameters: {total_params - trainable_params:,}")
print(f"  Training mode: FULL MODEL TRAINING (All parameters trainable)")
print(f"  Device: {device}")
print(f"  Model architecture: DenseNet-121 -> PSA -> GAP -> Custom Head")
print(f"  Attention mechanism: Pyramid Split Attention ⭐")

# Detailed architecture inspection
print(f"\n🔍 DETAILED ARCHITECTURE INSPECTION:")
print(f"  📦 Backbone: DenseNet-121 ({sum(p.numel() for p in model.backbone.parameters()):,} parameters)")
print(f"  🔍 PSA Block: {sum(p.numel() for p in model.psa.parameters()):,} parameters")
print(f"  🎯 Custom Head: {sum(p.numel() for p in model.classifier.parameters()):,} parameters")

print(f"\n✅ Model ready for training with PSA attention mechanism!")
print(f"   PSA provides multi-scale feature processing with pyramid attention")
# Out:
# 🚀 Creating DenseNet-121 model with PSA + GAP + Full Training...
# 🏗️ Creating densenet121 model with PSA + GAP + Full Model Training...
# 📥 Downloading ImageNet pretrained weights for densenet121...
# model.safetensors:   0%|          | 0.00/32.3M [00:00<?, ?B/s]
# ✅ Pretrained weights downloaded and loaded successfully!
# 📊 DenseNet backbone feature dimension: 1024
#
# 🔍 Adding PSA (Pyramid Split Attention) block...
#   • PSA groups: 4, group_channels: 256
#   • Multi-scale kernels: [3, 5, 7, 9]
#   • Reduction ratio: 4
#   • Input/Output channels: 1024
# ✅ PSA block integrated!
#    • Channel dimension: 1024
#    • Multi-scale pyramid processing with groups
#    • Soft attention fusion across scales
#    • Focus on multi-scale feature relationships
#
# 🔓 ENABLING FULL MODEL TRAINING - All parameters trainable!
# ✅ FULL MODEL TRAINING: Entire DenseNet-121 + PSA + Custom Head will be trained
#
# 🎯 Custom classifier head created (PSA + GAP approach):
#   Architecture: DenseNet-121 -> PSA -> GAP -> Custom Head
#   PSA: Pyramid Split Attention with multi-scale processing ⭐
#   Global Average Pooling: ✅ (reduces overfitting)
#   Final activation: Softmax (probability output)
#   Output format: [p(class0), p(class1)] with sum = 1.0
#   Training mode: FULL MODEL TRAINING (backbone + PSA + custom head)
#   Attention mechanism: PSA for multi-scale feature enhancement!
#
# 📊 DENSENET-121 + PSA MODEL SUMMARY:
#   Total parameters: 9,003,778
#   Trainable parameters: 9,003,778
#   Non-trainable parameters: 0
#   Training mode: FULL MODEL TRAINING (All parameters trainable)
#   Device: cuda
#   Model architecture: DenseNet-121 -> PSA -> GAP -> Custom Head
#   Attention mechanism: Pyramid Split Attention ⭐
#
# 🔍 DETAILED ARCHITECTURE INSPECTION:
#   📦 Backbone: DenseNet-121 (6,953,856 parameters)
#   🔍 PSA Block: 307,200 parameters
#   🎯 Custom Head: 1,742,722 parameters
#
# ✅ Model ready for training with PSA attention mechanism!
#    PSA provides multi-scale feature processing with pyramid attention

# %% [markdown]
# ## Model Training

# %%
class FocalLoss(nn.Module):
    """
    Focal Loss implementation for handling class imbalance.
    
    Focal Loss = -alpha * (1-p_t)^gamma * log(p_t)
    
    Args:
        alpha (float): Weighting factor for rare class (default: 1.0)
        gamma (float): Focusing parameter (default: 2.0)
        reduction (str): Specifies reduction to apply to output ('mean', 'sum', 'none')
    """
    
    def __init__(self, alpha=1.0, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        
    def forward(self, inputs, targets):
        """
        Forward pass of Focal Loss
        
        Args:
            inputs: Predictions from model (before softmax) [batch_size, num_classes]
            targets: Ground truth labels [batch_size]
        
        Returns:
            Focal loss value
        """
        # Apply softmax to get probabilities
        ce_loss = nn.functional.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)  # pt = p_t (probability of true class)
        
        # Calculate focal loss: -alpha * (1-pt)^gamma * log(pt)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss
        
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# Calculate class frequencies for Focal Loss alpha parameter
print("📊 Calculating class distribution for Focal Loss configuration...")

class_counts = train_df['label'].value_counts().sort_index()
total_samples = len(train_df)

print(f"Class distribution analysis:")
for i, count in enumerate(class_counts):
    class_name = "Normal" if i == 0 else "Atypical"
    percentage = (count / total_samples) * 100
    print(f"  Class {i} ({class_name}): {count} samples ({percentage:.1f}%)")

# Calculate alpha for focal loss (inverse frequency ratio)
normal_count = class_counts[0]
atypical_count = class_counts[1]
alpha_focal = normal_count / atypical_count  # Higher weight for minority class

print(f"\n🎯 Focal Loss Configuration:")
print(f"  Alpha (class weighting): {alpha_focal:.3f}")
print(f"  Gamma (focusing parameter): 2.0 (standard)")
print(f"  Focus: Higher weight on hard-to-classify samples")
print(f"  Benefit: Addresses both class imbalance and hard examples")

print(f"\n✅ Focal Loss class implemented and configured!")
print(f"  • Handles class imbalance with alpha parameter")
print(f"  • Focuses on hard examples with gamma parameter")
print(f"  • Can work with or without WeightedRandomSampler")
print(f"  • Better than standard CrossEntropyLoss for imbalanced data")
# Out:
# 📊 Calculating class distribution for Focal Loss configuration...
# Class distribution analysis:
#   Class 0 (Normal): 7056 samples (51.9%)
#   Class 1 (Atypical): 6530 samples (48.1%)
#
# 🎯 Focal Loss Configuration:
#   Alpha (class weighting): 1.081
#   Gamma (focusing parameter): 2.0 (standard)
#   Focus: Higher weight on hard-to-classify samples
#   Benefit: Addresses both class imbalance and hard examples
#
# ✅ Focal Loss class implemented and configured!
#   • Handles class imbalance with alpha parameter
#   • Focuses on hard examples with gamma parameter
#   • Can work with or without WeightedRandomSampler
#   • Better than standard CrossEntropyLoss for imbalanced data

# %%
# Training function (optimized for CPU with immediate feedback)
def train_epoch(model, train_loader, criterion, optimizer, device, epoch_num=None):
    import time
    
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    epoch_start = time.time()
    
    print(f"  📊 Starting training with {len(train_loader)} batches...")
    
    for batch_idx, (data, target) in enumerate(train_loader):
        batch_start = time.time()
        
        data, target = data.to(device), target.to(device)
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = torch.max(output.data, 1)
        total += target.size(0)
        correct += (predicted == target).sum().item()
        
        current_acc = 100. * correct / total
        batch_time = time.time() - batch_start
        
        # Show progress more frequently for first few batches, then every 10 batches
        show_progress = (
            batch_idx < 5 or  # First 5 batches
            batch_idx % 10 == 0 or  # Every 10th batch
            batch_idx == len(train_loader) - 1  # Last batch
        )
        
        if show_progress:
            elapsed = time.time() - epoch_start
            progress_pct = (batch_idx + 1) / len(train_loader) * 100
            eta = elapsed / (batch_idx + 1) * len(train_loader) - elapsed
            
            print(f'  ⚡ Batch {batch_idx+1:3d}/{len(train_loader)} ({progress_pct:5.1f}%) | '
                  f'Loss: {loss.item():.4f} | Acc: {current_acc:5.2f}% | '
                  f'Time: {batch_time:.2f}s | ETA: {eta/60:.1f}min')
    
    epoch_loss = running_loss / len(train_loader)
    epoch_acc = 100. * correct / total
    total_time = time.time() - epoch_start
    
    print(f'  ✅ Training complete! Total time: {total_time/60:.1f}min, Avg batch: {total_time/len(train_loader):.2f}s')
    
    return epoch_loss, epoch_acc

# Validation function (optimized for CPU with immediate feedback)
def validate_epoch(model, val_loader, criterion, device, epoch_num=None):
    import time
    
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    all_preds = []
    all_targets = []
    epoch_start = time.time()
    
    print(f"  📊 Starting validation with {len(val_loader)} batches...")
    
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(val_loader):
            batch_start = time.time()
            
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            
            running_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            
            all_preds.extend(predicted.cpu().numpy())
            all_targets.extend(target.cpu().numpy())
            
            current_acc = 100. * correct / total
            batch_time = time.time() - batch_start
            
            # Show progress for first few batches and every 5th batch
            show_progress = (
                batch_idx < 3 or  # First 3 batches
                batch_idx % 5 == 0 or  # Every 5th batch
                batch_idx == len(val_loader) - 1  # Last batch
            )
            
            if show_progress:
                elapsed = time.time() - epoch_start
                progress_pct = (batch_idx + 1) / len(val_loader) * 100
                
                print(f'  🔍 Val Batch {batch_idx+1:2d}/{len(val_loader)} ({progress_pct:5.1f}%) | '
                      f'Loss: {loss.item():.4f} | Acc: {current_acc:5.2f}% | '
                      f'Time: {batch_time:.2f}s')
    
    epoch_loss = running_loss / len(val_loader)
    epoch_acc = 100. * correct / total
    total_time = time.time() - epoch_start
    
    print(f'  ✅ Validation complete! Total time: {total_time:.1f}s, Avg batch: {total_time/len(val_loader):.2f}s')
    
    return epoch_loss, epoch_acc, all_preds, all_targets

# %%
# Training loop - Full Model Training with DenseNet-121 + ECA + Focal Loss
print("Setting up Full Model Training with ECA...")
print("="*80)
print("🎯 FULL MODEL TRAINING APPROACH:")
print("  • DenseNet-121 Backbone: Fully trainable")
print("  • ECA: Efficient Channel Attention")
print("  • Custom Classifier: GAP + Dense layers")
print("  • All parameters will be trained end-to-end")
print("="*80)

# Define loss function - Using Focal Loss for better class imbalance handling
criterion = FocalLoss(alpha=alpha_focal, gamma=2.0, reduction='mean')
print(f"\nLoss function: Focal Loss (alpha={alpha_focal:.3f}, gamma=2.0)")
print(f"  • Focal Loss handles class imbalance AND hard examples")
print(f"  • Alpha={alpha_focal:.3f} gives higher weight to minority class")
print(f"  • Gamma=2.0 focuses on hard-to-classify samples")

# Training tracking
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
best_val_loss = float('inf')
best_val_acc = 0.0
patience_counter = 0
patience = 10

# Training parameters for full model training
TOTAL_EPOCHS = 50
LEARNING_RATE = 1e-4  # Lower LR for full model training with pretrained weights

start_time = time.time()
print(f"\n🎯 Starting Full Model Training:")
print(f"  • Model: {model.__class__.__name__} (DenseNet-121 + ECA)")
print(f"  • Total Epochs: {TOTAL_EPOCHS}")  
print(f"  • Learning Rate: {LEARNING_RATE}")
print(f"  • Early Stopping Patience: {patience}")
print(f"  • Architecture: DenseNet-121 -> ECA -> GAP -> Custom Head")
print(f"  • Attention: ECA (Efficient Channel Attention) ⭐")
print(f"  • Training approach: Full model (backbone + attention + classifier)")

# FULL MODEL TRAINING WITH ECA
print(f"\n  ATTENTION MECHANISM DETAILS:")
print(f"  • ECA: Efficient Channel Attention")
print(f"  • Minimal parameters compared to self-attention")
print(f"  • Adaptive kernel size based on channel count")
print(f"  • Focus on inter-channel relationships")
print(f"  • No spatial dimension reduction")

print(f"\n📊 Model Parameter Summary:")
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"  • Total parameters: {total_params:,}")
print(f"  • Trainable parameters: {trainable_params:,}")
print(f"  • Trainable percentage: {trainable_params/total_params*100:.1f}%")
print(f"  • Architecture: DenseNet-121 + ECA + Custom Head")

# Optimizer and Scheduler for full model training
optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)

print(f"\n✅ Training Setup Complete:")
print(f"  Optimizer: AdamW (LR={LEARNING_RATE}, weight_decay=1e-4)")
print(f"  Scheduler: ReduceLROnPlateau (factor=0.5, patience=5)")
print(f"  All model parameters will be trained")

for epoch in range(TOTAL_EPOCHS):
    epoch_start_time = time.time()
    print(f'\n📍 Epoch {epoch+1}/{TOTAL_EPOCHS}')
    print('-' * 50)
    
    # Training phase
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device, epoch+1)
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    
    # Validation phase
    val_loss, val_acc, val_preds, val_targets = validate_epoch(model, val_loader, criterion, device, epoch+1)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)
    
    # Step the scheduler
    scheduler.step(val_loss)
    current_lr = optimizer.param_groups[0]['lr']
    epoch_time = time.time() - epoch_start_time
    
    print(f'\n📊 Epoch {epoch+1} Summary:')
    print(f'  Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%')
    print(f'  Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')
    print(f'  Learning Rate: {current_lr:.6f}')
    print(f'  Epoch Time: {epoch_time:.1f}s')
    
    # Save best model based on validation loss
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_val_acc = val_acc
        patience_counter = 0
        
        # Save checkpoint
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
            'best_val_acc': best_val_acc,
            'train_losses': train_losses,
            'val_losses': val_losses,
            'train_accuracies': train_accuracies,
            'val_accuracies': val_accuracies
        }, 'best_model_densenet121_eca_gap.pth')
        
        print(f'  ✅ Best model saved! Val Loss: {best_val_loss:.4f}, Val Acc: {best_val_acc:.2f}%')
        print(f'  ⭐ ECA providing efficient channel attention!')
    else:
        patience_counter += 1
        print(f'  No improvement. Patience: {patience_counter}/{patience}')
        
        if patience_counter >= patience:
            print(f'\n⏹️  Early stopping triggered after {epoch + 1} epochs')
            print(f'  Best Val Loss: {best_val_loss:.4f}')
            print(f'  Best Val Acc: {best_val_acc:.2f}%')
            break

training_time = time.time() - start_time
print(f"\n{'='*80}")
print(f"✅ TRAINING COMPLETED!")
print(f"{'='*80}")
print(f"  Total training time: {training_time/60:.2f} minutes")
print(f"  Best validation loss: {best_val_loss:.4f}")
print(f"  Best validation accuracy: {best_val_acc:.2f}%")
print(f"  Architecture: DenseNet-121 + ECA + GAP")
print(f"  Attention: Efficient Channel Attention ⭐")
print(f"  Training mode: Full model (backbone + ECA + classifier)")

# Save final results
results_summary = {
    'model': 'DenseNet-121 + ECA',
    'total_epochs': len(train_losses),
    'best_val_loss': best_val_loss,
    'best_val_acc': best_val_acc,
    'train_losses': train_losses,
    'val_losses': val_losses,
    'train_accuracies': train_accuracies,
    'val_accuracies': val_accuracies,
    'training_time_minutes': training_time/60
}

# Load best model for evaluation
print(f"\n📂 Loading best trained model for evaluation...")
checkpoint = torch.load('best_model_densenet121_eca_gap.pth')
model.load_state_dict(checkpoint['model_state_dict'])
print(f"✅ Best model loaded! Val Loss: {checkpoint['best_val_loss']:.4f}, Val Acc: {checkpoint['best_val_acc']:.2f}%")
# Out:
# Setting up Full Model Training with ECA...
# ================================================================================
# 🎯 FULL MODEL TRAINING APPROACH:
#   • DenseNet-121 Backbone: Fully trainable
#   • ECA: Efficient Channel Attention
#   • Custom Classifier: GAP + Dense layers
#   • All parameters will be trained end-to-end
# ================================================================================
#
# Loss function: Focal Loss (alpha=1.081, gamma=2.0)
#   • Focal Loss handles class imbalance AND hard examples
#   • Alpha=1.081 gives higher weight to minority class
#   • Gamma=2.0 focuses on hard-to-classify samples
#
# 🎯 Starting Full Model Training:
#   • Model: MitosisClassifier (DenseNet-121 + ECA)
#   • Total Epochs: 50
#   • Learning Rate: 0.0001
#   • Early Stopping Patience: 10
#   • Architecture: DenseNet-121 -> ECA -> GAP -> Custom Head
#   • Attention: ECA (Efficient Channel Attention) ⭐
#   • Training approach: Full model (backbone + attention + classifier)
#
#   ATTENTION MECHANISM DETAILS:
#   • ECA: Efficient Channel Attention
#   • Minimal parameters compared to self-attention
#   • Adaptive kernel size based on channel count
#   • Focus on inter-channel relationships
#   • No spatial dimension reduction
#
# 📊 Model Parameter Summary:
#   • Total parameters: 9,003,778
#   • Trainable parameters: 9,003,778
#   • Trainable percentage: 100.0%
#   • Architecture: DenseNet-121 + ECA + Custom Head
#
# ✅ Training Setup Complete:
#   Optimizer: AdamW (LR=0.0001, weight_decay=1e-4)
#   Scheduler: ReduceLROnPlateau (factor=0.5, patience=5)
#   All model parameters will be trained
#
# 📍 Epoch 1/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.2248 | Acc: 53.12% | Time: 1.62s | ETA: 14.7min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.1927 | Acc: 57.81% | Time: 0.18s | ETA: 8.0min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.1922 | Acc: 55.21% | Time: 0.18s | ETA: 5.7min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.2475 | Acc: 52.34% | Time: 0.18s | ETA: 4.6min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.2294 | Acc: 51.88% | Time: 0.18s | ETA: 3.9min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.2213 | Acc: 50.57% | Time: 0.18s | ETA: 2.5min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.2137 | Acc: 51.64% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.1896 | Acc: 53.83% | Time: 0.18s | ETA: 1.6min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.1718 | Acc: 54.88% | Time: 0.18s | ETA: 1.5min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.1910 | Acc: 55.51% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.1840 | Acc: 56.51% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.1696 | Acc: 57.09% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.1705 | Acc: 57.52% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1754 | Acc: 57.97% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.1859 | Acc: 58.29% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.1844 | Acc: 59.01% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.1584 | Acc: 59.53% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.1784 | Acc: 59.85% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.1563 | Acc: 60.39% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.1564 | Acc: 60.53% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.2031 | Acc: 60.97% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.2438 | Acc: 60.82% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.2030 | Acc: 61.12% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.1370 | Acc: 61.47% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.1631 | Acc: 61.86% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.1896 | Acc: 62.19% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.1401 | Acc: 62.66% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.1580 | Acc: 63.05% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.1627 | Acc: 63.28% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.1325 | Acc: 63.53% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.1628 | Acc: 63.66% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.1379 | Acc: 63.85% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.1252 | Acc: 64.09% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.1501 | Acc: 64.49% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.1500 | Acc: 64.60% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.1599 | Acc: 64.73% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.1332 | Acc: 64.95% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.1330 | Acc: 65.07% | Time: 0.19s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.1412 | Acc: 65.22% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.1966 | Acc: 65.35% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.1963 | Acc: 65.43% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.1752 | Acc: 65.60% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.1349 | Acc: 65.72% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.1639 | Acc: 65.78% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.1616 | Acc: 65.99% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.1582 | Acc: 66.19% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.1479 | Acc: 66.38% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1474 | Acc: 66.41% | Time: 0.21s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.1014 | Acc: 93.75% | Time: 0.07s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.1226 | Acc: 92.19% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1162 | Acc: 88.54% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1094 | Acc: 84.90% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.1016 | Acc: 85.23% | Time: 0.05s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1338 | Acc: 83.20% | Time: 0.05s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.1371 | Acc: 81.85% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.1358 | Acc: 82.09% | Time: 0.05s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1201 | Acc: 82.16% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0982 | Acc: 82.29% | Time: 0.05s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1532 | Acc: 81.55% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1309 | Acc: 81.79% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1168 | Acc: 82.17% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1097 | Acc: 82.31% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1257 | Acc: 82.02% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1429 | Acc: 81.72% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1586 | Acc: 81.38% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1178 | Acc: 81.29% | Time: 0.05s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.1331 | Acc: 81.40% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1339 | Acc: 81.50% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.1026 | Acc: 81.53% | Time: 0.10s
#   ✅ Validation complete! Total time: 14.1s, Avg batch: 0.16s
#
# 📊 Epoch 1 Summary:
#   Train Loss: 0.1668, Train Acc: 66.41%
#   Val Loss: 0.1267, Val Acc: 81.53%
#   Learning Rate: 0.000100
#   Epoch Time: 94.2s
#   ✅ Best model saved! Val Loss: 0.1267, Val Acc: 81.53%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 2/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.1295 | Acc: 71.88% | Time: 0.20s | ETA: 3.7min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.2012 | Acc: 64.06% | Time: 0.18s | ETA: 2.5min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.1445 | Acc: 66.67% | Time: 0.18s | ETA: 2.1min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.1459 | Acc: 69.53% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.1843 | Acc: 68.12% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.1436 | Acc: 72.16% | Time: 0.18s | ETA: 1.5min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.1382 | Acc: 71.88% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.1390 | Acc: 71.57% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.1585 | Acc: 71.65% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.1435 | Acc: 72.18% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.1220 | Acc: 72.03% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.1135 | Acc: 72.58% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0939 | Acc: 73.15% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1435 | Acc: 73.59% | Time: 0.19s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.1333 | Acc: 73.86% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.1407 | Acc: 73.76% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.1472 | Acc: 73.92% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.1546 | Acc: 73.74% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.1366 | Acc: 74.18% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.1615 | Acc: 74.28% | Time: 0.19s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.1231 | Acc: 74.38% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.1710 | Acc: 74.47% | Time: 0.19s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.1199 | Acc: 74.45% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0904 | Acc: 74.71% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.1496 | Acc: 74.84% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.1403 | Acc: 75.03% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.1603 | Acc: 75.03% | Time: 0.19s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.1168 | Acc: 75.28% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0995 | Acc: 75.53% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.1402 | Acc: 75.71% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.1492 | Acc: 75.84% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.1094 | Acc: 76.03% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.1154 | Acc: 76.16% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.1219 | Acc: 76.23% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0804 | Acc: 76.35% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0977 | Acc: 76.58% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.1033 | Acc: 76.79% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0996 | Acc: 76.93% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.1130 | Acc: 77.06% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0997 | Acc: 76.98% | Time: 0.19s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.1347 | Acc: 77.09% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.1456 | Acc: 77.11% | Time: 0.19s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.1334 | Acc: 77.17% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.1411 | Acc: 77.32% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.1149 | Acc: 77.42% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.1450 | Acc: 77.50% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.1037 | Acc: 77.58% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.1052 | Acc: 77.63% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0809 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.1023 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.0795 | Acc: 88.54% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.0880 | Acc: 89.06% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0865 | Acc: 89.49% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1174 | Acc: 87.70% | Time: 0.05s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.1147 | Acc: 87.35% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.1060 | Acc: 87.26% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1143 | Acc: 87.40% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0628 | Acc: 86.81% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1170 | Acc: 86.36% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1385 | Acc: 86.35% | Time: 0.05s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1085 | Acc: 86.58% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.0993 | Acc: 86.72% | Time: 0.05s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.0787 | Acc: 86.73% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1125 | Acc: 86.88% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1280 | Acc: 86.44% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1025 | Acc: 86.31% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0866 | Acc: 86.42% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1183 | Acc: 86.37% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.1090 | Acc: 86.26% | Time: 0.02s
#   ✅ Validation complete! Total time: 7.3s, Avg batch: 0.08s
#
# 📊 Epoch 2 Summary:
#   Train Loss: 0.1318, Train Acc: 77.63%
#   Val Loss: 0.1011, Val Acc: 86.26%
#   Learning Rate: 0.000100
#   Epoch Time: 86.0s
#   ✅ Best model saved! Val Loss: 0.1011, Val Acc: 86.26%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 3/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.1200 | Acc: 81.25% | Time: 0.19s | ETA: 3.7min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.1788 | Acc: 73.44% | Time: 0.18s | ETA: 2.5min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.1278 | Acc: 75.00% | Time: 0.18s | ETA: 2.1min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0967 | Acc: 78.91% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.1033 | Acc: 80.62% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.1072 | Acc: 82.39% | Time: 0.18s | ETA: 1.5min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.1559 | Acc: 80.51% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.1348 | Acc: 81.15% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.1021 | Acc: 81.71% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0916 | Acc: 82.29% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0623 | Acc: 82.68% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.1178 | Acc: 82.61% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.1078 | Acc: 82.68% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.0962 | Acc: 82.90% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0926 | Acc: 83.23% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0822 | Acc: 83.64% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.1195 | Acc: 83.55% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.1190 | Acc: 83.61% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0599 | Acc: 83.64% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.1213 | Acc: 83.71% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.1177 | Acc: 83.70% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0858 | Acc: 83.77% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0804 | Acc: 83.82% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.1574 | Acc: 83.72% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0644 | Acc: 83.89% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.1246 | Acc: 83.81% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0977 | Acc: 83.98% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.1248 | Acc: 83.97% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.1344 | Acc: 83.99% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0790 | Acc: 84.10% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0950 | Acc: 84.10% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0878 | Acc: 84.21% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0923 | Acc: 84.40% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0671 | Acc: 84.55% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.1126 | Acc: 84.67% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0782 | Acc: 84.85% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0901 | Acc: 84.91% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.1401 | Acc: 84.90% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0466 | Acc: 85.01% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0730 | Acc: 85.06% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0904 | Acc: 85.18% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0758 | Acc: 85.30% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0519 | Acc: 85.34% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0849 | Acc: 85.43% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0916 | Acc: 85.48% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.1231 | Acc: 85.58% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0836 | Acc: 85.58% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0879 | Acc: 85.57% | Time: 0.11s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.18s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0739 | Acc: 93.75% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0809 | Acc: 92.19% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.0952 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1002 | Acc: 88.02% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0811 | Acc: 88.64% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1184 | Acc: 87.30% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0842 | Acc: 86.46% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0906 | Acc: 86.30% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1083 | Acc: 86.59% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0746 | Acc: 86.11% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1212 | Acc: 85.52% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1097 | Acc: 85.94% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.0954 | Acc: 86.27% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1142 | Acc: 86.33% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1021 | Acc: 86.27% | Time: 0.05s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1077 | Acc: 86.41% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1343 | Acc: 86.22% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.0829 | Acc: 85.98% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0895 | Acc: 86.00% | Time: 0.05s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0985 | Acc: 85.97% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0596 | Acc: 85.90% | Time: 0.02s
#   ✅ Validation complete! Total time: 6.6s, Avg batch: 0.08s
#
# 📊 Epoch 3 Summary:
#   Train Loss: 0.0998, Train Acc: 85.57%
#   Val Loss: 0.0944, Val Acc: 85.90%
#   Learning Rate: 0.000100
#   Epoch Time: 85.2s
#   ✅ Best model saved! Val Loss: 0.0944, Val Acc: 85.90%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 4/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0917 | Acc: 87.50% | Time: 0.20s | ETA: 3.2min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0626 | Acc: 89.06% | Time: 0.18s | ETA: 2.2min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0740 | Acc: 90.62% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0816 | Acc: 89.84% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.1281 | Acc: 87.50% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0803 | Acc: 88.64% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0766 | Acc: 87.80% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0854 | Acc: 87.80% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.1076 | Acc: 86.97% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0793 | Acc: 87.01% | Time: 0.19s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0709 | Acc: 87.09% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0830 | Acc: 87.28% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0856 | Acc: 86.77% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1018 | Acc: 87.02% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0565 | Acc: 87.47% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0548 | Acc: 87.73% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0707 | Acc: 87.76% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0724 | Acc: 88.07% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0781 | Acc: 88.25% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0550 | Acc: 88.66% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0752 | Acc: 88.68% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0563 | Acc: 88.87% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0530 | Acc: 89.04% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0824 | Acc: 89.12% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0593 | Acc: 89.19% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0899 | Acc: 89.17% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0349 | Acc: 89.25% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.1093 | Acc: 89.22% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0557 | Acc: 89.30% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.1207 | Acc: 89.29% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0572 | Acc: 89.34% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0532 | Acc: 89.37% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.1015 | Acc: 89.42% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0589 | Acc: 89.48% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0718 | Acc: 89.57% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0833 | Acc: 89.61% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.1183 | Acc: 89.59% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.1237 | Acc: 89.58% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0544 | Acc: 89.66% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0586 | Acc: 89.65% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0638 | Acc: 89.59% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0773 | Acc: 89.60% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.1065 | Acc: 89.58% | Time: 0.19s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0529 | Acc: 89.63% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0639 | Acc: 89.75% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0620 | Acc: 89.72% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0548 | Acc: 89.72% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0368 | Acc: 89.72% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0684 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0972 | Acc: 89.06% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.0828 | Acc: 89.58% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.0887 | Acc: 91.15% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0965 | Acc: 88.64% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1435 | Acc: 86.33% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0803 | Acc: 86.31% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0934 | Acc: 86.54% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1037 | Acc: 87.20% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0802 | Acc: 86.81% | Time: 0.05s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1170 | Acc: 86.20% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1218 | Acc: 86.55% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1089 | Acc: 86.89% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1191 | Acc: 87.00% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1071 | Acc: 86.89% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1099 | Acc: 87.17% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1181 | Acc: 87.02% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.1185 | Acc: 86.97% | Time: 0.05s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0926 | Acc: 87.04% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0876 | Acc: 87.14% | Time: 0.05s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0661 | Acc: 87.09% | Time: 0.02s
#   ✅ Validation complete! Total time: 7.0s, Avg batch: 0.08s
#
# 📊 Epoch 4 Summary:
#   Train Loss: 0.0795, Train Acc: 89.72%
#   Val Loss: 0.0944, Val Acc: 87.09%
#   Learning Rate: 0.000100
#   Epoch Time: 85.8s
#   No improvement. Patience: 1/10
#
# 📍 Epoch 5/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0886 | Acc: 78.12% | Time: 0.21s | ETA: 3.3min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0522 | Acc: 84.38% | Time: 0.18s | ETA: 2.3min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0724 | Acc: 86.46% | Time: 0.18s | ETA: 2.0min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0345 | Acc: 89.84% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.0774 | Acc: 90.00% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0333 | Acc: 90.34% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.1318 | Acc: 90.48% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.1232 | Acc: 90.02% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0534 | Acc: 89.79% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0645 | Acc: 89.83% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0822 | Acc: 89.70% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0957 | Acc: 89.92% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0868 | Acc: 89.89% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.0687 | Acc: 89.94% | Time: 0.19s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0847 | Acc: 90.07% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0514 | Acc: 90.26% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0466 | Acc: 90.39% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0438 | Acc: 90.60% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0730 | Acc: 90.76% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0749 | Acc: 90.81% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0450 | Acc: 90.80% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0693 | Acc: 90.84% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.1069 | Acc: 90.73% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0870 | Acc: 90.77% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0576 | Acc: 90.83% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0989 | Acc: 90.77% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0708 | Acc: 90.88% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0482 | Acc: 90.96% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0636 | Acc: 90.98% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0922 | Acc: 90.92% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0586 | Acc: 90.97% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0357 | Acc: 91.06% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0537 | Acc: 91.11% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0615 | Acc: 91.14% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0490 | Acc: 91.06% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0552 | Acc: 91.22% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0596 | Acc: 91.07% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0735 | Acc: 91.14% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0715 | Acc: 91.17% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0853 | Acc: 91.24% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0555 | Acc: 91.32% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0327 | Acc: 91.34% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0713 | Acc: 91.40% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0729 | Acc: 91.42% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0423 | Acc: 91.39% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0647 | Acc: 91.40% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0478 | Acc: 91.43% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0698 | Acc: 91.42% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.18s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0588 | Acc: 93.75% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0673 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.0777 | Acc: 91.67% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.0934 | Acc: 91.15% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0970 | Acc: 90.06% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1319 | Acc: 89.26% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0664 | Acc: 88.99% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.1070 | Acc: 89.06% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1470 | Acc: 89.01% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0791 | Acc: 88.37% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1061 | Acc: 87.88% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1581 | Acc: 87.91% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1058 | Acc: 88.05% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1034 | Acc: 88.28% | Time: 0.05s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.0900 | Acc: 88.17% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1267 | Acc: 88.21% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1188 | Acc: 87.98% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.0744 | Acc: 88.08% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0854 | Acc: 88.16% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0729 | Acc: 88.23% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0602 | Acc: 88.09% | Time: 0.02s
#   ✅ Validation complete! Total time: 6.6s, Avg batch: 0.08s
#
# 📊 Epoch 5 Summary:
#   Train Loss: 0.0717, Train Acc: 91.42%
#   Val Loss: 0.0904, Val Acc: 88.09%
#   Learning Rate: 0.000100
#   Epoch Time: 85.2s
#   ✅ Best model saved! Val Loss: 0.0904, Val Acc: 88.09%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 6/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0855 | Acc: 90.62% | Time: 0.19s | ETA: 3.3min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0633 | Acc: 90.62% | Time: 0.18s | ETA: 2.3min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0559 | Acc: 92.71% | Time: 0.18s | ETA: 2.0min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0461 | Acc: 92.97% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.0582 | Acc: 93.75% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0449 | Acc: 93.75% | Time: 0.18s | ETA: 1.5min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0360 | Acc: 93.60% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0518 | Acc: 92.44% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0769 | Acc: 92.23% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0642 | Acc: 91.97% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0712 | Acc: 92.16% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.1056 | Acc: 92.25% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0391 | Acc: 92.09% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.0625 | Acc: 92.34% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0930 | Acc: 92.26% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0551 | Acc: 92.29% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0640 | Acc: 92.43% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0745 | Acc: 92.13% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0542 | Acc: 92.07% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0725 | Acc: 92.16% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0409 | Acc: 92.18% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0829 | Acc: 92.09% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0742 | Acc: 92.18% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0553 | Acc: 92.28% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0561 | Acc: 92.29% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0425 | Acc: 92.36% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0391 | Acc: 92.34% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0437 | Acc: 92.30% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0413 | Acc: 92.36% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0623 | Acc: 92.43% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0788 | Acc: 92.55% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.1402 | Acc: 92.56% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0483 | Acc: 92.57% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0577 | Acc: 92.68% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0916 | Acc: 92.72% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0551 | Acc: 92.73% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0446 | Acc: 92.75% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0440 | Acc: 92.83% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0509 | Acc: 92.90% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0588 | Acc: 92.94% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0680 | Acc: 92.86% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0606 | Acc: 92.85% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0486 | Acc: 92.88% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0709 | Acc: 92.80% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0653 | Acc: 92.89% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0783 | Acc: 92.93% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0642 | Acc: 92.93% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0297 | Acc: 92.93% | Time: 0.11s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.18s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0547 | Acc: 93.75% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0756 | Acc: 92.19% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1383 | Acc: 89.58% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.0680 | Acc: 91.15% | Time: 0.05s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0959 | Acc: 89.49% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1267 | Acc: 88.09% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0892 | Acc: 87.95% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0689 | Acc: 87.86% | Time: 0.05s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1386 | Acc: 88.00% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.1091 | Acc: 87.33% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.0982 | Acc: 87.12% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1349 | Acc: 87.23% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.0873 | Acc: 87.25% | Time: 0.05s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1308 | Acc: 87.28% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1159 | Acc: 87.40% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1271 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1206 | Acc: 87.28% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.0684 | Acc: 87.13% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0777 | Acc: 87.15% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0709 | Acc: 87.46% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0413 | Acc: 87.48% | Time: 0.02s
#   ✅ Validation complete! Total time: 6.7s, Avg batch: 0.08s
#
# 📊 Epoch 6 Summary:
#   Train Loss: 0.0637, Train Acc: 92.93%
#   Val Loss: 0.0939, Val Acc: 87.48%
#   Learning Rate: 0.000100
#   Epoch Time: 85.3s
#   No improvement. Patience: 1/10
#
# 📍 Epoch 7/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0312 | Acc: 100.00% | Time: 0.20s | ETA: 3.1min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0855 | Acc: 93.75% | Time: 0.18s | ETA: 2.2min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.1061 | Acc: 90.62% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0323 | Acc: 92.97% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.0818 | Acc: 91.88% | Time: 0.18s | ETA: 1.6min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0513 | Acc: 92.61% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0312 | Acc: 93.60% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0546 | Acc: 93.85% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0845 | Acc: 93.67% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0445 | Acc: 93.81% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0981 | Acc: 93.65% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0856 | Acc: 93.49% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0987 | Acc: 93.48% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.0340 | Acc: 93.54% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0455 | Acc: 93.69% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0612 | Acc: 93.86% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0555 | Acc: 94.16% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0522 | Acc: 94.16% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0874 | Acc: 94.19% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0528 | Acc: 94.21% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0710 | Acc: 94.08% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0340 | Acc: 94.04% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0562 | Acc: 94.08% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0868 | Acc: 94.11% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0640 | Acc: 94.09% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0389 | Acc: 93.99% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0325 | Acc: 93.99% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0781 | Acc: 93.95% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0557 | Acc: 93.88% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0352 | Acc: 93.97% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0663 | Acc: 94.07% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0503 | Acc: 94.08% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0512 | Acc: 94.05% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0704 | Acc: 94.08% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0722 | Acc: 94.05% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0495 | Acc: 94.06% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0327 | Acc: 94.12% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0484 | Acc: 94.12% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0721 | Acc: 94.11% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0295 | Acc: 94.09% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0509 | Acc: 94.09% | Time: 0.19s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0558 | Acc: 94.09% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.1665 | Acc: 94.05% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0497 | Acc: 94.07% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0567 | Acc: 94.07% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0619 | Acc: 94.09% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0451 | Acc: 94.11% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0893 | Acc: 94.13% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.18s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0867 | Acc: 87.50% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0680 | Acc: 89.06% | Time: 0.05s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.0795 | Acc: 88.54% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.0718 | Acc: 88.54% | Time: 0.05s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0868 | Acc: 87.50% | Time: 0.05s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1084 | Acc: 87.30% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0581 | Acc: 87.80% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.1036 | Acc: 87.98% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1021 | Acc: 88.71% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0591 | Acc: 88.54% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1168 | Acc: 87.88% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1014 | Acc: 87.84% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.0883 | Acc: 87.87% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.0939 | Acc: 88.23% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1343 | Acc: 88.22% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.1295 | Acc: 88.12% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1090 | Acc: 88.20% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.0953 | Acc: 88.08% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0942 | Acc: 88.19% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0861 | Acc: 88.37% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0312 | Acc: 88.34% | Time: 0.02s
#   ✅ Validation complete! Total time: 6.6s, Avg batch: 0.08s
#
# 📊 Epoch 7 Summary:
#   Train Loss: 0.0575, Train Acc: 94.13%
#   Val Loss: 0.0889, Val Acc: 88.34%
#   Learning Rate: 0.000100
#   Epoch Time: 85.2s
#   ✅ Best model saved! Val Loss: 0.0889, Val Acc: 88.34%
#   ⭐ ECA providing efficient channel attention!
#
# 📍 Epoch 8/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0566 | Acc: 90.62% | Time: 0.20s | ETA: 3.3min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0391 | Acc: 95.31% | Time: 0.18s | ETA: 2.3min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0377 | Acc: 95.83% | Time: 0.18s | ETA: 2.0min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0858 | Acc: 94.53% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.0450 | Acc: 95.00% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0564 | Acc: 94.03% | Time: 0.18s | ETA: 1.5min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0542 | Acc: 94.94% | Time: 0.19s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0469 | Acc: 94.15% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0433 | Acc: 94.74% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0400 | Acc: 94.98% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0505 | Acc: 95.08% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0794 | Acc: 94.85% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0397 | Acc: 94.87% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.1060 | Acc: 94.81% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0951 | Acc: 94.83% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0404 | Acc: 94.90% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0433 | Acc: 94.78% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0738 | Acc: 94.66% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0285 | Acc: 94.86% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0842 | Acc: 94.91% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0550 | Acc: 95.05% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0330 | Acc: 95.25% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0279 | Acc: 95.37% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0409 | Acc: 95.40% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0285 | Acc: 95.46% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0396 | Acc: 95.47% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0520 | Acc: 95.38% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0409 | Acc: 95.40% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0709 | Acc: 95.40% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0350 | Acc: 95.37% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0320 | Acc: 95.43% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0366 | Acc: 95.43% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0444 | Acc: 95.44% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0631 | Acc: 95.47% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0274 | Acc: 95.44% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0715 | Acc: 95.43% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0419 | Acc: 95.36% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0976 | Acc: 95.33% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0291 | Acc: 95.33% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0445 | Acc: 95.34% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0620 | Acc: 95.32% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0495 | Acc: 95.37% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0716 | Acc: 95.29% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0682 | Acc: 95.32% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.1007 | Acc: 95.32% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0307 | Acc: 95.34% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0537 | Acc: 95.32% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0259 | Acc: 95.33% | Time: 0.12s | ETA: 0.0min
# ...
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0265 | Acc: 98.50% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0253 | Acc: 98.47% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0264 | Acc: 98.45% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0376 | Acc: 98.46% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0256 | Acc: 98.46% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0248 | Acc: 98.49% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0467 | Acc: 98.49% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0508 | Acc: 98.51% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0325 | Acc: 98.51% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0278 | Acc: 98.52% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0248 | Acc: 98.49% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0275 | Acc: 98.50% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0282 | Acc: 98.52% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0247 | Acc: 98.54% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0468 | Acc: 98.54% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0279 | Acc: 98.57% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0251 | Acc: 98.57% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0246 | Acc: 98.56% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.18s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0533 | Acc: 96.88% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0700 | Acc: 95.31% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1320 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1105 | Acc: 91.15% | Time: 0.05s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0884 | Acc: 90.34% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.0623 | Acc: 88.87% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0680 | Acc: 89.29% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.1040 | Acc: 89.42% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1231 | Acc: 89.92% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0551 | Acc: 89.58% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1575 | Acc: 89.02% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.0949 | Acc: 89.33% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.0992 | Acc: 89.40% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.0969 | Acc: 89.29% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1048 | Acc: 89.29% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.0871 | Acc: 89.54% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1325 | Acc: 89.26% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.0853 | Acc: 89.02% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0801 | Acc: 89.16% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.1113 | Acc: 88.99% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0271 | Acc: 88.99% | Time: 0.02s
#   ✅ Validation complete! Total time: 6.6s, Avg batch: 0.08s
#
# 📊 Epoch 17 Summary:
#   Train Loss: 0.0334, Train Acc: 98.56%
#   Val Loss: 0.0906, Val Acc: 88.99%
#   Learning Rate: 0.000050
#   Epoch Time: 85.2s
#   No improvement. Patience: 8/10
#
# 📍 Epoch 18/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0249 | Acc: 100.00% | Time: 0.20s | ETA: 3.3min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0250 | Acc: 100.00% | Time: 0.18s | ETA: 2.3min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0255 | Acc: 100.00% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0248 | Acc: 100.00% | Time: 0.18s | ETA: 1.8min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.0300 | Acc: 99.38% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0304 | Acc: 99.43% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0266 | Acc: 99.26% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0255 | Acc: 99.40% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0251 | Acc: 99.31% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0347 | Acc: 99.08% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0256 | Acc: 99.18% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0340 | Acc: 99.08% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0257 | Acc: 99.04% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.0252 | Acc: 99.00% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0252 | Acc: 98.92% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0475 | Acc: 98.96% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0371 | Acc: 98.94% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0412 | Acc: 98.85% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0263 | Acc: 98.80% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0249 | Acc: 98.76% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0247 | Acc: 98.74% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0256 | Acc: 98.76% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0336 | Acc: 98.79% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0305 | Acc: 98.84% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0253 | Acc: 98.83% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0247 | Acc: 98.79% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0388 | Acc: 98.78% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0252 | Acc: 98.81% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0248 | Acc: 98.81% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0554 | Acc: 98.83% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0694 | Acc: 98.77% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0248 | Acc: 98.74% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0308 | Acc: 98.79% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0250 | Acc: 98.79% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0248 | Acc: 98.80% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0261 | Acc: 98.81% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0251 | Acc: 98.83% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0247 | Acc: 98.84% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0476 | Acc: 98.84% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0647 | Acc: 98.82% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0259 | Acc: 98.83% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0696 | Acc: 98.82% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0249 | Acc: 98.85% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0346 | Acc: 98.85% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0252 | Acc: 98.84% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0302 | Acc: 98.84% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0484 | Acc: 98.82% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0247 | Acc: 98.81% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.19s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0507 | Acc: 93.75% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0330 | Acc: 95.31% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1135 | Acc: 92.71% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1214 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.0884 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.1035 | Acc: 89.26% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.0523 | Acc: 89.73% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0958 | Acc: 89.66% | Time: 0.05s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1448 | Acc: 89.82% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0681 | Acc: 89.50% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.0960 | Acc: 89.25% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.1096 | Acc: 89.47% | Time: 0.05s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.1152 | Acc: 89.40% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.0878 | Acc: 89.29% | Time: 0.05s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.0903 | Acc: 89.60% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.0747 | Acc: 89.87% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.1157 | Acc: 89.79% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.0707 | Acc: 89.68% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0492 | Acc: 89.81% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0979 | Acc: 89.72% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0604 | Acc: 89.74% | Time: 0.02s
#   ✅ Validation complete! Total time: 6.6s, Avg batch: 0.08s
#
# 📊 Epoch 18 Summary:
#   Train Loss: 0.0319, Train Acc: 98.81%
#   Val Loss: 0.0929, Val Acc: 89.74%
#   Learning Rate: 0.000050
#   Epoch Time: 85.5s
#   No improvement. Patience: 9/10
#
# 📍 Epoch 19/50
# --------------------------------------------------
#   📊 Starting training with 425 batches...
#   ⚡ Batch   1/425 (  0.2%) | Loss: 0.0250 | Acc: 100.00% | Time: 0.20s | ETA: 3.1min
#   ⚡ Batch   2/425 (  0.5%) | Loss: 0.0265 | Acc: 100.00% | Time: 0.18s | ETA: 2.2min
#   ⚡ Batch   3/425 (  0.7%) | Loss: 0.0839 | Acc: 96.88% | Time: 0.18s | ETA: 1.9min
#   ⚡ Batch   4/425 (  0.9%) | Loss: 0.0481 | Acc: 96.88% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch   5/425 (  1.2%) | Loss: 0.0558 | Acc: 96.25% | Time: 0.18s | ETA: 1.7min
#   ⚡ Batch  11/425 (  2.6%) | Loss: 0.0249 | Acc: 98.30% | Time: 0.18s | ETA: 1.4min
#   ⚡ Batch  21/425 (  4.9%) | Loss: 0.0253 | Acc: 98.07% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  31/425 (  7.3%) | Loss: 0.0903 | Acc: 97.78% | Time: 0.18s | ETA: 1.3min
#   ⚡ Batch  41/425 (  9.6%) | Loss: 0.0476 | Acc: 98.02% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  51/425 ( 12.0%) | Loss: 0.0322 | Acc: 98.10% | Time: 0.18s | ETA: 1.2min
#   ⚡ Batch  61/425 ( 14.4%) | Loss: 0.0247 | Acc: 98.21% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  71/425 ( 16.7%) | Loss: 0.0340 | Acc: 98.15% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  81/425 ( 19.1%) | Loss: 0.0247 | Acc: 98.26% | Time: 0.18s | ETA: 1.1min
#   ⚡ Batch  91/425 ( 21.4%) | Loss: 0.0477 | Acc: 98.39% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 101/425 ( 23.8%) | Loss: 0.0247 | Acc: 98.36% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 111/425 ( 26.1%) | Loss: 0.0454 | Acc: 98.40% | Time: 0.18s | ETA: 1.0min
#   ⚡ Batch 121/425 ( 28.5%) | Loss: 0.0290 | Acc: 98.40% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 131/425 ( 30.8%) | Loss: 0.0475 | Acc: 98.43% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 141/425 ( 33.2%) | Loss: 0.0269 | Acc: 98.45% | Time: 0.18s | ETA: 0.9min
#   ⚡ Batch 151/425 ( 35.5%) | Loss: 0.0267 | Acc: 98.47% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 161/425 ( 37.9%) | Loss: 0.0706 | Acc: 98.51% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 171/425 ( 40.2%) | Loss: 0.0247 | Acc: 98.52% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 181/425 ( 42.6%) | Loss: 0.0291 | Acc: 98.52% | Time: 0.18s | ETA: 0.8min
#   ⚡ Batch 191/425 ( 44.9%) | Loss: 0.0256 | Acc: 98.49% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 201/425 ( 47.3%) | Loss: 0.0302 | Acc: 98.48% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 211/425 ( 49.6%) | Loss: 0.0247 | Acc: 98.52% | Time: 0.18s | ETA: 0.7min
#   ⚡ Batch 221/425 ( 52.0%) | Loss: 0.0250 | Acc: 98.54% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 231/425 ( 54.4%) | Loss: 0.0429 | Acc: 98.57% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 241/425 ( 56.7%) | Loss: 0.0360 | Acc: 98.57% | Time: 0.18s | ETA: 0.6min
#   ⚡ Batch 251/425 ( 59.1%) | Loss: 0.0246 | Acc: 98.53% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 261/425 ( 61.4%) | Loss: 0.0465 | Acc: 98.54% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 271/425 ( 63.8%) | Loss: 0.0426 | Acc: 98.51% | Time: 0.18s | ETA: 0.5min
#   ⚡ Batch 281/425 ( 66.1%) | Loss: 0.0246 | Acc: 98.52% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 291/425 ( 68.5%) | Loss: 0.0257 | Acc: 98.53% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 301/425 ( 70.8%) | Loss: 0.0254 | Acc: 98.55% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 311/425 ( 73.2%) | Loss: 0.0248 | Acc: 98.57% | Time: 0.18s | ETA: 0.4min
#   ⚡ Batch 321/425 ( 75.5%) | Loss: 0.0248 | Acc: 98.57% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 331/425 ( 77.9%) | Loss: 0.0418 | Acc: 98.57% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 341/425 ( 80.2%) | Loss: 0.0280 | Acc: 98.59% | Time: 0.18s | ETA: 0.3min
#   ⚡ Batch 351/425 ( 82.6%) | Loss: 0.0247 | Acc: 98.60% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 361/425 ( 84.9%) | Loss: 0.0382 | Acc: 98.63% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 371/425 ( 87.3%) | Loss: 0.0247 | Acc: 98.61% | Time: 0.18s | ETA: 0.2min
#   ⚡ Batch 381/425 ( 89.6%) | Loss: 0.0248 | Acc: 98.61% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 391/425 ( 92.0%) | Loss: 0.0809 | Acc: 98.59% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 401/425 ( 94.4%) | Loss: 0.0263 | Acc: 98.59% | Time: 0.18s | ETA: 0.1min
#   ⚡ Batch 411/425 ( 96.7%) | Loss: 0.0250 | Acc: 98.60% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 421/425 ( 99.1%) | Loss: 0.0389 | Acc: 98.60% | Time: 0.18s | ETA: 0.0min
#   ⚡ Batch 425/425 (100.0%) | Loss: 0.0666 | Acc: 98.60% | Time: 0.12s | ETA: 0.0min
#   ✅ Training complete! Total time: 1.3min, Avg batch: 0.18s
#   📊 Starting validation with 88 batches...
#   🔍 Val Batch  1/88 (  1.1%) | Loss: 0.0881 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch  2/88 (  2.3%) | Loss: 0.0942 | Acc: 90.62% | Time: 0.06s
#   🔍 Val Batch  3/88 (  3.4%) | Loss: 0.1261 | Acc: 88.54% | Time: 0.06s
#   🔍 Val Batch  6/88 (  6.8%) | Loss: 0.1164 | Acc: 90.10% | Time: 0.06s
#   🔍 Val Batch 11/88 ( 12.5%) | Loss: 0.1095 | Acc: 89.49% | Time: 0.06s
#   🔍 Val Batch 16/88 ( 18.2%) | Loss: 0.0840 | Acc: 88.09% | Time: 0.06s
#   🔍 Val Batch 21/88 ( 23.9%) | Loss: 0.1000 | Acc: 88.10% | Time: 0.06s
#   🔍 Val Batch 26/88 ( 29.5%) | Loss: 0.0596 | Acc: 88.58% | Time: 0.06s
#   🔍 Val Batch 31/88 ( 35.2%) | Loss: 0.1125 | Acc: 89.01% | Time: 0.06s
#   🔍 Val Batch 36/88 ( 40.9%) | Loss: 0.0728 | Acc: 88.80% | Time: 0.06s
#   🔍 Val Batch 41/88 ( 46.6%) | Loss: 0.1560 | Acc: 88.57% | Time: 0.06s
#   🔍 Val Batch 46/88 ( 52.3%) | Loss: 0.0801 | Acc: 88.65% | Time: 0.06s
#   🔍 Val Batch 51/88 ( 58.0%) | Loss: 0.0934 | Acc: 88.79% | Time: 0.06s
#   🔍 Val Batch 56/88 ( 63.6%) | Loss: 0.1066 | Acc: 88.84% | Time: 0.06s
#   🔍 Val Batch 61/88 ( 69.3%) | Loss: 0.1289 | Acc: 88.68% | Time: 0.06s
#   🔍 Val Batch 66/88 ( 75.0%) | Loss: 0.0896 | Acc: 89.02% | Time: 0.06s
#   🔍 Val Batch 71/88 ( 80.7%) | Loss: 0.0862 | Acc: 88.91% | Time: 0.06s
#   🔍 Val Batch 76/88 ( 86.4%) | Loss: 0.0939 | Acc: 88.65% | Time: 0.06s
#   🔍 Val Batch 81/88 ( 92.0%) | Loss: 0.0993 | Acc: 88.62% | Time: 0.06s
#   🔍 Val Batch 86/88 ( 97.7%) | Loss: 0.0752 | Acc: 88.74% | Time: 0.06s
#   🔍 Val Batch 88/88 (100.0%) | Loss: 0.0493 | Acc: 88.77% | Time: 0.02s
#   ✅ Validation complete! Total time: 6.8s, Avg batch: 0.08s
#
# 📊 Epoch 19 Summary:
#   Train Loss: 0.0335, Train Acc: 98.60%
#   Val Loss: 0.0945, Val Acc: 88.77%
#   Learning Rate: 0.000050
#   Epoch Time: 85.3s
#   No improvement. Patience: 10/10
#
# ⏹️  Early stopping triggered after 19 epochs
#   Best Val Loss: 0.0864
#   Best Val Acc: 88.77%
#
# ================================================================================
# ✅ TRAINING COMPLETED!
# ================================================================================
#   Total training time: 27.23 minutes
#   Best validation loss: 0.0864
#   Best validation accuracy: 88.77%
#   Architecture: DenseNet-121 + ECA + GAP
#   Attention: Efficient Channel Attention ⭐
#   Training mode: Full model (backbone + ECA + classifier)
#
# 📂 Loading best trained model for evaluation...
# ✅ Best model loaded! Val Loss: 0.0864, Val Acc: 88.77%

# %% [markdown]
# ## Training Visualization

# %%
# Plot training history
def plot_training_history(train_losses, val_losses, train_accuracies, val_accuracies):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    epochs = range(1, len(train_losses) + 1)
    
    # Plot loss
    ax1.plot(epochs, train_losses, 'b-', label='Training Loss')
    ax1.plot(epochs, val_losses, 'r-', label='Validation Loss')
    ax1.set_title('Model Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Plot accuracy
    ax2.plot(epochs, train_accuracies, 'b-', label='Training Accuracy')
    ax2.plot(epochs, val_accuracies, 'r-', label='Validation Accuracy')
    ax2.set_title('Model Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy (%)')
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# Plot the training history
plot_training_history(train_losses, val_losses, train_accuracies, val_accuracies)

# %% [markdown]
# ## Model Evaluation

# %%
# Load best model
model.load_state_dict(torch.load('best_model_densenet121_eca_gap.pth')['model_state_dict'])
model.eval()

# Evaluate on test set
print("Evaluating DenseNet-121 model on test set...")
print("📊 Model specifications:")
print("  • Model: MitosisClassifier")
print("  • Backbone: DenseNet-121")
print("  • Output: 2 neurons with SoftMax activation")
print("  • Loss function: FocalLoss()")
print("  • Device: cuda")
print("  • Classification head: 1024 -> 1024 -> 512 -> 256 -> 128 -> 2")
print("  • Output layer: 2 neurons with Softmax activation")
print("  • Output format: Two probabilities [p(class0), p(class1)], use argmax for prediction")

test_running_loss = 0.0
test_correct = 0
test_total = 0
all_test_preds = []
all_test_targets = []
all_test_probs = []

with torch.no_grad():
    for batch_idx, (data, target) in enumerate(test_loader):
        data, target = data.to(device), target.to(device)
        output = model(data)  # Softmax probabilities
        loss = criterion(output, target)  # FocalLoss
        
        test_running_loss += loss.item()
        _, predicted = torch.max(output.data, 1)  # argmax for prediction
        test_total += target.size(0)
        test_correct += (predicted == target).sum().item()
        
        all_test_preds.extend(predicted.cpu().numpy())
        all_test_targets.extend(target.cpu().numpy())
        all_test_probs.extend(output.cpu().numpy())
        
        if batch_idx % 10 == 0:
            current_acc = 100. * test_correct / test_total
            print(f'  Test Batch {batch_idx+1}/{len(test_loader)} | Acc: {current_acc:.2f}%')

test_loss = test_running_loss / len(test_loader)
test_acc = 100. * test_correct / test_total

print(f"\n📈 Test Results (DenseNet-121 Full Model Training):")
print(f"  Test Loss: {test_loss:.4f}")
print(f"  Test Accuracy: {test_acc:.2f}%")
print(f"  Total test samples: {test_total}")
print(f"  Correct predictions: {test_correct}")

# Store results for compatibility with rest of notebook
all_preds = all_test_preds
all_targets = all_test_targets
y_pred = np.array(all_test_preds)
y_true = np.array(all_test_targets)
y_probs = np.array(all_test_probs)
print(f"  Total test samples: {test_total}")
print(f"  Correct predictions: {test_correct}")

# Store results for compatibility with rest of notebook
all_preds = all_test_preds
all_targets = all_test_targets
# Out:
# Evaluating DenseNet-121 model on test set...
# 📊 Model specifications:
#   • Model: MitosisClassifier
#   • Backbone: DenseNet-121
#   • Output: 2 neurons with SoftMax activation
#   • Loss function: FocalLoss()
#   • Device: cuda
#   • Classification head: 1024 -> 1024 -> 512 -> 256 -> 128 -> 2
#   • Output layer: 2 neurons with Softmax activation
#   • Output format: Two probabilities [p(class0), p(class1)], use argmax for prediction
#   Test Batch 1/88 | Acc: 93.75%
#   Test Batch 11/88 | Acc: 87.22%
#   Test Batch 21/88 | Acc: 87.50%
#   Test Batch 31/88 | Acc: 88.00%
#   Test Batch 41/88 | Acc: 88.49%
#   Test Batch 51/88 | Acc: 88.60%
#   Test Batch 61/88 | Acc: 88.78%
#   Test Batch 71/88 | Acc: 88.69%
#   Test Batch 81/88 | Acc: 88.81%
#
# 📈 Test Results (DenseNet-121 Full Model Training):
#   Test Loss: 0.0885
#   Test Accuracy: 89.10%
#   Total test samples: 2788
#   Correct predictions: 2484
#   Total test samples: 2788
#   Correct predictions: 2484

# %%
# Analyze performance by different factors
test_df_with_predictions = test_df.copy().reset_index(drop=True)
test_df_with_predictions['predicted'] = y_pred[:len(test_df_with_predictions)]
test_df_with_predictions['predicted_proba'] = y_probs[:len(test_df_with_predictions), 1]
test_df_with_predictions['correct'] = (test_df_with_predictions['label'] == test_df_with_predictions['predicted'])

print("Performance Analysis:")

# Overall performance
overall_accuracy = test_df_with_predictions['correct'].mean()
print(f"Overall Test Accuracy: {overall_accuracy:.4f} ({len(test_df_with_predictions)} samples)")

# Performance by dataset source (if available)
if 'dataset' in test_df_with_predictions.columns and len(test_df_with_predictions['dataset'].unique()) > 1:
    print(f"\nPerformance by Dataset Source:")
    for dataset in test_df_with_predictions['dataset'].unique():
        if pd.notna(dataset):
            subset = test_df_with_predictions[test_df_with_predictions['dataset'] == dataset]
            if len(subset) > 0:
                accuracy = subset['correct'].mean()
                print(f"  {dataset}: {accuracy:.4f} accuracy ({len(subset)} samples)")

# Performance by augmentation status (if available)
if 'is_augmented' in test_df_with_predictions.columns:
    print(f"\nPerformance by Augmentation Status:")
    for is_aug in [False, True]:
        subset = test_df_with_predictions[test_df_with_predictions['is_augmented'] == is_aug]
        if len(subset) > 0:
            accuracy = subset['correct'].mean()
            status = "Augmented" if is_aug else "Original"
            print(f"  {status}: {accuracy:.4f} accuracy ({len(subset)} samples)")

# Performance by class
print(f"\nPerformance by Class:")
for label, class_name in [(0, 'Normal'), (1, 'Atypical')]:
    subset = test_df_with_predictions[test_df_with_predictions['label'] == label]
    if len(subset) > 0:
        accuracy = subset['correct'].mean()
        print(f"  {class_name}: {accuracy:.4f} accuracy ({len(subset)} samples)")

# Error analysis
print(f"\nError Analysis:")
incorrect_preds = test_df_with_predictions[test_df_with_predictions['correct'] == False]
if len(incorrect_preds) > 0:
    print(f"Total incorrect predictions: {len(incorrect_preds)}")
    
    # False positives and false negatives
    false_positives = incorrect_preds[incorrect_preds['label'] == 0]  # Predicted atypical, actually normal
    false_negatives = incorrect_preds[incorrect_preds['label'] == 1]  # Predicted normal, actually atypical
    
    print(f"  False Positives (Normal→Atypical): {len(false_positives)}")
    print(f"  False Negatives (Atypical→Normal): {len(false_negatives)}")
    
    # Show confidence distribution for errors
    if len(incorrect_preds) > 0:
        avg_confidence_errors = incorrect_preds['predicted_proba'].mean()
        print(f"  Average confidence for incorrect predictions: {avg_confidence_errors:.3f}")
else:
    print("No incorrect predictions!")

# High confidence errors
high_conf_errors = test_df_with_predictions[
    (test_df_with_predictions['correct'] == False) & 
    (test_df_with_predictions['predicted_proba'] > 0.8)
]
if len(high_conf_errors) > 0:
    print(f"\nHigh-confidence errors (>0.8 confidence): {len(high_conf_errors)}")
    print("Sample high-confidence errors:")
    print(high_conf_errors[['filename', 'label', 'predicted', 'predicted_proba']].head())
# Out:
# Performance Analysis:
# Overall Test Accuracy: 0.8910 (2788 samples)
#
# Performance by Dataset Source:
#   MIDOG25: 0.8972 accuracy (2402 samples)
#   AMI-BR: 0.8523 accuracy (386 samples)
#
# Performance by Augmentation Status:
#   Original: 0.8910 accuracy (2788 samples)
#
# Performance by Class:
#   Normal: 0.9499 accuracy (2353 samples)
#   Atypical: 0.5724 accuracy (435 samples)
#
# Error Analysis:
# Total incorrect predictions: 304
#   False Positives (Normal→Atypical): 118
#   False Negatives (Atypical→Normal): 186
#   Average confidence for incorrect predictions: 0.385
#
# High-confidence errors (>0.8 confidence): 60
# Sample high-confidence errors:
#               filename  label  predicted  predicted_proba
# 53            8220.png      0          1         0.979769
# 89            8802.png      0          1         0.911626
# 157           9542.png      0          1         0.977732
# 184           4938.png      0          1         0.901978
# 185  TUPAC16_10594.png      0          1         0.939440

# %%
# Visualize some predictions
def visualize_predictions(df_with_pred, n_samples=12):
    fig, axes = plt.subplots(3, 4, figsize=(16, 12))
    axes = axes.ravel()
    
    # Get some correct and incorrect predictions
    correct_pred = df_with_pred[df_with_pred['correct'] == True]
    incorrect_pred = df_with_pred[df_with_pred['correct'] == False]
    
    if len(correct_pred) > 0:
        correct_sample = correct_pred.sample(min(6, len(correct_pred)))
    else:
        correct_sample = pd.DataFrame()
    
    if len(incorrect_pred) > 0:
        incorrect_sample = incorrect_pred.sample(min(6, len(incorrect_pred)))
    else:
        incorrect_sample = pd.DataFrame()
    
    samples = pd.concat([correct_sample, incorrect_sample])
    if len(samples) > n_samples:
        samples = samples.sample(n_samples)
    
    for i, (_, row) in enumerate(samples.iterrows()):
        if i >= n_samples:
            break
            
        try:
            img = Image.open(row['image_path'])
            axes[i].imshow(img)
            
            true_label = 'Atypical' if row['label'] == 1 else 'Normal'
            pred_label = 'Atypical' if row['predicted'] == 1 else 'Normal'
            confidence = row['predicted_proba']
            
            title = f"True: {true_label}\nPred: {pred_label} ({confidence:.3f})\n{row['dataset']}"
            color = 'green' if row['correct'] else 'red'
            axes[i].set_title(title, color=color, fontsize=10)
            axes[i].axis('off')
        except Exception as e:
            axes[i].text(0.5, 0.5, f"Error loading\n{row['filename']}", 
                        ha='center', va='center', transform=axes[i].transAxes)
            axes[i].axis('off')
    
    # Hide unused subplots
    for i in range(len(samples), n_samples):
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.show()

visualize_predictions(test_df_with_predictions)

# %% [markdown]
# ## Model Saving and Summary

# %%
# Save model as the best model for future use
torch.save({
    'model_state_dict': model.state_dict(),
    'best_val_loss': best_val_loss,
    'best_val_acc': best_val_acc,
    'epoch': len(train_losses),
    'class_names': ['Normal', 'Atypical']
}, 'mitotic_figure_densenet121_eca_gap_classifier.pth')

print("Model saved as 'mitotic_figure_densenet121_eca_gap_classifier.pth'")

# Calculate metrics
from sklearn.metrics import precision_score, recall_score, f1_score

test_precision = precision_score(y_true, y_pred, average='weighted')
test_recall = recall_score(y_true, y_pred, average='weighted')
test_f1 = f1_score(y_true, y_pred, average='weighted')

# Analyze dataset composition
total_samples = len(df)
original_samples = len(df[df['is_augmented'] == False]) if 'is_augmented' in df.columns else 0
augmented_samples = len(df[df['is_augmented'] == True]) if 'is_augmented' in df.columns else 0

# Save model summary and results
results_summary = {
    'model_architecture': 'DenseNet-121 + ECA + GAP + Custom Head (PyTorch)',
    'framework': 'PyTorch',
    'backbone_model': 'DenseNet-121',
    'attention_mechanism': 'ECA (Efficient Channel Attention)',
    'pretrained_weights': 'ImageNet (automatically downloaded)',
    'training_approach': 'Full model training with ECA + Global Average Pooling + Focal Loss',
    'class_balancing': 'Focal Loss + WeightedRandomSampler (advanced strategy)',
    'learning_rate': float(LEARNING_RATE),
    'output_format': '2 neurons with Softmax activation',
    'loss_function': 'Focal Loss',
    'focal_alpha': float(alpha_focal),
    'focal_gamma': 2.0,
    'prediction_method': 'argmax of [p(class0), p(class1)]',
    'dataset_source': 'Pre-augmented Kaggle dataset',
    'total_samples': int(total_samples),
    'original_samples': int(original_samples),
    'augmented_samples': int(augmented_samples),
    'train_samples': len(train_df),
    'val_samples': len(val_df),
    'test_samples': len(test_df),
    'test_accuracy': float(test_acc / 100),  # Convert from percentage
    'test_precision': float(test_precision),
    'test_recall': float(test_recall),
    'test_f1': float(test_f1),
    # 'auc_score': float(auc_score),
    'best_val_accuracy': float(best_val_acc / 100),  # Convert from percentage
    'best_val_loss': float(best_val_loss),
    'early_stopping_metric': 'validation_loss',
    'early_stopping_patience': 10,
    'class_distribution': df['label'].value_counts().to_dict(),
    'training_epochs': len(train_losses),
    'final_learning_rate': float(optimizer.param_groups[0]['lr']),
    'used_augmented_data': augmented_samples > 0,
    'trainable_parameters': int(trainable_params),
    'total_parameters': int(total_params),
    'trainable_percentage': float(trainable_params/total_params*100),
    'gap_layer': True,
    'frozen_backbone': False,  # Full model training
    'eca_attention': True,
    'dense_connectivity': True,
    'advanced_loss': True
}

print("\n" + "="*90)
print("FINAL RESULTS SUMMARY - MITOTIC FIGURE CLASSIFICATION (DENSENET-121 + ECA)")
print("="*90)
print(f"Model Architecture: {results_summary['model_architecture']}")
print(f"Backbone Model: {results_summary['backbone_model']}")
print(f"Framework: {results_summary['framework']}")
print(f"Attention Mechanism: {results_summary['attention_mechanism']}")
print(f"Pretrained Weights: {results_summary['pretrained_weights']}")
print(f"Training Approach: {results_summary['training_approach']}")
print(f"Class Balancing: {results_summary['class_balancing']}")
print(f"Output Format: {results_summary['output_format']}")
print(f"Loss Function: {results_summary['loss_function']} (alpha={results_summary['focal_alpha']:.3f}, gamma={results_summary['focal_gamma']})")
print(f"Prediction Method: {results_summary['prediction_method']}")
print(f"Dataset Source: {results_summary['dataset_source']}")

print(f"\nArchitecture Details:")
print(f"  Backbone: DenseNet-121 (fully trainable 🔓)")
print(f"  Attention: ECA (Efficient Channel Attention) ⭐")
print(f"  Dense Connectivity: ✅ (feature reuse & gradient flow)")
print(f"  GAP Layer: Global Average Pooling")
print(f"  Custom Head: 1024 -> 512 -> 256 -> 128 -> 2")
print(f"  Learning Rate: {results_summary['learning_rate']}")
print(f"  Final Learning Rate: {results_summary['final_learning_rate']:.2e}")
print(f"  Pretrained: ImageNet weights (automatic download)")

print(f"\nDataset Composition:")
print(f"  Total Samples: {results_summary['total_samples']:,}")
print(f"  Training Samples: {results_summary['train_samples']:,}")
print(f"  Validation Samples: {results_summary['val_samples']:,}")
print(f"  Test Samples: {results_summary['test_samples']:,}")
if results_summary['used_augmented_data']:
    print(f"  Original Samples: {results_summary['original_samples']:,}")
    print(f"  Augmented Samples: {results_summary['augmented_samples']:,}")
    augmentation_ratio = results_summary['augmented_samples'] / results_summary['original_samples']
    print(f"  Augmentation Ratio: {augmentation_ratio:.1f}x")

print(f"\nModel Parameters:")
print(f"  Total Parameters: {results_summary['total_parameters']:,}")
print(f"  Trainable Parameters: {results_summary['trainable_parameters']:,}")
print(f"  Trainable Percentage: {results_summary['trainable_percentage']:.1f}%")

print(f"\nTraining Performance:")
print(f"  Training Epochs: {results_summary['training_epochs']}")
print(f"  Best Validation Loss: {results_summary['best_val_loss']:.4f}")
print(f"  Best Validation Accuracy: {results_summary['best_val_accuracy']:.4f}")

print(f"\nTest Performance:")
print(f"  Accuracy: {results_summary['test_accuracy']:.4f}")
print(f"  Precision: {results_summary['test_precision']:.4f}")
print(f"  Recall: {results_summary['test_recall']:.4f}")
print(f"  F1-Score: {results_summary['test_f1']:.4f}")
# print(f"  AUC Score: {results_summary['auc_score']:.4f}")

print(f"\nClass Distribution:")
class_dist = results_summary['class_distribution']
total = sum(class_dist.values())
for label, count in class_dist.items():
    class_name = "Atypical" if label == 1 else "Normal"
    percentage = (count / total) * 100
    print(f"  {class_name}: {count} samples ({percentage:.1f}%)")

print(f"\n🎯 DENSENET-121 + ECA TRAINING HIGHLIGHTS:")
print(f"  • Training Mode: Full model training ({results_summary['trainable_percentage']:.1f}% parameters)")
print(f"  • Backbone: DenseNet-121 (fully trainable) - Dense feature connections")
print(f"  • Attention: ECA (Efficient Channel Attention) ⭐")
print(f"  • Global Average Pooling: ✅ (reduces overfitting)")
print(f"  • Advanced Loss: Focal Loss (α={results_summary['focal_alpha']:.3f}, γ={results_summary['focal_gamma']})")
print(f"  • Dense Connectivity: Feature reuse & improved gradient flow")
print(f"  • Class Balancing: Focal Loss + WeightedRandomSampler (double protection)")
print(f"  • Hard Example Focus: Focal Loss emphasizes difficult samples")
print(f"  • Early Stopping: Based on validation loss (patience=10)")
print(f"  • Best Val Loss: {results_summary['best_val_loss']:.4f}")
print(f"  • Final Layer: {NUM_CLASSES} neurons with Softmax")
print(f"  • Output: [p(class0), p(class1)] with argmax prediction")
print(f"  • Automatic Downloads: ImageNet pretrained weights")

print("="*90)

# Save results to JSON
with open('densenet121_eca_gap_training_results.json', 'w') as f:
    json.dump(results_summary, f, indent=2)

print("\nResults saved to 'densenet121_eca_gap_training_results.json'")
print("DenseNet-121 + ECA + GAP model training completed successfully!")

# Final model performance summary
print(f"\n🎯 KEY PERFORMANCE METRICS (DENSENET-121 + ECA):")
print(f"  • Test Accuracy: {results_summary['test_accuracy']:.1%}")
# print(f"  • AUC Score: {results_summary['auc_score']:.3f}")
print(f"  • F1 Score: {results_summary['test_f1']:.3f}")
print(f"  • Architecture: DenseNet-121 + ECA + GAP + Custom Head")
print(f"  • Attention: ECA (Efficient Channel Attention)")
print(f"  • Loss Function: Focal Loss (advanced class imbalance handling)")
print(f"  • Training: Full model training (end-to-end)")
print(f"  • Dense Connectivity: Enhanced feature reuse")
print(f"  • Advanced Strategy: Focal Loss + WeightedRandomSampler + ECA")
if results_summary['used_augmented_data']:
    print(f"  • Benefited from {augmentation_ratio:.1f}x data augmentation")
print(f"  • DenseNet-121 + ECA model ready for deployment! 🚀")
# Out:
# Model saved as 'mitotic_figure_densenet121_eca_gap_classifier.pth'
#
# ==========================================================================================
# FINAL RESULTS SUMMARY - MITOTIC FIGURE CLASSIFICATION (DENSENET-121 + ECA)
# ==========================================================================================
# Model Architecture: DenseNet-121 + ECA + GAP + Custom Head (PyTorch)
# Backbone Model: DenseNet-121
# Framework: PyTorch
# Attention Mechanism: ECA (Efficient Channel Attention)
# Pretrained Weights: ImageNet (automatically downloaded)
# Training Approach: Full model training with ECA + Global Average Pooling + Focal Loss
# Class Balancing: Focal Loss + WeightedRandomSampler (advanced strategy)
# Output Format: 2 neurons with Softmax activation
# Loss Function: Focal Loss (alpha=1.081, gamma=2.0)
# Prediction Method: argmax of [p(class0), p(class1)]
# Dataset Source: Pre-augmented Kaggle dataset
#
# Architecture Details:
#   Backbone: DenseNet-121 (fully trainable 🔓)
#   Attention: ECA (Efficient Channel Attention) ⭐
#   Dense Connectivity: ✅ (feature reuse & gradient flow)
#   GAP Layer: Global Average Pooling
#   Custom Head: 1024 -> 512 -> 256 -> 128 -> 2
#   Learning Rate: 0.0001
#   Final Learning Rate: 5.00e-05
#   Pretrained: ImageNet weights (automatic download)
#
# Dataset Composition:
#   Total Samples: 19,162
#   Training Samples: 13,586
#   Validation Samples: 2,788
#   Test Samples: 2,788
#   Original Samples: 13,938
#   Augmented Samples: 5,224
#   Augmentation Ratio: 0.4x
#
# Model Parameters:
#   Total Parameters: 9,003,778
#   Trainable Parameters: 9,003,778
#   Trainable Percentage: 100.0%
#
# Training Performance:
#   Training Epochs: 19
#   Best Validation Loss: 0.0864
#   Best Validation Accuracy: 0.8877
#
# Test Performance:
#   Accuracy: 0.8910
#   Precision: 0.8817
#   Recall: 0.8877
#   F1-Score: 0.8840
#
# Class Distribution:
#   Normal: 11762 samples (61.4%)
#   Atypical: 7400 samples (38.6%)
#
# 🎯 DENSENET-121 + ECA TRAINING HIGHLIGHTS:
#   • Training Mode: Full model training (100.0% parameters)
#   • Backbone: DenseNet-121 (fully trainable) - Dense feature connections
#   • Attention: ECA (Efficient Channel Attention) ⭐
#   • Global Average Pooling: ✅ (reduces overfitting)
#   • Advanced Loss: Focal Loss (α=1.081, γ=2.0)
#   • Dense Connectivity: Feature reuse & improved gradient flow
#   • Class Balancing: Focal Loss + WeightedRandomSampler (double protection)
#   • Hard Example Focus: Focal Loss emphasizes difficult samples
#   • Early Stopping: Based on validation loss (patience=10)
#   • Best Val Loss: 0.0864
#   • Final Layer: 2 neurons with Softmax
#   • Output: [p(class0), p(class1)] with argmax prediction
#   • Automatic Downloads: ImageNet pretrained weights
# ==========================================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_48/3970429551.py in <cell line: 0>()
#     147 # Save results to JSON
#     148 with open('densenet121_eca_gap_training_results.json', 'w') as f:
# --> 149     json.dump(results_summary, f, indent=2)
#     150
#     151 print("\nResults saved to 'densenet121_eca_gap_training_results.json'")
#
# NameError: name 'json' is not defined

# %% [markdown]
# ## 📊 Detailed Model Evaluation - Confusion Matrix & ROC Curve
#
# Now let's generate comprehensive evaluation metrics including:
# - **Confusion Matrix**: Shows the breakdown of correct and incorrect predictions
# - **ROC Curve & AUC**: Shows the model's ability to distinguish between classes
# - **Precision-Recall Curve**: Shows precision vs recall trade-off
# - **Sample Predictions**: Visual validation with confidence scores

# %%
import numpy as np
import torch
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns

# Load the best DenseNet-121 + ECA model
print("📂 Loading best trained DenseNet-121 + ECA model...")
try:
    checkpoint = torch.load('best_model_densenet121_eca_gap.pth')
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"✅ Best ECA model loaded! Best Val Loss: {checkpoint.get('best_val_loss', 'N/A'):.4f}")
    print(f"✅ Best ECA model loaded! Best Val Acc: {checkpoint.get('best_val_acc', 'N/A'):.2f}%")
except FileNotFoundError:
    print("⚠️ Best model file not found, using current model state")

model.eval()

# Generate predictions
all_predictions = []
all_probabilities = []
all_targets = []
all_predicted_probs = []

with torch.no_grad():
    for data, target in val_loader:
        data, target = data.to(device), target.to(device)
        outputs = model(data)
        probabilities = torch.softmax(outputs, dim=1)
        predictions = torch.argmax(probabilities, dim=1)

        all_predictions.extend(predictions.cpu().numpy())
        all_targets.extend(target.cpu().numpy())
        all_probabilities.extend(probabilities.cpu().numpy())
        all_predicted_probs.extend(probabilities[:, 1].cpu().numpy())

# Convert to numpy
y_true = np.array(all_targets)
y_pred = np.array(all_predictions)
y_prob = np.array(all_predicted_probs)

# Class names
class_names = ['Normal', 'Atypical']

print(f"\n📊 EVALUATION RESULTS (DENSENET-121 + ECA):")
print(f"  • Total test samples: {len(y_true)}")
print(f"  • Predictions generated with ECA attention mechanism")

# Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)
print(f"\n🎯 Confusion Matrix:")
print(f"  True Negatives (Normal → Normal): {cm[0,0]}")
print(f"  False Positives (Normal → Atypical): {cm[0,1]}")
print(f"  False Negatives (Atypical → Normal): {cm[1,0]}")
print(f"  True Positives (Atypical → Atypical): {cm[1,1]}")

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names,
            cbar_kws={'label': 'Count'})
plt.title('📊 Confusion Matrix - DenseNet-121 + ECA', fontsize=14, fontweight='bold')
plt.xlabel('Predicted Label', fontweight='bold')
plt.ylabel('True Label', fontweight='bold')

# Add percentages to cells
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
for i in range(len(class_names)):
    for j in range(len(class_names)):
        plt.text(j + 0.5, i + 0.7, f'({cm_percent[i, j]:.1%})',
                 ha='center', va='center', fontsize=10, color='darkred', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# 📂 Loading best trained DenseNet-121 + ECA model...
# ✅ Best ECA model loaded! Best Val Loss: 0.0864
# ✅ Best ECA model loaded! Best Val Acc: 88.77%
#
# 📊 EVALUATION RESULTS (DENSENET-121 + ECA):
#   • Total test samples: 2788
#   • Predictions generated with ECA attention mechanism
#
# 🎯 Confusion Matrix:
#   True Negatives (Normal → Normal): 2229
#   False Positives (Normal → Atypical): 124
#   False Negatives (Atypical → Normal): 189
#   True Positives (Atypical → Atypical): 246

# %%
# 🖼️ DENSENET-121 SAMPLE PREDICTIONS VISUALIZATION
print("🔍 Showing sample predictions with confidence scores...")
print("="*80)

# Get a batch of validation images for visualization
model.eval()
with torch.no_grad():
    # Get one batch from validation loader
    data_iter = iter(val_loader)
    images, labels = next(data_iter)
    images, labels = images.to(device), labels.to(device)
    
    # Get predictions
    outputs = model(images)
    probabilities = torch.softmax(outputs, dim=1)
    predictions = torch.argmax(probabilities, dim=1)
    
    # Move to CPU for visualization
    images = images.cpu()
    labels = labels.cpu()
    predictions = predictions.cpu()
    probabilities = probabilities.cpu()

# Create visualization
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
fig.suptitle('🖼️ DenseNet-121 Sample Predictions from Validation Set', fontsize=16, fontweight='bold')

class_names = ['Non-Mitotic', 'Mitotic']
colors = ['#4caf50', '#f44336']  # Green for correct, Red for incorrect

for i in range(8):
    row = i // 4
    col = i % 4
    
    # Get image, true label, prediction, and confidence
    img = images[i]
    true_label = labels[i].item()
    pred_label = predictions[i].item()
    confidence = probabilities[i][pred_label].item()
    
    # Denormalize image for display (assuming ImageNet normalization)
    mean = torch.tensor([0.485, 0.456, 0.406])
    std = torch.tensor([0.229, 0.224, 0.225])
    img = img * std.view(3, 1, 1) + mean.view(3, 1, 1)
    img = torch.clamp(img, 0, 1)
    
    # Display image
    axes[row, col].imshow(img.permute(1, 2, 0))
    axes[row, col].axis('off')
    
    # Determine if prediction is correct
    is_correct = true_label == pred_label
    border_color = colors[0] if is_correct else colors[1]
    status_icon = "✅" if is_correct else "❌"
    
    # Create title with prediction info
    title = f"{status_icon} True: {class_names[true_label]}\n"
    title += f"Pred: {class_names[pred_label]} ({confidence:.1%})"
    
    axes[row, col].set_title(title, fontsize=10, fontweight='bold', 
                           color=border_color, pad=10)
    
    # Add colored border
    for spine in axes[row, col].spines.values():
        spine.set_edgecolor(border_color)
        spine.set_linewidth(3)

plt.tight_layout()
plt.show()

# Show statistics for this batch
batch_accuracy = (predictions == labels).float().mean().item()
correct_predictions = (predictions == labels).sum().item()
total_predictions = len(labels)

print(f"\n📊 DENSENET-121 BATCH STATISTICS:")
print(f"🎯 Batch Accuracy: {batch_accuracy:.1%} ({correct_predictions}/{total_predictions})")
print(f"🔹 Non-Mitotic samples: {(labels == 0).sum().item()}")
print(f"🔸 Mitotic samples: {(labels == 1).sum().item()}")

# Show confidence distribution
high_conf_correct = ((probabilities.max(dim=1)[0] > 0.9) & (predictions == labels)).sum().item()
low_conf_incorrect = ((probabilities.max(dim=1)[0] < 0.6) & (predictions != labels)).sum().item()

print(f"\n🔍 CONFIDENCE ANALYSIS:")
print(f"✅ High confidence (>90%) correct predictions: {high_conf_correct}")
print(f"⚠️ Low confidence (<60%) incorrect predictions: {low_conf_incorrect}")

print("\n" + "="*80)
# Out:
# 🔍 Showing sample predictions with confidence scores...
# ================================================================================
# 📊 DENSENET-121 BATCH STATISTICS:
# 🎯 Batch Accuracy: 93.8% (30/32)
# 🔹 Non-Mitotic samples: 29
# 🔸 Mitotic samples: 3
#
# 🔍 CONFIDENCE ANALYSIS:
# ✅ High confidence (>90%) correct predictions: 0
# ⚠️ Low confidence (<60%) incorrect predictions: 0
#
# ================================================================================

# %%
# 🎯 DENSENET-121 FINAL EVALUATION SUMMARY & CLINICAL RECOMMENDATIONS
print("📋 COMPREHENSIVE DENSENET-121 MODEL EVALUATION SUMMARY")
print("=" * 80)

# Calculate key metrics for summary
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn)  # Recall for mitotic class
specificity = tn / (tn + fp)  # Recall for non-mitotic class
precision_mitotic = tp / (tp + fp)  # Precision for mitotic class
precision_non_mitotic = tn / (tn + fn)  # Precision for non-mitotic class

print(f"🏆 DENSENET-121 MODEL PERFORMANCE OVERVIEW:")
print(f"   • Overall Accuracy: {accuracy:.1%}")
print(f"   • AUC-ROC Score: {auc_score:.4f}")
print(f"   • Sensitivity (Mitotic Detection): {sensitivity:.1%}")
print(f"   • Specificity (Non-Mitotic Detection): {specificity:.1%}")

print(f"\n🏥 CLINICAL RELEVANCE FOR MITOTIC FIGURE DETECTION:")
print(f"   • True Positive Rate (Sensitivity): {sensitivity:.1%}")
print(f"     → Out of all actual mitotic figures, {sensitivity:.1%} were correctly identified")
print(f"   • False Negative Rate: {fn/(tp+fn):.1%}")
print(f"     → {fn} mitotic figures were missed (could impact cancer grading)")
print(f"   • False Positive Rate: {fp/(fp+tn):.1%}")
print(f"     → {fp} non-mitotic figures were incorrectly flagged as mitotic")
print(f"   • Positive Predictive Value: {precision_mitotic:.1%}")
print(f"     → When model predicts mitotic, it's correct {precision_mitotic:.1%} of the time")

print(f"\n🔍 CONFUSION MATRIX CLINICAL INTERPRETATION:")
print(f"   ✅ True Negatives (TN): {tn} - Correctly identified non-mitotic figures")
print(f"   ❌ False Positives (FP): {fp} - Non-mitotic figures misclassified as mitotic")
print(f"   ❌ False Negatives (FN): {fn} - Mitotic figures missed by the model")
print(f"   ✅ True Positives (TP): {tp} - Correctly identified mitotic figures")

print(f"\n📊 DENSENET-121 AUC-ROC CLINICAL INTERPRETATION:")
if auc_score >= 0.9:
    auc_interpretation = "EXCELLENT - Outstanding ability to distinguish mitotic from non-mitotic figures"
    clinical_readiness = "Ready for clinical validation studies"
elif auc_score >= 0.8:
    auc_interpretation = "VERY GOOD - Good discrimination ability for mitotic figure detection"
    clinical_readiness = "Consider additional validation on diverse pathology datasets"
elif auc_score >= 0.7:
    auc_interpretation = "GOOD - Acceptable discrimination ability"
    clinical_readiness = "Requires improvement before clinical consideration"
else:
    auc_interpretation = "NEEDS IMPROVEMENT - Limited discrimination ability"
    clinical_readiness = "Significant improvements needed for clinical use"

print(f"   🎯 Score: {auc_score:.4f} - {auc_interpretation}")
print(f"   🏥 Clinical Readiness: {clinical_readiness}")

print(f"\n🔬 DENSENET-121 VS. OTHER ARCHITECTURES:")
print(f"   • DenseNet-121 leverages dense connectivity for feature reuse")
print(f"   • Fewer parameters than ResNet but deeper feature propagation")
print(f"   • GAP layer reduces overfitting and improves generalization")
print(f"   • Focal Loss addresses class imbalance in mitotic figure detection")

print(f"\n💡 CLINICAL DEPLOYMENT RECOMMENDATIONS:")

# Risk assessment based on metrics
if sensitivity >= 0.9 and specificity >= 0.8:
    risk_level = "🟢 LOW RISK"
    deployment_advice = "Suitable for clinical assistance with pathologist oversight"
elif sensitivity >= 0.8 and specificity >= 0.7:
    risk_level = "🟡 MODERATE RISK"  
    deployment_advice = "Requires careful clinical validation and expert review"
else:
    risk_level = "🔴 HIGH RISK"
    deployment_advice = "Not recommended for clinical use without major improvements"

print(f"   • Risk Level: {risk_level}")
print(f"   • Deployment Advice: {deployment_advice}")

print(f"\n🎯 STRENGTHS OF DENSENET-121 MODEL:")
strengths = []
if accuracy >= 0.85:
    strengths.append(f"High overall accuracy ({accuracy:.1%})")
if auc_score >= 0.85:
    strengths.append(f"Excellent discrimination (AUC: {auc_score:.4f})")
if sensitivity >= 0.8:
    strengths.append(f"Good sensitivity for mitotic detection ({sensitivity:.1%})")
if specificity >= 0.8:
    strengths.append(f"Good specificity for non-mitotic identification ({specificity:.1%})")
if precision_mitotic >= 0.8:
    strengths.append(f"High precision for mitotic predictions ({precision_mitotic:.1%})")

for strength in strengths:
    print(f"   ✅ {strength}")

print(f"\n⚠️  AREAS FOR IMPROVEMENT:")
improvements = []
if accuracy < 0.85:
    improvements.append(f"Overall accuracy needs improvement (current: {accuracy:.1%})")
if auc_score < 0.85:
    improvements.append(f"Discrimination ability needs enhancement (AUC: {auc_score:.4f})")
if sensitivity < 0.8:
    improvements.append(f"Sensitivity for mitotic detection needs improvement ({sensitivity:.1%})")
if specificity < 0.8:
    improvements.append(f"Specificity needs improvement to reduce false alarms ({specificity:.1%})")
if fn > tp * 0.2:  # If false negatives > 20% of true positives
    improvements.append(f"Too many missed mitotic figures ({fn} false negatives)")
if fp > tp:  # If false positives > true positives
    improvements.append(f"Too many false alarms ({fp} false positives)")

for improvement in improvements:
    print(f"   🔧 {improvement}")

if not improvements:
    print(f"   🎉 DenseNet-121 model meets clinical standards across all key metrics!")

print(f"\n🏥 CLINICAL IMPACT ASSESSMENT:")
if sensitivity >= 0.9:
    print(f"   ✅ EXCELLENT sensitivity: Very few mitotic figures will be missed")
else:
    print(f"   ⚠️ Sensitivity {sensitivity:.1%}: Risk of missing {100-sensitivity*100:.1f}% of mitotic figures")

if fp <= tp:
    print(f"   ✅ GOOD precision: Low false alarm rate")
else:
    print(f"   ⚠️ High false positive rate: May burden pathologists with unnecessary reviews")

# Model comparison context
print(f"\n📊 DENSENET-121 ARCHITECTURE ADVANTAGES:")
print(f"   • Dense connectivity: Efficient feature reuse and gradient flow")
print(f"   • Parameter efficiency: {sum(p.numel() for p in model.parameters())/1e6:.1f}M parameters")
print(f"   • GAP integration: Reduces overfitting, improves localization")
print(f"   • Focal Loss compatibility: Effectively handles class imbalance")
print(f"   • Clinical relevance: Suitable for pathology image analysis")

print(f"\n" + "=" * 80)
print(f"🏁 DENSENET-121 EVALUATION COMPLETED")
print(f"📊 Final Performance: {accuracy:.1%} Accuracy | {auc_score:.4f} AUC | {sensitivity:.1%} Sensitivity | {specificity:.1%} Specificity")
print(f"🏥 Clinical Status: {clinical_readiness}")
print(f"=" * 80)
# Out:
# 📋 COMPREHENSIVE DENSENET-121 MODEL EVALUATION SUMMARY
# ================================================================================
# 🏆 DENSENET-121 MODEL PERFORMANCE OVERVIEW:
#    • Overall Accuracy: 57.2%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_48/2780034883.py in <cell line: 0>()
#      12 print(f"🏆 DENSENET-121 MODEL PERFORMANCE OVERVIEW:")
#      13 print(f"   • Overall Accuracy: {accuracy:.1%}")
# ---> 14 print(f"   • AUC-ROC Score: {auc_score:.4f}")
#      15 print(f"   • Sensitivity (Mitotic Detection): {sensitivity:.1%}")
#      16 print(f"   • Specificity (Non-Mitotic Detection): {specificity:.1%}")
#
# NameError: name 'auc_score' is not defined
