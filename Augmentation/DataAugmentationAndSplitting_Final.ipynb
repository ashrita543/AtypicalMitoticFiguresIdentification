# %% [markdown]
# # Combined MIDOG Binary Classification - Data Processing
#
# This notebook focuses on data processing and analysis of the AMI-BR and MIDOG25 datasets for binary classification of mitotic figures.
#
# ## Dataset Overview:
# - **AMI-BR Dataset**: Uses `majority_atypical` column (True/False) for classification
# - **MIDOG25 Dataset**: Uses `majority` column (AMF/NMF) for classification
# - **Target**: Binary classification - Atypical vs Normal mitotic figures
#
# ## Data Processing Steps:
# 1. Data loading and preprocessing
# 2. Data visualization and analysis
# 3. Data preparation and splitting
# 4. Basic statistics and insights

# %%
# Import Required Libraries for Data Processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path
import cv2
from PIL import Image
import warnings
import json
warnings.filterwarnings('ignore')

# Sklearn for metrics and preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

print("Data processing libraries imported successfully!")
# Out:
# Data processing libraries imported successfully!

# %%
# Core libraries for data processing
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Image processing
import cv2
from PIL import Image

# Machine learning utilities (for basic analysis)
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# Plotting style
plt.style.use('default')
sns.set_palette("husl")

# Set random seeds for reproducibility
np.random.seed(42)

print("All data processing libraries imported successfully!")
# Out:
# All data processing libraries imported successfully!

# %%
# Set random seeds for reproducibility
import random

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)

set_seed(42)

# Define paths
BASE_DIR = Path('.')
AMI_BR_CSV = Path('/kaggle/input/mitoticfigure-dataset/Dataset/CSVFiles/AMI-BR.csv')
MIDOG25_CSV = Path('/kaggle/input/mitoticfigure-dataset/Dataset/CSVFiles/MIDOG25_Atypical_Classification_Train_Set.csv')
AMI_BR_DIR = Path('/kaggle/input/mitoticfigure-dataset/Dataset/AMI-BR')
MIDOG25_DIR = Path('/kaggle/input/mitoticfigure-dataset/Dataset/MIDOG25_Binary_Classification_Train_Set')

# Basic parameters for data processing
IMG_SIZE = 224
NUM_CLASSES = 2

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
# Load CSV files
ami_br_df = pd.read_csv(AMI_BR_CSV)
midog25_df = pd.read_csv(MIDOG25_CSV)

print("AMI-BR Dataset Info:")
print(f"Shape: {ami_br_df.shape}")
print(f"Columns: {ami_br_df.columns.tolist()}")
print(f"\nClass distribution in AMI-BR:")
print(ami_br_df['majority_atypical'].value_counts())

print("\n" + "="*50 + "\n")

print("MIDOG25 Dataset Info:")
print(f"Shape: {midog25_df.shape}")
print(f"Columns: {midog25_df.columns.tolist()}")
print(f"\nClass distribution in MIDOG25:")
print(midog25_df['majority'].value_counts())
# Out:
# AMI-BR Dataset Info:
# Shape: (3720, 12)
# Columns: ['Unnamed: 0', 'slide', 'dataset', 'uid', 'x', 'y', 'expert1_label', 'expert2_label', 'expert1_atypical', 'expert2_atypical', 'expert3_atypical', 'majority_atypical']
#
# Class distribution in AMI-BR:
# majority_atypical
# False    2888
# True      832
# Name: count, dtype: int64
#
# ==================================================
#
# MIDOG25 Dataset Info:
# Shape: (11939, 12)
# Columns: ['image_id', 'filename', 'coordinateX', 'coordinateY', 'Tumor', 'Scanner', 'Origin', 'Species', 'expert1', 'expert2', 'expert3', 'majority']
#
# Class distribution in MIDOG25:
# majority
# NMF    10191
# AMF     1748
# Name: count, dtype: int64

# %%
# Process AMI-BR dataset
def process_ami_br_data(df):
    processed_data = []
    
    for _, row in df.iterrows():
        uid = row['uid']
        dataset_name = row['dataset']  # This will be either 'MIDOG21' or 'TUPAC16'
        is_atypical = row['majority_atypical']
        
        # Determine the folder based on atypical status
        folder = 'atypical' if is_atypical else 'normal'
        
        # Create the expected filename using the dataset name from CSV
        filename = f"{dataset_name}_{uid}.png"
        image_path = AMI_BR_DIR / folder / filename
        slide = row['slide']

        # Check if file exists
        if image_path.exists():
            processed_data.append({
                'image_path': str(image_path),
                'filename': filename,
                'slideID': slide,
                'label': 1 if is_atypical else 0,  # 1 for atypical, 0 for normal
                'dataset': 'AMI-BR',
                'uid': uid,
                'source_dataset': dataset_name  # Keep track of MIDOG21 vs TUPAC16
            })
        else:
            # Debug: Print missing files to help troubleshoot
            print(f"Warning: File not found: {filename} in {folder} folder")

    
    return pd.DataFrame(processed_data)

# Process MIDOG25 dataset
def process_midog25_data(df):
    processed_data = []
    
    for _, row in df.iterrows():
        image_id = row['image_id']
        majority_class = row['majority']
        
        # Create the image path
        image_path = MIDOG25_DIR / image_id
        slide = row['filename']
        
        # Check if file exists
        if image_path.exists():
            # AMF = Atypical (1), NMF = Normal (0)
            label = 1 if majority_class == 'AMF' else 0
            
            processed_data.append({
                'image_path': str(image_path),
                'filename': image_id,
                'slideID': slide,
                'label': label,
                'dataset': 'MIDOG25',
                'uid': None  # MIDOG25 doesn't have uid
            })
    
    return pd.DataFrame(processed_data)

# Process both datasets
ami_br_processed = process_ami_br_data(ami_br_df)
midog25_processed = process_midog25_data(midog25_df)

print(f"AMI-BR processed: {len(ami_br_processed)} samples")
print(f"MIDOG25 processed: {len(midog25_processed)} samples")

# Display sample data
print("\nAMI-BR sample:")
print(ami_br_processed.head(3))
print("\nMIDOG25 sample:")
print(midog25_processed.head(3))
# Out:
# AMI-BR processed: 3720 samples
# MIDOG25 processed: 11939 samples
#
# AMI-BR sample:
#                                           image_path       filename   slideID  \
# 0  /kaggle/input/mitoticfigure-dataset/Dataset/AM...  MIDOG21_6.png  002.tiff
# 1  /kaggle/input/mitoticfigure-dataset/Dataset/AM...  MIDOG21_7.png  002.tiff
# 2  /kaggle/input/mitoticfigure-dataset/Dataset/AM...  MIDOG21_9.png  002.tiff
#
#    label dataset  uid source_dataset
# 0      0  AMI-BR    6        MIDOG21
# 1      1  AMI-BR    7        MIDOG21
# 2      0  AMI-BR    9        MIDOG21
#
# MIDOG25 sample:
#                                           image_path filename   slideID  \
# 0  /kaggle/input/mitoticfigure-dataset/Dataset/MI...    1.png  201.tiff
# 1  /kaggle/input/mitoticfigure-dataset/Dataset/MI...    2.png  201.tiff
# 2  /kaggle/input/mitoticfigure-dataset/Dataset/MI...    3.png  201.tiff
#
#    label  dataset   uid
# 0      0  MIDOG25  None
# 1      0  MIDOG25  None
# 2      0  MIDOG25  None

# %%
# Diagnostic check - verify data processing
print("🔍 DIAGNOSTIC CHECK:")
print(f"✓ AMI-BR processed samples: {len(ami_br_processed)}")
print(f"✓ MIDOG25 processed samples: {len(midog25_processed)}")

# Check if required columns exist
required_cols = ['image_path', 'label', 'dataset', 'slideID']
for df_name, df in [('AMI-BR', ami_br_processed), ('MIDOG25', midog25_processed)]:
    missing_cols = [col for col in required_cols if col not in df.columns]
    if missing_cols:
        print(f"❌ {df_name} missing columns: {missing_cols}")
    else:
        print(f"✓ {df_name} has all required columns")

# Check for any NaN values in critical columns
for df_name, df in [('AMI-BR', ami_br_processed), ('MIDOG25', midog25_processed)]:
    nan_counts = df[['image_path', 'label', 'slideID']].isna().sum()
    if nan_counts.sum() > 0:
        print(f"⚠️  {df_name} has NaN values:")
        for col, count in nan_counts.items():
            if count > 0:
                print(f"    {col}: {count} NaN values")
    else:
        print(f"✓ {df_name} has no NaN values in critical columns")

print("\n📊 Sample data preview:")
print("AMI-BR columns:", ami_br_processed.columns.tolist())
print("MIDOG25 columns:", midog25_processed.columns.tolist())
print("\n✅ If no errors shown above, data processing is successful!")
# Out:
# 🔍 DIAGNOSTIC CHECK:
# ✓ AMI-BR processed samples: 3720
# ✓ MIDOG25 processed samples: 11939
# ✓ AMI-BR has all required columns
# ✓ MIDOG25 has all required columns
# ✓ AMI-BR has no NaN values in critical columns
# ✓ MIDOG25 has no NaN values in critical columns
#
# 📊 Sample data preview:
# AMI-BR columns: ['image_path', 'filename', 'slideID', 'label', 'dataset', 'uid', 'source_dataset']
# MIDOG25 columns: ['image_path', 'filename', 'slideID', 'label', 'dataset', 'uid']
#
# ✅ If no errors shown above, data processing is successful!

# %%
# Check for potential duplicates between datasets using slideID
def check_for_duplicates():
    # Extract slide identifiers for comparison
    ami_br_slides = set()
    for _, row in ami_br_processed.iterrows():
        # Use slideID for AMI-BR dataset
        if pd.notna(row['slideID']):
            ami_br_slides.add(row['slideID'])
    
    midog25_slides = set()
    for _, row in midog25_processed.iterrows():
        # Use slideID for MIDOG25 dataset
        if pd.notna(row['slideID']):
            midog25_slides.add(row['slideID'])
    
    # Find potential overlaps based on slide IDs
    potential_duplicates = ami_br_slides.intersection(midog25_slides)
    
    print(f"AMI-BR unique slide IDs: {len(ami_br_slides)}")
    print(f"MIDOG25 unique slide IDs: {len(midog25_slides)}")
    print(f"Overlapping slide IDs: {len(potential_duplicates)}")
    
    if potential_duplicates:
        print(f"First few overlapping slides: {list(potential_duplicates)[:10]}")
        
        # Show breakdown by source dataset for overlapping slides
        if 'source_dataset' in ami_br_processed.columns:
            ami_br_overlap_samples = ami_br_processed[ami_br_processed['slideID'].isin(potential_duplicates)]
            if len(ami_br_overlap_samples) > 0:
                ami_br_duplicates_by_source = ami_br_overlap_samples['source_dataset'].value_counts()
                print(f"Overlapping samples in AMI-BR by source:")
                for source, count in ami_br_duplicates_by_source.items():
                    print(f"  {source}: {count} samples from overlapping slides")
        
        # Show sample counts for overlapping slides
        ami_br_overlap_count = len(ami_br_processed[ami_br_processed['slideID'].isin(potential_duplicates)])
        midog25_overlap_count = len(midog25_processed[midog25_processed['slideID'].isin(potential_duplicates)])
        print(f"Total samples from overlapping slides:")
        print(f"  AMI-BR: {ami_br_overlap_count} samples")
        print(f"  MIDOG25: {midog25_overlap_count} samples")
    
    return potential_duplicates

duplicates = check_for_duplicates()
# Out:
# AMI-BR unique slide IDs: 202
# MIDOG25 unique slide IDs: 475
# Overlapping slide IDs: 135
# First few overlapping slides: ['133.tiff', '055.tiff', '046.tiff', '062.tiff', '110.tiff', '087.tiff', '064.tiff', '049.tiff', '111.tiff', '039.tiff']
# Overlapping samples in AMI-BR by source:
#   MIDOG21: 1721 samples from overlapping slides
# Total samples from overlapping slides:
#   AMI-BR: 1721 samples
#   MIDOG25: 1723 samples

# %%
# Handle duplicates by keeping only MIDOG25 versions (based on slideID)
def remove_duplicates(ami_br_df, midog25_df, duplicate_slide_ids):
    if not duplicate_slide_ids:
        return ami_br_df, midog25_df
    
    # Remove samples from overlapping slides from AMI-BR dataset
    ami_br_filtered = ami_br_df[~ami_br_df['slideID'].isin(duplicate_slide_ids)].copy()
    
    removed_samples = len(ami_br_df) - len(ami_br_filtered)
    print(f"Removed {removed_samples} samples from {len(duplicate_slide_ids)} overlapping slides in AMI-BR")
    print(f"AMI-BR samples after deduplication: {len(ami_br_filtered)}")
    print(f"MIDOG25 samples: {len(midog25_df)}")
    
    # Show which slides were removed
    if removed_samples > 0:
        removed_slides_info = ami_br_df[ami_br_df['slideID'].isin(duplicate_slide_ids)]
        if 'source_dataset' in removed_slides_info.columns:
            print(f"Removed samples by source dataset:")
            for source, count in removed_slides_info['source_dataset'].value_counts().items():
                print(f"  {source}: {count} samples")
    
    return ami_br_filtered, midog25_df

# Remove duplicates
ami_br_final, midog25_final = remove_duplicates(ami_br_processed, midog25_processed, duplicates)

# Combine datasets
combined_df = pd.concat([ami_br_final, midog25_final], ignore_index=True)

print(f"\nCombined dataset shape: {combined_df.shape}")
print(f"Class distribution in combined dataset:")
print(combined_df['label'].value_counts())
print(f"Dataset distribution:")
print(combined_df['dataset'].value_counts())
# Out:
# Removed 1721 samples from 135 overlapping slides in AMI-BR
# AMI-BR samples after deduplication: 1999
# MIDOG25 samples: 11939
# Removed samples by source dataset:
#   MIDOG21: 1721 samples
#
# Combined dataset shape: (13938, 7)
# Class distribution in combined dataset:
# label
# 0    11762
# 1     2176
# Name: count, dtype: int64
# Dataset distribution:
# dataset
# MIDOG25    11939
# AMI-BR      1999
# Name: count, dtype: int64

# %% [markdown]
# ## Data Augmentation for AMF Oversampling
#
# To balance the dataset, we'll oversample AMF (Atypical) images by generating 4 additional augmented versions of each AMF image, resulting in 5 total images per original AMF sample.

# %%
# Import additional libraries for data augmentation
from PIL import Image, ImageEnhance, ImageFilter
import random
from scipy import ndimage
import copy

print("Augmentation libraries imported successfully!")
# Out:
# Augmentation libraries imported successfully!

# %%
# Define augmentation functions for AMF images
def augment_image(image_path, augmentation_type):
    """
    Apply specific augmentation to an image and return the augmented image array.
    
    Args:
        image_path: Path to the original image
        augmentation_type: Type of augmentation to apply (1-4)
    
    Returns:
        Augmented image as numpy array
    """
    # Load image
    img = Image.open(image_path)
    
    if augmentation_type == 1:
        # Rotation (15-30 degrees)
        angle = random.uniform(15, 30) * random.choice([-1, 1])
        img = img.rotate(angle, fillcolor=(255, 255, 255))
        
    elif augmentation_type == 2:
        # Horizontal flip + slight brightness adjustment
        img = img.transpose(Image.FLIP_LEFT_RIGHT)
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(random.uniform(0.9, 1.1))
        
    elif augmentation_type == 3:
        # Vertical flip + contrast adjustment
        img = img.transpose(Image.FLIP_TOP_BOTTOM)
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(random.uniform(0.9, 1.1))
        
    elif augmentation_type == 4:
        # Combination: slight rotation + sharpness adjustment
        angle = random.uniform(5, 15) * random.choice([-1, 1])
        img = img.rotate(angle, fillcolor=(255, 255, 255))
        enhancer = ImageEnhance.Sharpness(img)
        img = enhancer.enhance(random.uniform(0.9, 1.1))
    
    # Convert to numpy array (same format as original processing)
    return np.array(img)

# Function to create augmented dataset entries
def create_augmented_entry(original_entry, aug_type):
    """
    Create a new dataframe entry for an augmented image.
    """
    new_entry = original_entry.copy()
    
    # Add augmentation metadata
    new_entry['is_augmented'] = True
    new_entry['augmentation_type'] = aug_type
    new_entry['original_image_path'] = original_entry['image_path']
    
    return new_entry

print("Augmentation functions defined successfully!")
# Out:
# Augmentation functions defined successfully!

# %%
# Note: Augmentation now happens AFTER splitting, not here.
# This ensures only training data gets augmented, preventing data leakage.
print("📋 Keeping original dataset intact for proper train/val/test splitting...")
print("🎯 Augmentation will be applied only to training data after splitting.")
# Out:
# 📋 Keeping original dataset intact for proper train/val/test splitting...
# 🎯 Augmentation will be applied only to training data after splitting.

# %%
# Visualize original AMF samples with potential augmentations
def visualize_augmentation_preview(df, n_original_samples=2):
    """
    Visualize original AMF images alongside what their augmented versions would look like.
    This shows the augmentation techniques without requiring augmented data to exist.
    """
    # Get AMF samples (atypical images)
    original_amf = df[df['label'] == 1]
    
    if len(original_amf) == 0:
        print("No AMF samples found for visualization")
        return
    
    # Sample a few original images
    sample_originals = original_amf.sample(min(n_original_samples, len(original_amf)))
    
    print(f"📋 Showing {len(sample_originals)} AMF samples with augmentation preview...")
    
    for idx, (_, original_row) in enumerate(sample_originals.iterrows()):
        # Create subplot for original + 4 augmented versions
        fig, axes = plt.subplots(1, 5, figsize=(20, 4))
        
        # Get original image path
        original_path = original_row['image_path']
        
        try:
            # Show original image
            original_img = Image.open(original_path)
            axes[0].imshow(original_img)
            axes[0].set_title(f"Original AMF\n{original_row['dataset']}")
            axes[0].axis('off')
            
            # Show 4 augmented versions (preview)
            for aug_type in range(1, 5):
                try:
                    aug_img = augment_image(original_path, aug_type)
                    axes[aug_type].imshow(aug_img)
                    
                    aug_names = {1: "Rotation", 2: "H-Flip + Brightness", 
                               3: "V-Flip + Contrast", 4: "Rotation + Sharpness"}
                    axes[aug_type].set_title(f"Preview Aug {aug_type}:\n{aug_names[aug_type]}")
                    axes[aug_type].axis('off')
                    
                except Exception as e:
                    axes[aug_type].text(0.5, 0.5, f"Error: {str(e)[:20]}...", 
                                       ha='center', va='center', transform=axes[aug_type].transAxes)
                    axes[aug_type].set_title(f"Aug {aug_type}: Error")
                    axes[aug_type].axis('off')
            
            plt.suptitle(f"AMF Augmentation Preview {idx + 1}", fontsize=16)
            plt.tight_layout()
            plt.show()
            
        except Exception as e:
            print(f"Error visualizing {original_path}: {e}")

# Visualize augmentation preview (since actual augmentation happens later)
print("🖼️ Previewing AMF augmentation techniques...")
print("📝 Note: Actual augmentation will be applied only to training data after splitting")
visualize_augmentation_preview(combined_df, n_original_samples=2)
# Out:
# 🖼️ Previewing AMF augmentation techniques...
# 📝 Note: Actual augmentation will be applied only to training data after splitting
# 📋 Showing 2 AMF samples with augmentation preview...

# %%
# Basic class distribution visualization (before augmentation)
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Overall class distribution (original data)
combined_df['label'].value_counts().plot(kind='bar', ax=axes[0,0], color=['skyblue', 'lightcoral'])
axes[0,0].set_title('Class Distribution (Original Data)')
axes[0,0].set_xlabel('Class (0=Normal, 1=Atypical)')
axes[0,0].set_ylabel('Count')
axes[0,0].tick_params(axis='x', rotation=0)

# Dataset distribution
combined_df['dataset'].value_counts().plot(kind='bar', ax=axes[0,1], color=['lightgreen', 'orange'])
axes[0,1].set_title('Dataset Distribution')
axes[0,1].set_xlabel('Dataset')
axes[0,1].set_ylabel('Count')
axes[0,1].tick_params(axis='x', rotation=45)

# Class distribution by dataset
pd.crosstab(combined_df['dataset'], combined_df['label']).plot(kind='bar', ax=axes[1,0], 
                                                              color=['skyblue', 'lightcoral'])
axes[1,0].set_title('Class Distribution by Dataset')
axes[1,0].set_xlabel('Dataset')
axes[1,0].set_ylabel('Count')
axes[1,0].legend(['Normal', 'Atypical'])
axes[1,0].tick_params(axis='x', rotation=45)

# Percentage distribution
class_pct = combined_df['label'].value_counts(normalize=True) * 100
class_pct.plot(kind='pie', ax=axes[1,1], autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])
axes[1,1].set_title('Class Distribution (Percentage)')
axes[1,1].set_ylabel('')

plt.tight_layout()
plt.show()

# Print detailed statistics for original data
print("📊 ORIGINAL DATA STATISTICS (Before Augmentation):")
print("=" * 60)
print(f"Total samples: {len(combined_df)}")
print(f"Normal samples: {len(combined_df[combined_df['label'] == 0])} ({len(combined_df[combined_df['label'] == 0])/len(combined_df)*100:.1f}%)")
print(f"Atypical samples: {len(combined_df[combined_df['label'] == 1])} ({len(combined_df[combined_df['label'] == 1])/len(combined_df)*100:.1f}%)")

print(f"\nOriginal class imbalance:")
normal_count = len(combined_df[combined_df['label'] == 0])
amf_count = len(combined_df[combined_df['label'] == 1])
imbalance_ratio = normal_count / amf_count
print(f"  Normal:AMF ratio = {imbalance_ratio:.2f}:1")
print(f"  This imbalance will be addressed through training-only augmentation")

print(f"\nDataset composition:")
print(pd.crosstab(combined_df['dataset'], combined_df['label'], margins=True))

print(f"\n🎯 Next Steps:")
print(f"  1. Split data into train/val/test using stratified splitting")
print(f"  2. Apply augmentation ONLY to training AMF images")
print(f"  3. Keep validation and test sets completely original")
print("=" * 60)
# Out:
# 📊 ORIGINAL DATA STATISTICS (Before Augmentation):
# ============================================================
# Total samples: 13938
# Normal samples: 11762 (84.4%)
# Atypical samples: 2176 (15.6%)
#
# Original class imbalance:
#   Normal:AMF ratio = 5.41:1
#   This imbalance will be addressed through training-only augmentation
#
# Dataset composition:
# label        0     1    All
# dataset
# AMI-BR    1571   428   1999
# MIDOG25  10191  1748  11939
# All      11762  2176  13938
#
# 🎯 Next Steps:
#   1. Split data into train/val/test using stratified splitting
#   2. Apply augmentation ONLY to training AMF images
#   3. Keep validation and test sets completely original
# ============================================================

# %% [markdown]
# ## Save Augmented Images and Create Kaggle CSV
#
# For Kaggle submission, we need to save all images as files and create a CSV with filename and labels (True/False for Atypical/Normal).

# %%
import shutil
from pathlib import Path
import os

# Define output directory with separate folders for train/val/test
OUTPUT_DIR = Path(os.getcwd()) / 'kaggle_dataset'
TRAINING_DIR = OUTPUT_DIR / 'training'
VALIDATION_DIR = OUTPUT_DIR / 'validation'
TESTING_DIR = OUTPUT_DIR / 'testing'
CSV_FILE = OUTPUT_DIR / 'dataset.csv'

# Create directories
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
TRAINING_DIR.mkdir(parents=True, exist_ok=True)
VALIDATION_DIR.mkdir(parents=True, exist_ok=True)
TESTING_DIR.mkdir(parents=True, exist_ok=True)

print(f"📁 Created output directory: {OUTPUT_DIR}")
print(f"📁 Created training directory: {TRAINING_DIR}")
print(f"📁 Created validation directory: {VALIDATION_DIR}")
print(f"📁 Created testing directory: {TESTING_DIR}")

# Prepare CSV data for each split
training_data = []
validation_data = []
testing_data = []
copied_files = 0
copy_errors = 0

print("🔄 Processing and organizing images by splits...")

# Function to copy and organize images
def copy_and_organize_images(df, target_dir, split_name, data_list):
    """Copy images from dataframe to target directory and update data list"""
    local_copied = 0
    local_errors = 0
    
    print(f"\n📂 Processing {split_name} images...")
    
    for idx, (_, row) in enumerate(df.iterrows()):
        original_path = row['image_path']
        original_filename = row['filename']
        label = row['label']  # 0 = Normal, 1 = Atypical

        # Convert label to True/False (True = Atypical, False = Normal)
        is_atypical = label == 1
        
        try:
            # Check if the file exists before copying
            if not os.path.exists(original_path):
                print(f"⚠️ Warning: Image not found: {original_path}")
                local_errors += 1
                continue
                
            # Copy image to split-specific directory
            destination_path = target_dir / original_filename
            shutil.copy2(original_path, destination_path)

            # Add to split-specific CSV data
            data_list.append({
                'filename': original_filename,
                'is_atypical': is_atypical,
                'dataset': row['dataset'],
                'split': split_name,
                'is_augmented': row.get('is_augmented', False),
                'augmentation_type': row.get('augmentation_type', None)
            })

            local_copied += 1

        except Exception as e:
            print(f"❌ Error copying {original_filename}: {e}")
            local_errors += 1

        # Progress update
        if (idx + 1) % 100 == 0 or (idx + 1) == len(df):
            print(f"  ✅ Processed {idx + 1}/{len(df)} {split_name} images...")
    
    print(f"  📊 {split_name}: {local_copied} copied, {local_errors} errors")
    return local_copied, local_errors

# Note: This section is a placeholder for data organization
# The actual organization will happen after augmentation is complete
print("📝 Data organization will be performed after augmentation...")
print("🔄 Skipping image copying for now - will be done later...")

# Initialize empty counters for now
train_copied, train_errors = 0, 0
val_copied, val_errors = 0, 0
test_copied, test_errors = 0, 0

# Calculate placeholder totals
copied_files = train_copied + val_copied + test_copied
copy_errors = train_errors + val_errors + test_errors

print(f"\n📝 Placeholder - Actual image organization happens after augmentation!")
print(f"📊 This section will be updated later in the workflow...")
print(f"  Training images: will be processed after augmentation")
print(f"  Validation images: will be processed after augmentation")
print(f"  Testing images: will be processed after augmentation")
# Out:
# 📁 Created output directory: /kaggle/working/kaggle_dataset
# 📁 Created training directory: /kaggle/working/kaggle_dataset/training
# 📁 Created validation directory: /kaggle/working/kaggle_dataset/validation
# 📁 Created testing directory: /kaggle/working/kaggle_dataset/testing
# 🔄 Processing and organizing images by splits...
# 📝 Data organization will be performed after augmentation...
# 🔄 Skipping image copying for now - will be done later...
#
# 📝 Placeholder - Actual image organization happens after augmentation!
# 📊 This section will be updated later in the workflow...
#   Training images: will be processed after augmentation
#   Validation images: will be processed after augmentation
#   Testing images: will be processed after augmentation

# %%
# This section will be updated after augmentation is complete
print("📝 Image organization and CSV creation will happen after augmentation...")
print("🔄 Please run the augmentation section first, then return here")

# Initialize placeholders
all_data = []
# Out:
# 📝 Image organization and CSV creation will happen after augmentation...
# 🔄 Please run the augmentation section first, then return here

# %%
# Placeholder: CSV creation happens after image organization
print("📝 CSV creation will happen after augmentation and image organization...")
print("🔄 Please run the augmentation and organization sections first")
print("📄 The final CSV will be created in the last section with all organized data")
# Out:
# 📝 CSV creation will happen after augmentation and image organization...
# 🔄 Please run the augmentation and organization sections first
# 📄 The final CSV will be created in the last section with all organized data

# %%
# Placeholder: File verification happens after image organization
print("📝 File verification will happen after augmentation and image organization...")
print("🔄 Please run the augmentation and organization sections first")
print("📊 File verification and visualization will be available in the final section")
# Out:
# 📝 File verification will happen after augmentation and image organization...
# 🔄 Please run the augmentation and organization sections first
# 📊 File verification and visualization will be available in the final section

# %% [markdown]
# ## Data Visualization and Analysis

# %%
# Visualize class distribution
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Overall class distribution
combined_df['label'].value_counts().plot(kind='bar', ax=axes[0,0], color=['skyblue', 'lightcoral'])
axes[0,0].set_title('Overall Class Distribution')
axes[0,0].set_xlabel('Class (0=Normal, 1=Atypical)')
axes[0,0].set_ylabel('Count')
axes[0,0].tick_params(axis='x', rotation=0)

# Dataset distribution
combined_df['dataset'].value_counts().plot(kind='bar', ax=axes[0,1], color=['lightgreen', 'orange'])
axes[0,1].set_title('Dataset Distribution')
axes[0,1].set_xlabel('Dataset')
axes[0,1].set_ylabel('Count')
axes[0,1].tick_params(axis='x', rotation=45)

# Class distribution by dataset
pd.crosstab(combined_df['dataset'], combined_df['label']).plot(kind='bar', ax=axes[1,0], 
                                                              color=['skyblue', 'lightcoral'])
axes[1,0].set_title('Class Distribution by Dataset')
axes[1,0].set_xlabel('Dataset')
axes[1,0].set_ylabel('Count')
axes[1,0].legend(['Normal', 'Atypical'])
axes[1,0].tick_params(axis='x', rotation=45)

# Percentage distribution
class_pct = combined_df['label'].value_counts(normalize=True) * 100
class_pct.plot(kind='pie', ax=axes[1,1], autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])
axes[1,1].set_title('Class Distribution (Percentage)')
axes[1,1].set_ylabel('')

plt.tight_layout()
plt.show()

# Print detailed statistics
print("Detailed Statistics:")
print(f"Total samples: {len(combined_df)}")
print(f"Normal samples: {len(combined_df[combined_df['label'] == 0])} ({len(combined_df[combined_df['label'] == 0])/len(combined_df)*100:.1f}%)")
print(f"Atypical samples: {len(combined_df[combined_df['label'] == 1])} ({len(combined_df[combined_df['label'] == 1])/len(combined_df)*100:.1f}%)")
print(f"\nBy dataset:")
print(pd.crosstab(combined_df['dataset'], combined_df['label'], margins=True))
# Out:
# Detailed Statistics:
# Total samples: 13938
# Normal samples: 11762 (84.4%)
# Atypical samples: 2176 (15.6%)
#
# By dataset:
# label        0     1    All
# dataset
# AMI-BR    1571   428   1999
# MIDOG25  10191  1748  11939
# All      11762  2176  13938

# %%
# Sample image visualization
def visualize_samples(df, n_samples=8):
    fig, axes = plt.subplots(2, 4, figsize=(16, 8))
    axes = axes.ravel()
    
    # Get samples from each class and dataset
    samples = []
    for dataset in ['AMI-BR', 'MIDOG25']:
        for label in [0, 1]:
            subset = df[(df['dataset'] == dataset) & (df['label'] == label)]
            if len(subset) > 0:
                samples.extend(subset.sample(min(2, len(subset))).to_dict('records'))
    
    for i, sample in enumerate(samples[:8]):
        try:
            img = Image.open(sample['image_path'])
            axes[i].imshow(img)
            axes[i].set_title(f"{sample['dataset']}\n{'Atypical' if sample['label'] == 1 else 'Normal'}")
            axes[i].axis('off')
        except Exception as e:
            axes[i].text(0.5, 0.5, f"Error loading\n{sample['filename']}", 
                        ha='center', va='center', transform=axes[i].transAxes)
            axes[i].set_title(f"{sample['dataset']} - {'Atypical' if sample['label'] == 1 else 'Normal'}")
            axes[i].axis('off')
    
    plt.tight_layout()
    plt.show()

visualize_samples(combined_df)

# %% [markdown]
# ## Data Preparation for Training

# %%
# Split the data into train, validation, and test sets
# IMPORTANT: Use stratified splitting to maintain balanced class distribution
# Note: Since slides can contain both NMF and AMF samples, we split by individual samples

def stratified_split(df, train_size=0.6, val_size=0.2, test_size=0.2, random_state=42):
    """
    Split data using stratified sampling to maintain balanced class distribution.
    Since slides can contain both normal and atypical samples, we split by individual samples.
    
    Args:
        df: Input dataframe
        train_size: Proportion for training (default 0.6 = 60%)
        val_size: Proportion for validation (default 0.2 = 20%)
        test_size: Proportion for testing (default 0.2 = 20%)
        random_state: Random seed for reproducibility
    """
    # Verify proportions sum to 1
    total_proportion = train_size + val_size + test_size
    if abs(total_proportion - 1.0) > 1e-6:
        raise ValueError(f"Proportions must sum to 1.0, got {total_proportion}")
    
    print(f"📊 Stratified Splitting (60% Train, 20% Val, 20% Test):")
    print(f"Total samples: {len(df)}")
    print(f"Target split: {train_size*100:.0f}% train, {val_size*100:.0f}% val, {test_size*100:.0f}% test")
    print(f"Class distribution:")
    class_dist = df['label'].value_counts()
    class_pct = df['label'].value_counts(normalize=True) * 100
    print(f"  Normal (0): {class_dist.get(0, 0)} ({class_pct.get(0, 0):.1f}%)")
    print(f"  Atypical (1): {class_dist.get(1, 0)} ({class_pct.get(1, 0):.1f}%)")
    
    # Check slide composition to confirm our approach
    slide_class_info = df.groupby('slideID')['label'].agg(['nunique', 'count', 'sum'])
    slide_class_info['has_both_classes'] = slide_class_info['nunique'] > 1
    slides_with_both = slide_class_info['has_both_classes'].sum()
    
    print(f"\nSlide analysis:")
    print(f"  Total unique slides: {len(slide_class_info)}")
    print(f"  Slides with both classes: {slides_with_both}")
    print(f"  Slides with only one class: {len(slide_class_info) - slides_with_both}")
    
    if slides_with_both > 0:
        print(f"  ✓ Confirmed: {slides_with_both} slides contain both NMF and AMF samples")
        print(f"  → Using individual sample stratification instead of slide-based splitting")
    
    # First split: train+val vs test (stratified by labels)
    X = df.drop('label', axis=1)
    y = df['label']
    
    X_train_val, X_test, y_train_val, y_test = train_test_split(
        X, y,
        test_size=test_size,  # 20% for test
        random_state=random_state,
        stratify=y  # 🎯 STRATIFIED by class labels
    )
    
    # Second split: train vs val from remaining 80%
    # val_size needs to be adjusted: 20% of total = 25% of remaining 80%
    val_size_adjusted = val_size / (train_size + val_size)  # 0.2 / 0.8 = 0.25
    
    X_train, X_val, y_train, y_val = train_test_split(
        X_train_val, y_train_val,
        test_size=val_size_adjusted,  # 25% of remaining 80% = 20% of total
        random_state=random_state,
        stratify=y_train_val  # 🎯 STRATIFIED by class labels
    )
    
    # Reconstruct dataframes
    train_df = pd.concat([X_train, y_train], axis=1)
    val_df = pd.concat([X_val, y_val], axis=1)
    test_df = pd.concat([X_test, y_test], axis=1)
    
    # Verify exact proportions achieved
    total_samples = len(df)
    actual_train_pct = len(train_df) / total_samples * 100
    actual_val_pct = len(val_df) / total_samples * 100
    actual_test_pct = len(test_df) / total_samples * 100
    
    print(f"\n✅ Sample distribution:")
    print(f"Training samples: {len(train_df)} ({actual_train_pct:.1f}%)")
    print(f"Validation samples: {len(val_df)} ({actual_val_pct:.1f}%)")
    print(f"Test samples: {len(test_df)} ({actual_test_pct:.1f}%)")
    
    # Verify stratification worked
    print(f"\n🎯 Class distribution verification (stratified):")
    for split_name, split_df in [("Train", train_df), ("Val", val_df), ("Test", test_df)]:
        class_dist = split_df['label'].value_counts()
        class_pct = split_df['label'].value_counts(normalize=True) * 100
        print(f"{split_name}: Normal={class_dist.get(0, 0)} ({class_pct.get(0, 0):.1f}%), "
              f"Atypical={class_dist.get(1, 0)} ({class_pct.get(1, 0):.1f}%)")
    
    return train_df, val_df, test_df

# Use stratified splitting with 60-20-20 split
print("🔬 Using STRATIFIED splitting with 60% train, 20% val, 20% test...")
train_df, val_df, test_df = stratified_split(
    combined_df, train_size=0.6, val_size=0.2, test_size=0.2, random_state=42
)

print(f"\n📈 Final sample distribution (BEFORE augmentation):")
print(f"Training set: {len(train_df)} samples")
print(f"Validation set: {len(val_df)} samples")
print(f"Test set: {len(test_df)} samples")

# Check detailed class distribution in each set (before augmentation)
print("\n📊 Detailed class distribution (BEFORE augmentation):")
print("Train:", train_df['label'].value_counts().to_dict())
print("Val:", val_df['label'].value_counts().to_dict())
print("Test:", test_df['label'].value_counts().to_dict())
# Out:
# 🔬 Using STRATIFIED splitting with 60% train, 20% val, 20% test...
# 📊 Stratified Splitting (60% Train, 20% Val, 20% Test):
# Total samples: 13938
# Target split: 60% train, 20% val, 20% test
# Class distribution:
#   Normal (0): 11762 (84.4%)
#   Atypical (1): 2176 (15.6%)
#
# Slide analysis:
#   Total unique slides: 542
#   Slides with both classes: 365
#   Slides with only one class: 177
#   ✓ Confirmed: 365 slides contain both NMF and AMF samples
#   → Using individual sample stratification instead of slide-based splitting
#
# ✅ Sample distribution:
# Training samples: 8362 (60.0%)
# Validation samples: 2788 (20.0%)
# Test samples: 2788 (20.0%)
#
# 🎯 Class distribution verification (stratified):
# Train: Normal=7056 (84.4%), Atypical=1306 (15.6%)
# Val: Normal=2353 (84.4%), Atypical=435 (15.6%)
# Test: Normal=2353 (84.4%), Atypical=435 (15.6%)
#
# 📈 Final sample distribution (BEFORE augmentation):
# Training set: 8362 samples
# Validation set: 2788 samples
# Test set: 2788 samples
#
# 📊 Detailed class distribution (BEFORE augmentation):
# Train: {0: 7056, 1: 1306}
# Val: {0: 2353, 1: 435}
# Test: {0: 2353, 1: 435}

# %% [markdown]
# ## Data Augmentation (Training Set Only)
#
# **IMPORTANT**: Augmentation is applied ONLY to the training set to:
# 1. Balance the classes in training data
# 2. Keep validation and test sets unaugmented for fair evaluation
# 3. Prevent data leakage between splits

# %%
# Apply augmentation ONLY to AMF (Atypical) images in TRAINING set
print("🎨 Applying augmentation ONLY to AMF images in TRAINING dataset...")
print("🎯 Strategy: Balance training data while keeping validation/test unaugmented")

# Filter AMF (atypical) images from the TRAINING dataset only
train_amf_images = train_df[train_df['label'] == 1].copy()
train_normal_images = train_df[train_df['label'] == 0].copy()

print(f"\n📊 Training set breakdown (before augmentation):")
print(f"Training AMF images: {len(train_amf_images)}")
print(f"Training Normal images: {len(train_normal_images)}")

# Create augmented versions ONLY for training AMF images
augmented_entries = []
augmentation_success = 0
augmentation_errors = 0

# Set random seed for reproducible augmentations
random.seed(42)

print(f"\n🔄 Augmenting ONLY training AMF images...")

for idx, (_, row) in enumerate(train_amf_images.iterrows()):
    image_path = row['image_path']
    
    # Check if original image exists
    if not os.path.exists(image_path):
        print(f"⚠️ Warning: Original image not found: {image_path}")
        augmentation_errors += 1
        continue
    
    try:
        # Generate 4 augmented versions (types 1-4) for training data only
        for aug_type in range(1, 5):
            # Create augmented image
            augmented_img_array = augment_image(image_path, aug_type)
            augmented_img = Image.fromarray(augmented_img_array.astype('uint8'))
            
            # Create augmented filename and temporary path for organization later
            original_filename = row['filename']
            base_name, ext = os.path.splitext(original_filename)
            augmented_filename = f"{base_name}_aug{aug_type}{ext}"
            
            # Create temp directory to store augmented images
            temp_aug_dir = Path(os.getcwd()) / 'temp_augmented'
            temp_aug_dir.mkdir(exist_ok=True)
            
            # Save augmented image to temporary location
            temp_aug_path = temp_aug_dir / augmented_filename
            augmented_img.save(temp_aug_path)
            
            # Create augmented entry with correct path
            aug_entry = create_augmented_entry(row, aug_type)
            aug_entry['image_path'] = str(temp_aug_path)  # Update to actual saved path
            aug_entry['filename'] = augmented_filename  # Ensure filename is correct
            
            augmented_entries.append(aug_entry)
            augmentation_success += 1
        
        # Progress update
        if (idx + 1) % 50 == 0 or (idx + 1) == len(train_amf_images):
            print(f"  ✅ Processed {idx + 1}/{len(train_amf_images)} training AMF images, created {augmentation_success} augmented images...")
            
    except Exception as e:
        print(f"  ❌ Error processing {image_path}: {e}")
        augmentation_errors += 1

# Create augmented dataframe
augmented_df = pd.DataFrame(augmented_entries)

# Add metadata to original training images
train_df['is_augmented'] = False
train_df['augmentation_type'] = None

# Add metadata to validation and test images (never augmented)
val_df['is_augmented'] = False
val_df['augmentation_type'] = None
test_df['is_augmented'] = False
test_df['augmentation_type'] = None

# Combine original training data with augmented training data
train_augmented_df = pd.concat([train_df, augmented_df], ignore_index=True)

print(f"\n✅ Training augmentation completed!")
print(f"📊 Training set results:")
print(f"   Original training samples: {len(train_df)}")
print(f"   Augmented training samples: {len(augmented_df)}")
print(f"   Total training samples: {len(train_augmented_df)}")
print(f"   Augmentation success: {augmentation_success}")
print(f"   Augmentation errors: {augmentation_errors}")

# Update final dataset with augmented training data + original val/test data
final_combined_df = pd.concat([train_augmented_df, val_df, test_df], ignore_index=True)

# Calculate final statistics
final_class_counts = final_combined_df['label'].value_counts()
final_class_pct = final_combined_df['label'].value_counts(normalize=True) * 100

print(f"\n📊 FINAL DATASET COMPOSITION (After training augmentation):")
print(f"Total samples: {len(final_combined_df)}")
print(f"Normal: {final_class_counts.get(0, 0)} ({final_class_pct.get(0, 0):.1f}%)")
print(f"Atypical (AMF): {final_class_counts.get(1, 0)} ({final_class_pct.get(1, 0):.1f}%)")

print(f"\n🔍 Final breakdown by split:")
print(f"Training (augmented): {len(train_augmented_df)} samples")
print(f"   - Training Normal: {len(train_augmented_df[train_augmented_df['label'] == 0])}")
print(f"   - Training AMF (original): {len(train_augmented_df[(train_augmented_df['label'] == 1) & (train_augmented_df['is_augmented'] == False)])}")
print(f"   - Training AMF (augmented): {len(train_augmented_df[(train_augmented_df['label'] == 1) & (train_augmented_df['is_augmented'] == True)])}")
print(f"Validation (original only): {len(val_df)} samples")
print(f"   - Validation Normal: {len(val_df[val_df['label'] == 0])}")
print(f"   - Validation AMF: {len(val_df[val_df['label'] == 1])}")
print(f"Testing (original only): {len(test_df)} samples")
print(f"   - Testing Normal: {len(test_df[test_df['label'] == 0])}")
print(f"   - Testing AMF: {len(test_df[test_df['label'] == 1])}")

# Update the combined dataset variable with the final augmented dataset
combined_df = final_combined_df
print(f"\n✅ Dataset updated with training augmentation only!")
print(f"🎯 Key achievement: Only training data augmented, validation/test remain original!")
# Out:
# 🎨 Applying augmentation ONLY to AMF images in TRAINING dataset...
# 🎯 Strategy: Balance training data while keeping validation/test unaugmented
#
# 📊 Training set breakdown (before augmentation):
# Training AMF images: 1306
# Training Normal images: 7056
#
# 🔄 Augmenting ONLY training AMF images...
#   ✅ Processed 50/1306 training AMF images, created 200 augmented images...
#   ✅ Processed 100/1306 training AMF images, created 400 augmented images...
#   ✅ Processed 150/1306 training AMF images, created 600 augmented images...
#   ✅ Processed 200/1306 training AMF images, created 800 augmented images...
#   ✅ Processed 250/1306 training AMF images, created 1000 augmented images...
#   ✅ Processed 300/1306 training AMF images, created 1200 augmented images...
#   ✅ Processed 350/1306 training AMF images, created 1400 augmented images...
#   ✅ Processed 400/1306 training AMF images, created 1600 augmented images...
#   ✅ Processed 450/1306 training AMF images, created 1800 augmented images...
#   ✅ Processed 500/1306 training AMF images, created 2000 augmented images...
#   ✅ Processed 550/1306 training AMF images, created 2200 augmented images...
#   ✅ Processed 600/1306 training AMF images, created 2400 augmented images...
#   ✅ Processed 650/1306 training AMF images, created 2600 augmented images...
#   ✅ Processed 700/1306 training AMF images, created 2800 augmented images...
#   ✅ Processed 750/1306 training AMF images, created 3000 augmented images...
#   ✅ Processed 800/1306 training AMF images, created 3200 augmented images...
#   ✅ Processed 850/1306 training AMF images, created 3400 augmented images...
#   ✅ Processed 900/1306 training AMF images, created 3600 augmented images...
#   ✅ Processed 950/1306 training AMF images, created 3800 augmented images...
#   ✅ Processed 1000/1306 training AMF images, created 4000 augmented images...
#   ✅ Processed 1050/1306 training AMF images, created 4200 augmented images...
#   ✅ Processed 1100/1306 training AMF images, created 4400 augmented images...
#   ✅ Processed 1150/1306 training AMF images, created 4600 augmented images...
#   ✅ Processed 1200/1306 training AMF images, created 4800 augmented images...
#   ✅ Processed 1250/1306 training AMF images, created 5000 augmented images...
#   ✅ Processed 1300/1306 training AMF images, created 5200 augmented images...
#   ✅ Processed 1306/1306 training AMF images, created 5224 augmented images...
#
# ✅ Training augmentation completed!
# 📊 Training set results:
#    Original training samples: 8362
#    Augmented training samples: 5224
#    Total training samples: 13586
#    Augmentation success: 5224
#    Augmentation errors: 0
#
# 📊 FINAL DATASET COMPOSITION (After training augmentation):
# Total samples: 19162
# Normal: 11762 (61.4%)
# Atypical (AMF): 7400 (38.6%)
#
# 🔍 Final breakdown by split:
# Training (augmented): 13586 samples
#    - Training Normal: 7056
#    - Training AMF (original): 1306
#    - Training AMF (augmented): 5224
# Validation (original only): 2788 samples
#    - Validation Normal: 2353
#    - Validation AMF: 435
# Testing (original only): 2788 samples
#    - Testing Normal: 2353
#    - Testing AMF: 435
#
# ✅ Dataset updated with training augmentation only!
# 🎯 Key achievement: Only training data augmented, validation/test remain original!

# %%
# Now organize and save images with augmented training data
print("📁 Now organizing images into separate folders with augmented training data...")

# Reset the data lists
training_data = []
validation_data = []
testing_data = []

# Ensure directory variables are consistent
KAGGLE_DATASET_DIR = OUTPUT_DIR

# Process training data (includes augmented images)
print(f"\n📂 Processing training images (with augmentations)...")
train_copied, train_errors = copy_and_organize_images(
    train_augmented_df, TRAINING_DIR, 'training', training_data
)

# Process validation data (original only)
print(f"\n📂 Processing validation images (original only)...")
val_copied, val_errors = copy_and_organize_images(
    val_df, VALIDATION_DIR, 'validation', validation_data
)

# Process testing data (original only)
print(f"\n📂 Processing testing images (original only)...")
test_copied, test_errors = copy_and_organize_images(
    test_df, TESTING_DIR, 'testing', testing_data
)

# Calculate totals
copied_files = train_copied + val_copied + test_copied
copy_errors = train_errors + val_errors + test_errors

print(f"\n✅ IMAGE ORGANIZATION COMPLETED!")
print(f"📊 Summary:")
print(f"  Training images: {train_copied} (includes {len(augmented_df)} augmented)")
print(f"  Validation images: {val_copied}")
print(f"  Testing images: {test_copied}")
print(f"  Total copied: {copied_files}")
print(f"  Total errors: {copy_errors}")

# Combine all data for comprehensive CSV
all_data = training_data + validation_data + testing_data

print(f"\n📊 TOTAL IMAGES ORGANIZED: {len(all_data)}")
print(f"  - Training samples: {len(training_data)}")
print(f"  - Validation samples: {len(validation_data)}")
print(f"  - Testing samples: {len(testing_data)}")

# Show augmentation breakdown in training data
training_df_check = pd.DataFrame(training_data)
if len(training_df_check) > 0:
    aug_breakdown = training_df_check['is_augmented'].value_counts()
    print(f"\n🔍 Training set augmentation breakdown:")
    print(f"  Original images: {aug_breakdown.get(False, 0)}")
    print(f"  Augmented images: {aug_breakdown.get(True, 0)}")
    
    if aug_breakdown.get(True, 0) > 0:
        print(f"\n  Augmentation types in training:")
        aug_types = training_df_check[training_df_check['is_augmented'] == True]['augmentation_type'].value_counts().sort_index()
        for aug_type, count in aug_types.items():
            print(f"    Type {aug_type}: {count} images")

# Clean up temporary augmented images directory
temp_aug_dir = Path(os.getcwd()) / 'temp_augmented'
if temp_aug_dir.exists():
    shutil.rmtree(temp_aug_dir)
    print(f"\n🧹 Cleaned up temporary augmented images directory")

print(f"\n✅ Image organization and augmentation completed successfully!")
print(f"📁 All images are now properly organized in their respective folders")
# Out:
# 📁 Now organizing images into separate folders with augmented training data...
#
# 📂 Processing training images (with augmentations)...
#
# 📂 Processing training images...
#   ✅ Processed 100/13586 training images...
#   ✅ Processed 200/13586 training images...
#   ✅ Processed 300/13586 training images...
#   ✅ Processed 400/13586 training images...
#   ✅ Processed 500/13586 training images...
#   ✅ Processed 600/13586 training images...
#   ✅ Processed 700/13586 training images...
#   ✅ Processed 800/13586 training images...
#   ✅ Processed 900/13586 training images...
#   ✅ Processed 1000/13586 training images...
#   ✅ Processed 1100/13586 training images...
#   ✅ Processed 1200/13586 training images...
#   ✅ Processed 1300/13586 training images...
#   ✅ Processed 1400/13586 training images...
#   ✅ Processed 1500/13586 training images...
#   ✅ Processed 1600/13586 training images...
#   ✅ Processed 1700/13586 training images...
#   ✅ Processed 1800/13586 training images...
#   ✅ Processed 1900/13586 training images...
#   ✅ Processed 2000/13586 training images...
#   ✅ Processed 2100/13586 training images...
#   ✅ Processed 2200/13586 training images...
#   ✅ Processed 2300/13586 training images...
#   ✅ Processed 2400/13586 training images...
#   ✅ Processed 2500/13586 training images...
#   ✅ Processed 2600/13586 training images...
#   ✅ Processed 2700/13586 training images...
#   ✅ Processed 2800/13586 training images...
#   ✅ Processed 2900/13586 training images...
#   ✅ Processed 3000/13586 training images...
#   ✅ Processed 3100/13586 training images...
#   ✅ Processed 3200/13586 training images...
#   ✅ Processed 3300/13586 training images...
#   ✅ Processed 3400/13586 training images...
#   ✅ Processed 3500/13586 training images...
#   ✅ Processed 3600/13586 training images...
#   ✅ Processed 3700/13586 training images...
#   ✅ Processed 3800/13586 training images...
#   ✅ Processed 3900/13586 training images...
#   ✅ Processed 4000/13586 training images...
#   ✅ Processed 4100/13586 training images...
#   ✅ Processed 4200/13586 training images...
#   ✅ Processed 4300/13586 training images...
#   ✅ Processed 4400/13586 training images...
#   ✅ Processed 4500/13586 training images...
#   ✅ Processed 4600/13586 training images...
#   ✅ Processed 4700/13586 training images...
#   ✅ Processed 4800/13586 training images...
#   ✅ Processed 4900/13586 training images...
#   ✅ Processed 5000/13586 training images...
#   ✅ Processed 5100/13586 training images...
#   ✅ Processed 5200/13586 training images...
#   ✅ Processed 5300/13586 training images...
#   ✅ Processed 5400/13586 training images...
#   ✅ Processed 5500/13586 training images...
#   ✅ Processed 5600/13586 training images...
#   ✅ Processed 5700/13586 training images...
#   ✅ Processed 5800/13586 training images...
#   ✅ Processed 5900/13586 training images...
#   ✅ Processed 6000/13586 training images...
#   ✅ Processed 6100/13586 training images...
#   ✅ Processed 6200/13586 training images...
#   ✅ Processed 6300/13586 training images...
#   ✅ Processed 6400/13586 training images...
#   ✅ Processed 6500/13586 training images...
#   ✅ Processed 6600/13586 training images...
#   ✅ Processed 6700/13586 training images...
#   ✅ Processed 6800/13586 training images...
#   ✅ Processed 6900/13586 training images...
#   ✅ Processed 7000/13586 training images...
#   ✅ Processed 7100/13586 training images...
#   ✅ Processed 7200/13586 training images...
#   ✅ Processed 7300/13586 training images...
#   ✅ Processed 7400/13586 training images...
#   ✅ Processed 7500/13586 training images...
#   ✅ Processed 7600/13586 training images...
#   ✅ Processed 7700/13586 training images...
#   ✅ Processed 7800/13586 training images...
#   ✅ Processed 7900/13586 training images...
#   ✅ Processed 8000/13586 training images...
#   ✅ Processed 8100/13586 training images...
#   ✅ Processed 8200/13586 training images...
#   ✅ Processed 8300/13586 training images...
#   ✅ Processed 8400/13586 training images...
#   ✅ Processed 8500/13586 training images...
#   ✅ Processed 8600/13586 training images...
#   ✅ Processed 8700/13586 training images...
#   ✅ Processed 8800/13586 training images...
#   ✅ Processed 8900/13586 training images...
#   ✅ Processed 9000/13586 training images...
#   ✅ Processed 9100/13586 training images...
#   ✅ Processed 9200/13586 training images...
#   ✅ Processed 9300/13586 training images...
#   ✅ Processed 9400/13586 training images...
#   ✅ Processed 9500/13586 training images...
#   ✅ Processed 9600/13586 training images...
#   ✅ Processed 9700/13586 training images...
#   ✅ Processed 9800/13586 training images...
#   ✅ Processed 9900/13586 training images...
#   ✅ Processed 10000/13586 training images...
#   ✅ Processed 10100/13586 training images...
#   ✅ Processed 10200/13586 training images...
#   ✅ Processed 10300/13586 training images...
#   ✅ Processed 10400/13586 training images...
#   ✅ Processed 10500/13586 training images...
#   ✅ Processed 10600/13586 training images...
#   ✅ Processed 10700/13586 training images...
#   ✅ Processed 10800/13586 training images...
#   ✅ Processed 10900/13586 training images...
#   ✅ Processed 11000/13586 training images...
#   ✅ Processed 11100/13586 training images...
#   ✅ Processed 11200/13586 training images...
#   ✅ Processed 11300/13586 training images...
#   ✅ Processed 11400/13586 training images...
#   ✅ Processed 11500/13586 training images...
#   ✅ Processed 11600/13586 training images...
#   ✅ Processed 11700/13586 training images...
#   ✅ Processed 11800/13586 training images...
#   ✅ Processed 11900/13586 training images...
#   ✅ Processed 12000/13586 training images...
#   ✅ Processed 12100/13586 training images...
#   ✅ Processed 12200/13586 training images...
#   ✅ Processed 12300/13586 training images...
#   ✅ Processed 12400/13586 training images...
#   ✅ Processed 12500/13586 training images...
#   ✅ Processed 12600/13586 training images...
#   ✅ Processed 12700/13586 training images...
#   ✅ Processed 12800/13586 training images...
#   ✅ Processed 12900/13586 training images...
#   ✅ Processed 13000/13586 training images...
#   ✅ Processed 13100/13586 training images...
#   ✅ Processed 13200/13586 training images...
#   ✅ Processed 13300/13586 training images...
#   ✅ Processed 13400/13586 training images...
#   ✅ Processed 13500/13586 training images...
#   ✅ Processed 13586/13586 training images...
#   📊 training: 13586 copied, 0 errors
#
# 📂 Processing validation images (original only)...
#
# 📂 Processing validation images...
#   ✅ Processed 100/2788 validation images...
#   ✅ Processed 200/2788 validation images...
#   ✅ Processed 300/2788 validation images...
#   ✅ Processed 400/2788 validation images...
#   ✅ Processed 500/2788 validation images...
#   ✅ Processed 600/2788 validation images...
#   ✅ Processed 700/2788 validation images...
#   ✅ Processed 800/2788 validation images...
#   ✅ Processed 900/2788 validation images...
#   ✅ Processed 1000/2788 validation images...
#   ✅ Processed 1100/2788 validation images...
#   ✅ Processed 1200/2788 validation images...
#   ✅ Processed 1300/2788 validation images...
#   ✅ Processed 1400/2788 validation images...
#   ✅ Processed 1500/2788 validation images...
#   ✅ Processed 1600/2788 validation images...
#   ✅ Processed 1700/2788 validation images...
#   ✅ Processed 1800/2788 validation images...
#   ✅ Processed 1900/2788 validation images...
#   ✅ Processed 2000/2788 validation images...
#   ✅ Processed 2100/2788 validation images...
#   ✅ Processed 2200/2788 validation images...
#   ✅ Processed 2300/2788 validation images...
#   ✅ Processed 2400/2788 validation images...
#   ✅ Processed 2500/2788 validation images...
#   ✅ Processed 2600/2788 validation images...
#   ✅ Processed 2700/2788 validation images...
#   ✅ Processed 2788/2788 validation images...
#   📊 validation: 2788 copied, 0 errors
#
# 📂 Processing testing images (original only)...
#
# 📂 Processing testing images...
#   ✅ Processed 100/2788 testing images...
#   ✅ Processed 200/2788 testing images...
#   ✅ Processed 300/2788 testing images...
#   ✅ Processed 400/2788 testing images...
#   ✅ Processed 500/2788 testing images...
#   ✅ Processed 600/2788 testing images...
#   ✅ Processed 700/2788 testing images...
#   ✅ Processed 800/2788 testing images...
#   ✅ Processed 900/2788 testing images...
#   ✅ Processed 1000/2788 testing images...
#   ✅ Processed 1100/2788 testing images...
#   ✅ Processed 1200/2788 testing images...
#   ✅ Processed 1300/2788 testing images...
#   ✅ Processed 1400/2788 testing images...
#   ✅ Processed 1500/2788 testing images...
#   ✅ Processed 1600/2788 testing images...
#   ✅ Processed 1700/2788 testing images...
#   ✅ Processed 1800/2788 testing images...
#   ✅ Processed 1900/2788 testing images...
#   ✅ Processed 2000/2788 testing images...
#   ✅ Processed 2100/2788 testing images...
#   ✅ Processed 2200/2788 testing images...
#   ✅ Processed 2300/2788 testing images...
#   ✅ Processed 2400/2788 testing images...
#   ✅ Processed 2500/2788 testing images...
#   ✅ Processed 2600/2788 testing images...
#   ✅ Processed 2700/2788 testing images...
#   ✅ Processed 2788/2788 testing images...
#   📊 testing: 2788 copied, 0 errors
#
# ✅ IMAGE ORGANIZATION COMPLETED!
# 📊 Summary:
#   Training images: 13586 (includes 5224 augmented)
#   Validation images: 2788
#   Testing images: 2788
#   Total copied: 19162
#   Total errors: 0
#
# 📊 TOTAL IMAGES ORGANIZED: 19162
#   - Training samples: 13586
#   - Validation samples: 2788
#   - Testing samples: 2788
#
# 🔍 Training set augmentation breakdown:
#   Original images: 8362
#   Augmented images: 5224
#
#   Augmentation types in training:
#     Type 1.0: 1306 images
#     Type 2.0: 1306 images
#     Type 3.0: 1306 images
#     Type 4.0: 1306 images
#
# 🧹 Cleaned up temporary augmented images directory
#
# ✅ Image organization and augmentation completed successfully!
# 📁 All images are now properly organized in their respective folders

# %% [markdown]
# ## Data Processing Summary

# %%
# Data Processing Summary and Statistics

# Calculate basic statistics using the final dataset
total_samples = len(combined_df)
ami_br_samples = len(ami_br_final)
midog25_samples = len(midog25_final)

# Recalculate split statistics with augmented training data
train_samples = len(train_augmented_df)
val_samples = len(val_df)
test_samples = len(test_df)

# Class distribution analysis (final)
class_distribution = combined_df['label'].value_counts()
class_percentages = combined_df['label'].value_counts(normalize=True) * 100

# Dataset distribution
dataset_distribution = combined_df['dataset'].value_counts()

# Create comprehensive data summary
data_summary = {
    'total_samples': int(total_samples),
    'ami_br_samples': int(ami_br_samples),
    'midog25_samples': int(midog25_samples),
    'train_samples': int(train_samples),
    'val_samples': int(val_samples),
    'test_samples': int(test_samples),
    'class_distribution': {
        'normal': int(class_distribution.get(0, 0)),
        'atypical': int(class_distribution.get(1, 0))
    },
    'class_percentages': {
        'normal': float(class_percentages.get(0, 0)),
        'atypical': float(class_percentages.get(1, 0))
    },
    'dataset_distribution': dataset_distribution.to_dict(),
    'duplicates_removed': len(duplicates) if duplicates else 0
}

print("=" * 60)
print("DATA PROCESSING SUMMARY")
print("=" * 60)
print(f"Total Samples Processed: {data_summary['total_samples']}")
print(f"  - AMI-BR Dataset: {data_summary['ami_br_samples']}")
print(f"  - MIDOG25 Dataset: {data_summary['midog25_samples']}")
print(f"\nData Splits:")
print(f"  - Training: {data_summary['train_samples']} samples")
print(f"  - Validation: {data_summary['val_samples']} samples")
print(f"  - Test: {data_summary['test_samples']} samples")
print(f"\nClass Distribution:")
print(f"  - Normal: {data_summary['class_distribution']['normal']} ({data_summary['class_percentages']['normal']:.1f}%)")
print(f"  - Atypical: {data_summary['class_distribution']['atypical']} ({data_summary['class_percentages']['atypical']:.1f}%)")
print(f"\nData Quality:")
print(f"  - Duplicate slides removed: {data_summary['duplicates_removed']}")
print(f"  - Stratified splitting: ✓")
print(f"  - Balanced class distribution: ✓")
print("=" * 60)

# Save data processing summary to JSON
with open('data_processing_summary.json', 'w') as f:
    json.dump(data_summary, f, indent=2)

print("\nData processing summary saved to 'data_processing_summary.json'")
print("Data processing completed successfully!")
# Out:
# ============================================================
# DATA PROCESSING SUMMARY
# ============================================================
# Total Samples Processed: 19162
#   - AMI-BR Dataset: 1999
#   - MIDOG25 Dataset: 11939
#
# Data Splits:
#   - Training: 13586 samples
#   - Validation: 2788 samples
#   - Test: 2788 samples
#
# Class Distribution:
#   - Normal: 11762 (61.4%)
#   - Atypical: 7400 (38.6%)
#
# Data Quality:
#   - Duplicate slides removed: 135
#   - Stratified splitting: ✓
#   - Balanced class distribution: ✓
# ============================================================
#
# Data processing summary saved to 'data_processing_summary.json'
# Data processing completed successfully!

# %%
# Create final CSV with all organized data
print("💾 Creating final dataset CSV with organized data...")

# Check if all_data exists and has content
if 'all_data' in locals() and len(all_data) > 0:
    # Create complete CSV with all organized data
    kaggle_df = pd.DataFrame(all_data)

    # Save the dataset as CSV
    csv_path = KAGGLE_DATASET_DIR / 'mitotic_figures_dataset.csv'
    kaggle_df.to_csv(csv_path, index=False)

    print(f"\n💾 Dataset saved successfully!")
    print(f"📄 CSV file: {csv_path}")
    print(f"🗂️  Dataset folders: {KAGGLE_DATASET_DIR}")

    # Final dataset statistics
    print(f"\n📈 FINAL ORGANIZED DATASET STATISTICS:")
    print(f"  Total samples: {len(kaggle_df):,}")

    # Statistics by split
    split_stats = kaggle_df['split'].value_counts()
    print(f"\n  📊 Split distribution:")
    for split in ['training', 'validation', 'testing']:
        count = split_stats.get(split, 0)
        percentage = (count / len(kaggle_df)) * 100 if len(kaggle_df) > 0 else 0
        print(f"    {split.capitalize()}: {count:,} samples ({percentage:.1f}%)")

    # Statistics by label
    print(f"\n  🏷️  Label distribution:")
    label_stats = kaggle_df['is_atypical'].value_counts().sort_index()
    for label, count in label_stats.items():
        label_name = "Atypical Mitotic Figure (AMF)" if label else "Normal Mitotic Figure (NMF)"
        percentage = (count / len(kaggle_df)) * 100
        print(f"    {label_name}: {count:,} samples ({percentage:.1f}%)")

    # Training set augmentation details
    training_subset = kaggle_df[kaggle_df['split'] == 'training']
    if len(training_subset) > 0:
        aug_stats = training_subset['is_augmented'].value_counts()
        print(f"\n  🔄 Training set augmentation:")
        print(f"    Original images: {aug_stats.get(False, 0):,}")
        print(f"    Augmented images: {aug_stats.get(True, 0):,}")

    # Dataset source distribution
    print(f"\n  🗃️  Dataset sources:")
    source_stats = kaggle_df['dataset'].value_counts()
    for dataset, count in source_stats.items():
        percentage = (count / len(kaggle_df)) * 100
        print(f"    {dataset}: {count:,} samples ({percentage:.1f}%)")

    print(f"\n🎉 Complete dataset preparation finished!")
    print(f"📁 Your organized dataset is ready at: {KAGGLE_DATASET_DIR}")
    print(f"🏗️  Folder structure:")
    print(f"   📂 {KAGGLE_DATASET_DIR / 'training'}")
    print(f"   📂 {KAGGLE_DATASET_DIR / 'validation'}")
    print(f"   📂 {KAGGLE_DATASET_DIR / 'testing'}")
    print(f"   📄 {csv_path}")
    print(f"🚀 Ready for model training!")
else:
    print("⚠️  Data not yet organized. Please run the augmentation and organization sections first.")
    print("📝 The organized data will be available after running all previous cells.")
# Out:
# 💾 Creating final dataset CSV with organized data...
#
# 💾 Dataset saved successfully!
# 📄 CSV file: /kaggle/working/kaggle_dataset/mitotic_figures_dataset.csv
# 🗂️  Dataset folders: /kaggle/working/kaggle_dataset
#
# 📈 FINAL ORGANIZED DATASET STATISTICS:
#   Total samples: 19,162
#
#   📊 Split distribution:
#     Training: 13,586 samples (70.9%)
#     Validation: 2,788 samples (14.5%)
#     Testing: 2,788 samples (14.5%)
#
#   🏷️  Label distribution:
#     Normal Mitotic Figure (NMF): 11,762 samples (61.4%)
#     Atypical Mitotic Figure (AMF): 7,400 samples (38.6%)
#
#   🔄 Training set augmentation:
#     Original images: 8,362
#     Augmented images: 5,224
#
#   🗃️  Dataset sources:
#     MIDOG25: 16,151 samples (84.3%)
#     AMI-BR: 3,011 samples (15.7%)
#
# 🎉 Complete dataset preparation finished!
# 📁 Your organized dataset is ready at: /kaggle/working/kaggle_dataset
# 🏗️  Folder structure:
#    📂 /kaggle/working/kaggle_dataset/training
#    📂 /kaggle/working/kaggle_dataset/validation
#    📂 /kaggle/working/kaggle_dataset/testing
#    📄 /kaggle/working/kaggle_dataset/mitotic_figures_dataset.csv
# 🚀 Ready for model training!

# %%
# 1️⃣ Zip the entire directory
# !zip -r my_results.zip /kaggle/working/kaggle_dataset

# 2️⃣ Move it to the notebook's output path so it's downloadable
# !mv my_results.zip /kaggle/working/
# Out:
#   adding: kaggle/working/kaggle_dataset/ (stored 0%)
#   adding: kaggle/working/kaggle_dataset/mitotic_figures_dataset.csv (deflated 91%)
#   adding: kaggle/working/kaggle_dataset/validation/ (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/826.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6427.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/8024.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1834.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10235.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1757.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/621.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5315.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5621.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1397.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8171.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7885.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7397.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11714.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4924.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1967.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5070.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/9739.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4627.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5443.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11624.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2153.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4561.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_3322.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/652.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11900.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3436.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2024.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8499.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11932.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/482.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_493.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8111.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10988.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6107.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2219.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10014.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2290.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4031.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8396.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2694.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9956.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11766.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4503.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5982.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1549.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9445.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6811.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2241.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3736.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/966.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9440.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3937.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8332.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8406.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8101.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1972.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3345.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8187.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11694.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6790.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4716.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6272.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/11433.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10585.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_10617.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3991.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2610.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11183.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7033.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10921.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1163.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9858.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2973.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9761.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6373.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7379.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6519.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5078.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3504.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7272.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7048.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/2651.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2337.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5861.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6982.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/6009.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8228.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9584.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4316.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11610.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/46.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10429.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1169.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4574.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_89.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6267.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/11930.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6758.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9800.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4000.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9206.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9558.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8874.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7516.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1235.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2865.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2323.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10316.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8900.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3746.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7572.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2026.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10539.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4561.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3637.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3060.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/250.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1103.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6148.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/10405.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11239.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/366.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9980.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2114.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11181.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11850.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3110.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8444.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3971.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2161.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3739.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10341.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_12096.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3113.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/568.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1959.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4058.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3931.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2704.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10432.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7677.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7586.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/689.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/76.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8457.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8006.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/8179.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1541.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3572.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5458.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4262.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10364.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1313.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_360.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6036.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4966.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1322.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1901.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_101.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11064.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/429.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2893.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7077.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2603.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/225.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9539.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2697.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/2965.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/645.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7568.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4984.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11606.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_138.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6773.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11826.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_496.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8752.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8963.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1474.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9351.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9399.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10983.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3856.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10710.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7978.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3375.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3240.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1182.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10799.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7704.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2013.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4790.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4110.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6329.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9252.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/314.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2647.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4606.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9307.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7057.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/7367.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5438.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/6725.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_3066.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7354.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/935.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7320.png (deflated 2%)
#   adding: kaggle/working/kaggle_dataset/validation/5086.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4976.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1775.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9275.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4872.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4053.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8152.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10483.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5066.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/11288.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1192.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3297.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4843.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2074.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3331.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6554.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_8821.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/5214.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5801.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4437.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4591.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/7791.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7396.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5726.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/9140.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7162.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5339.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_3763.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/11093.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6817.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9419.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8865.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6391.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7543.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4757.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8605.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7227.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_3016.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_922.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/794.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10816.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4023.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11543.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7893.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7736.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8259.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_7763.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/6291.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/5768.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8182.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5345.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8691.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/532.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3357.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_556.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8141.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3974.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7270.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_97.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5027.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3122.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11372.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5733.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7606.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10239.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4060.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5539.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/2970.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4256.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6490.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1389.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3655.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7503.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_400.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3836.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7173.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5693.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_9455.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11461.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3009.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10212.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4178.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8883.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2397.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9835.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11038.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2457.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6803.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11756.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1327.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3761.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9853.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7913.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3004.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11732.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/23.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9969.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8158.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9091.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9481.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10402.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/164.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4307.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/226.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9757.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4158.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1796.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6609.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2368.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5499.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2736.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1212.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9703.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11229.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_368.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5472.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1866.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_370.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1676.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9096.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7353.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5332.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5131.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/565.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6344.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7083.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5256.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3868.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3093.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8952.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3829.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2777.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2900.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2210.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1138.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3163.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2059.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3203.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_11262.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/580.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4648.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/995.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6004.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2754.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4674.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5514.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_983.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8986.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10853.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5837.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1613.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_3272.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2904.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10268.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8420.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6885.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3443.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2876.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5239.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8811.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8869.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11022.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5660.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_14498.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8890.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8643.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1848.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2367.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5503.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/10354.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2760.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2121.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7993.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7208.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10392.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5767.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2918.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/960.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11795.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8034.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1029.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9449.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5190.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9974.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7941.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/11280.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4718.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5969.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2746.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11283.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4899.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7579.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10139.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10899.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8198.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5365.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9043.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10440.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8672.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2218.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/3071.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11085.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5069.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9008.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1629.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11698.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2612.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4249.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10574.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9059.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/528.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4069.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8559.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1925.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9301.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10190.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10796.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2879.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8113.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1555.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4020.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4001.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8877.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7151.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/9050.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9984.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1559.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1813.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11641.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10985.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6526.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2217.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11865.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7441.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11398.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5453.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5489.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/742.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10999.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/344.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9513.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2490.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1989.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/751.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5497.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2434.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4556.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1255.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/44.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11040.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9107.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9811.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9755.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4162.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1489.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_93.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4619.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11289.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2525.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_4858.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11657.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8366.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5537.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7029.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/8454.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10778.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5125.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8304.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/573.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11809.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2712.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5618.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10017.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11225.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7836.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1821.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4736.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/715.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2260.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10538.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2473.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9949.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6951.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2689.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4773.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3437.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11667.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2281.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2680.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6258.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11927.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3102.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3438.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1088.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5241.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5227.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1367.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1202.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11688.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4187.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2948.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_607.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2882.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/758.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/408.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3305.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1099.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_3979.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/9482.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2515.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1938.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8946.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2328.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5186.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11407.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9604.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6400.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/929.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5697.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/6306.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/188.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6131.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1078.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1387.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/167.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1246.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2706.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3312.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/5512.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_3681.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/618.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3316.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1711.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/9808.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10604.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_928.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9566.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8745.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5795.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2442.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_586.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_515.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9250.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8495.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7465.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1991.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1600.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11396.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4286.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_685.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7281.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10798.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2138.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_13178.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2728.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1707.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2623.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_503.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9199.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7097.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2640.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8687.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_118.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3566.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8806.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1158.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6413.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_244.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5211.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/9291.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11839.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5292.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/11446.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2963.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5147.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9914.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1809.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_284.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/8041.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7689.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/887.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5578.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11053.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10523.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_5113.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7730.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7851.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6900.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11505.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/11119.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6313.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7176.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5864.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4339.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/606.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9181.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3984.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10309.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4445.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7106.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/495.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/5603.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1344.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6947.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/validation/9620.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9385.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7630.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1031.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7608.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3017.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10795.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/7310.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/4015.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/662.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_2340.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6256.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1103.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/9221.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/10454.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_14495.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/707.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/1230.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/105.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/6732.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/2972.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3196.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_656.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/TUPAC16_1405.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/validation/3198.png (deflated 0%)
# ...
#   adding: kaggle/working/kaggle_dataset/testing/9249.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6236.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2358.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11557.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_7023.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6428.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/4096.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8906.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3237.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7960.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9240.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3542.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_19.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10946.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_1664.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5714.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10464.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5134.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5637.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5424.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/470.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10481.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_1781.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2147.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/320.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3701.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4056.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4549.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1217.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10747.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6030.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2038.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_1173.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3277.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3905.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7642.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_2970.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_2458.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3996.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3600.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9277.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1727.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_4844.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_3187.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1019.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2095.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6618.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_3693.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8318.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10703.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8066.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_546.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11102.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6171.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_2456.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_425.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4385.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2289.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9500.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_3440.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4861.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7007.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/2503.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8802.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/3127.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6977.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_4797.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10641.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1475.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1326.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_2852.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6003.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7090.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/6983.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/11011.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4592.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1370.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5325.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10353.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/11074.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1313.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7796.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7387.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2316.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2974.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_4158.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/6835.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8110.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5639.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11513.png (deflated 2%)
#   adding: kaggle/working/kaggle_dataset/testing/3910.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_153.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1245.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4497.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_2346.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2307.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7053.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/4151.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3176.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4327.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_5161.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/4488.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11439.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1450.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8827.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4958.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11470.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6751.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8763.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11857.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11870.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4583.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3997.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9848.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4018.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6120.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/11604.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6643.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9459.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6310.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6697.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5166.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8469.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/880.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11550.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/4707.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10070.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4546.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_2061.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7063.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3327.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_371.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_5045.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/4938.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3269.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3647.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1868.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_885.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3489.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/466.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5462.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_7052.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/541.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4945.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7922.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7549.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6700.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1094.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7528.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4468.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_1315.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5349.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6402.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3494.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4427.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9762.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3858.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1153.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8230.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6255.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6779.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2388.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1174.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6655.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5081.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11450.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4912.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4843.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2274.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1472.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6960.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/11458.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5919.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1299.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1505.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/7518.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_3534.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1873.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/991.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4019.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10054.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_893.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9425.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9985.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_5114.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10465.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11378.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/58.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8603.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7655.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/6211.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/5748.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5455.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1922.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6434.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/4044.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2101.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9838.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6563.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9885.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10587.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5848.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_1181.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/2408.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8033.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/9726.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/8419.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11400.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_2943.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_4393.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/1378.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/638.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/5348.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3760.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/7330.png (deflated 1%)
#   adding: kaggle/working/kaggle_dataset/testing/2587.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/TUPAC16_1677.png (stored 0%)
#   adding: kaggle/working/kaggle_dataset/testing/10857.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/3164.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/6782.png (deflated 0%)
#   adding: kaggle/working/kaggle_dataset/testing/11821.png (deflated 0%)
# mv: 'my_results.zip' and '/kaggle/working/my_results.zip' are the same file

# %%
from IPython.display import FileLink
FileLink('my_results.zip')
# Out:
# /kaggle/working/my_results.zip
